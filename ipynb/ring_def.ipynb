# %%
import pandas as pd
import requests
import json

# %%
def req(obj):
    url = 'https://ring.org.ua/search?q=' + obj + '&datasources=edrdr&format=json'
    response = requests.get(url) # надсилаємо get-запит на сервер ring.org.ua
    #response = requests.get(url, verify=False) # якщо матюкається на SSL-сертифікат
    if response.status_code == 200:
        dict_resp = response.json()
        items = dict_resp['search_results']['paginator']['count'] # кількість пов'язаних фірм
        pages = dict_resp['search_results']['paginator']['num_pages'] # кількість сторінок у результаті
        result = dict_resp['search_results']['object_list'] # формуємо список даних про фірми
        if pages > 1: # якщо результати запиту не вмістилися на одну сторінку (не може бути більше 1000?)
            for i in range(2, pages+1): # повторюємо запит для всіх сторінок, починаючи з другої
                url = 'https://ring.org.ua/search?q=' + obj + '&datasources=edrdr&format=json&page=' + str(i)
                response = requests.get(url) # надсилаємо get-запит на сервер ring.org.ua
                #response = requests.get(url, verify=False) # якщо матюкається на SSL-сертифікат
                if response.status_code == 200:
                    dict_resp = response.json()
                    result += dict_resp['search_results']['object_list'] # поповнюємо список даних про фірми
                else:
                    print('Error: requested url ' + url + ' is not available!')
        if len(result) == items: # перевіряємо, чи нам вдалося отримати інформацію про всі пов'язані фірми
            return (items, result)
        else:
            print('Warning: parsed url ' + url.split('&page=')[0] + ' is not full!')
            return (len(result), result)
    else:
        print('Error: requested url ' + url + ' is not available!')
        return (0, ['error'])

# %%
def add_info(firm):
    # додаємо фірму до словника знайдених контрагентів
    edrpou = firm['full_edrpou']
    name = firm['latest_record']['name'].lower()
    short_name = firm['latest_record']['short_name'].lower()
    status = firm['latest_record']['status'].lower()
    dict_find[edrpou] = (name, short_name, status) # додаємо інформацію про фірму: назва, повна назва, статус
    dict_firm[name] = edrpou # якщо будуть дублі за повною назвою фірми, то запишеться лише останній ЄДРПОУ!
    if (status != 'припинено') and (name not in list_temp) and (name not in list_next): # якщо фірма функціонує
        list_next.append(name) # на наступному рівні шукатимемо засновані цією фірмою фірми
        # додаємо інформацію про засновників фірми
        list_all = list(set([person[0].lower().replace('  ', ' ') for person in firm['raw_persons']])) # фізособи
        for person in list_all:
            if person not in set(dict_find.keys()): # якщо ця особа ще не засвітилася раніше
                dict_find[person] = () # додаємо її П.І.Б. до словника знайдених контрагентів
            if (person not in list_temp) and (person not in list_next): # і якщо вона не включена до пошуку
                list_next.append(person) # на наступному рівні шукатимемо засновані цією особою фірми
        list_master = list(set([person[0].lower().replace('  ', ' ') for person in firm['raw_persons'] 
                                if person[1] == 'Голова'])) # список голів фірми (голова тільки один?)
        list_founder = list(set([person[0].lower().replace('  ', ' ') for person in firm['raw_persons'] 
                                 if person[1] == 'Засновник'])) # список засновників (вносили кошти)
        list_benef = list(set([person[0].lower().replace('  ', ' ') for person in firm['raw_persons'] 
                               if person[1] == 'Бенефіціарний власник'])) # список бенефіціарів
        for head in list_master: # додаємо інформацію про голів фірм, вони можуть не бути засновниками
            list_head.append([head, edrpou])
        records = firm['raw_records'] # тут міститься інформація про частки участі засновників (у грн.)
        part = dict()
        for record in records: # відбираємо інформацію тільки про ненульові внески
            if (record.find(' грн.')!=-1) and (record.find(' 0.00 грн.')==-1) and (record.find(' 0,00 грн.')==-1):
                part[record.split(',')[0].lower().replace('  ', ' ')] = float(
                    record.split('-')[-1].split('грн')[0].strip().replace(',', '.')) # засновник і його внесок
        if len(part) > 0: # якщо є інформація хоча б про один ненульовий внесок до статутного капіталу
            capital = sum(part.values())
            for founder in list(part):
                if founder in list_all: # засновник -- фізична особа
                    if founder in list_benef: # засновник є бенефіціаром
                        list_type.append([founder, edrpou, part[founder]/capital, 1])
                    else: # засновник не є бенефіціаром
                        list_type.append([founder, edrpou, part[founder]/capital, 0])
                else: # засновник -- юридична особа (фірма)
                    if founder in list(dict_firm): # і для цієї фірми ми вже маємо інформації про її ЄДРПОУ
                        list_type.append([dict_firm[founder], edrpou, part[founder]/capital, 0])
                    else: # інакше записуємо просто назву фірми
                        list_type.append([founder, edrpou, part[founder]/capital, 0])
        # якщо бенефіціар не вносив кошти до статутного капіталу, додаємо інформацію про нього
        zero_benef = list(set(list_benef) - set(list(part)))
        if len(zero_benef) > 0:
            for founder in zero_benef:
                list_type.append([founder, edrpou, 0, 1])
        # якщо засновник не є бенефіціаром і не вносив кошти до статутного капіталу, додаємо інформацію про нього
        zero_founder = list(set(list_founder) - set(list_benef) - set(list(part)))
        if len(zero_founder) > 0:
            for founder in zero_founder:
                list_type.append([founder, edrpou, 0, 0])
        #print('Всі засновники: ', list_all)
        #print('Голови: ', list_master)
        #print('Звичайні засновники: ', list_founder)
        #print('Засновники-бенефіціари: ', list_benef)
        #print('Засновники з ненульовими внесками: ', list(part))
        #print('"Нульові" засновники-бенефіціари: ', zero_benef)
        #print('"Нульові" звичайні засновники: ', zero_founder)

# %%
dict_find = dict() # словник знайдених контрагентів
dict_firm = dict() # словник назва фірми --> ЄДРПОУ
list_type = [] # список зв'язків між знайденими контрагентами
list_head = [] # список голів фірм
list_temp = [] # список контрагентів на поточному рівні
list_next = [] # список контрагентів наступного рівня
i = 0 # лічильник (номер рівня відносно початкового об'єкта)

# %%
# ці дані буде задавати користувач під час запуску
start = '35696771' # задаємо ЄДРПОУ початкової фірми
level = 3 # задаємо максимальну кількість рівнів

# %%
# %%time
list_next.append(start)
while (len(list_next) > 0) and (i < level):
    list_temp = list_next.copy()
    list_next = []
    for obj in list_temp:
        resp = req(obj)
        num = resp[0] # кількість знайдених фірм, пов'язаних із даним об'єктом (ЄДРПОУ, назва фірми, П.І.Б.)
        if num != 0:
            list_obj = resp[1] # список даних по знайдених фірмах
            for n in range(num):
                edrpou = list_obj[n]['full_edrpou'] # підтягуємо ЄДРПОУ фірми (що робити, якщо його немає?)
                if edrpou not in set(dict_find.keys()): # якщо ми ще не обробляли інформацію про дану фірму
                    add_info(list_obj[n]) # додаємо інформацію про засновників фірми та нові об'єкти для пошуку
        else:
            if req(obj)[1] == ['error']:
                print('Error request for object = ', obj)
    i += 1
# Out:
# CPU times: user 2.66 s, sys: 105 ms, total: 2.76 s
# Wall time: 36.9 s

# %%
dict_find # знайдені контрагенти (вершини графа), для фірм додаємо повну назву, скорочену назву і стан
# Out:
# {'35696771': ('товариство з обмеженою відповідальністю "комплекс інвестмент менеджмент"',
#   'тов "кім"',
#   'зареєстровано'),
#  'ловчин лев юрійович': (),
#  'соколенко олександр іванович': (),
#  'рутовський дмитро олегович': (),
#  '37761449': ('товариство з обмеженою відповідальністю "інджи"',
#   'тов "інджи"',
#   'зареєстровано'),
#  'меламуд євген мойсейович': (),
#  'кравченко валентин валерійович': (),
#  '38663859': ('приватне підприємство "щедрий сад."',
#   'пп "щедрий сад."',
#   'зареєстровано'),
#  '38141129': ('фермерське господарство "соколенки"',
#   'фг "соколенки"',
#   'зареєстровано'),
#  'соколенко сергій іванович': (),
#  '21503248': ('товариство з обмеженою відповідальністю "фірма "сезон лтд."',
#   'тов "фірма "сезон лтд."',
#   'зареєстровано'),
#  'бернатович вадим миколайович': (),
#  'ємельянова ольга олександрівна': (),
#  'соколенко іван станіславович': (),
#  '13904523': ('мале підприємство у вигляді товариства з обмеженою відповідальністю фірма "сокол" лтд',
#   'мп тов "сокол" лтд',
#   'припинено'),
#  '40581613': ('товариство з обмеженою відповідальністю "камидана"',
#   'тов "камидана"',
#   'зареєстровано'),
#  'рутовська світлана олександрівна': (),
#  '39189177': ('товариство з обмеженою відповідальністю "сервіс уют"',
#   'тов "сервіс уют"',
#   'зареєстровано'),
#  'корольов сергій петрович': (),
#  '39119103': ('товариство з обмеженою відповідальністю "домера"',
#   'тов "домера"',
#   'зареєстровано'),
#  'рутовський олег георгійович': (),
#  '33852359': ('товариство з обмеженою відповідальністю "южспецмонтаж донбас"',
#   'тов "южспецмонтаж донбас"',
#   'припинено'),
#  '30542625': ('товариство з обмеженою відповідальністю "южспецмонтаж"',
#   'тов "южспецмонтаж"',
#   'зареєстровано'),
#  'галак оксана василівна': (),
#  'анісіфоров володимир львович': (),
#  'малюта ірина михайлівна': (),
#  'корольов петро васильович': (),
#  '33138719': ('дочірнє підприємство "юсм-уют"', '', 'зареєстровано'),
#  'саіпова наталія леонідівна': (),
#  '39324857': ('товариство з обмеженою відповідальністю "стройбілдінг"',
#   'тов "стройбілдінг"',
#   'зареєстровано'),
#  'жоров євген данилович': (),
#  '42498353': ('товариство з обмеженою відповідальністю "коляда софт"',
#   'тов "коляда софт"',
#   'зареєстровано'),
#  'супруненко валерій іванович': (),
#  'тростянецький володимир васильович': (),
#  'гук вячеслав олександрович': (),
#  '41398320': ('товариство з обмеженою відповідальністю "комфорт буд одеса"',
#   'тов "комфорт буд одеса"',
#   'зареєстровано'),
#  'діланян самвел авакович': (),
#  'дорошенко анатолій іванович': (),
#  '05392335': ('акціонерне товариство "південсільспецмонтаж" закритого типу',
#   'ат "пссм"зт',
#   'припинено'),
#  '39009435': ('товариство з обмеженою відповідальністю "навігейт україна"',
#   'тов "навігейт україна"',
#   'зареєстровано'),
#  'плукчі петро гнатович': (),
#  'нарольський андрій олегович': (),
#  '19198523': ('мале підприємство - товариство з обмеженою відповідальністю "онікс - лтд"',
#   '',
#   'в стані припинення'),
#  'зак вячеслав юхимович': (),
#  '35930695': ('громадська організація "організація інвалідів "новий крок"',
#   'го "організація інвалідів "новий крок"',
#   'зареєстровано'),
#  'стрельников андрій вікторович': (),
#  'шейко ольга вікторівна': (),
#  '32240582': ('приватне підприємство "щедрий сад"',
#   'пп "щедрий сад"',
#   'зареєстровано'),
#  'шеремет олег петрович': (),
#  '20631837': ('виробничо - комерційна приватна фірма "тік"',
#   '',
#   'зареєстровано'),
#  'соколенко іван сергійович': (),
#  '20641014': ('товариство з обмеженою відповідальністю виробниче підприємство "комплекс"',
#   '',
#   'зареєстровано'),
#  'швачко геннадій євгенович': (),
#  '34845688': ('приватне підприємство "міжнародний центр іноваційних технологій, інформації, підприємництва, бізнесу, організації праці та навчання"',
#   'пп "мцітіпбопн"',
#   'зареєстровано'),
#  'коваленко володимир григорович': (),
#  'руденко олег іванович': (),
#  'бондаренко василь павлович': (),
#  '21503231': ('товариство з обмеженою відповідальністю "фірма "фрізон лтд."',
#   'тов "фірма "фрізон лтд."',
#   'зареєстровано'),
#  'майсак сергій григорович': (),
#  'осетров валентин геннадійович': (),
#  'донченко євгеній васильович': (),
#  'майсак ігор григорович': (),
#  '37486625': ('товариство з обмеженою відповідальністю "уют сервіс"',
#   'тов "уют сервіс"',
#   'зареєстровано'),
#  'олійник олег володимирович': (),
#  '37573403': ('товариство з обмеженою відповідальністю "уют-сервіс"',
#   'тов "уют-сервіс"',
#   'зареєстровано'),
#  'ткачук валентина павлівна': (),
#  'ткачук валентина петрівна': (),
#  '42715530': ('товариство з обмеженою відповідальністю "еллада уют сервіс "',
#   'тов " еллада уют сервіс "',
#   'зареєстровано'),
#  "херсоненко олена в'ячеславівна": (),
#  '37893163': ('товариство з обмеженою відповідальністю "житло уют сервіс"',
#   'тов"житло уют сервіс"',
#   'зареєстровано'),
#  'голубовський олександр павлович': (),
#  'фруктов сергій сергійович': (),
#  'богуш анна вікторівна': (),
#  'караванський сергій георгійович': (),
#  '39444367': ('товариство з обмеженою відповідальністю "авіа техконтакт"',
#   'тов "авіа техконтакт"',
#   'зареєстровано'),
#  'крилов антон сергійович': (),
#  'тітаренко євген анатолійович': (),
#  'корольова тетяна едуардівна': (),
#  'старшова наталія вікторівна': (),
#  'євдокімова олена миколаївна': (),
#  '40630906': ('товариство з обмеженою відповідальністю "торгбуд девелоп"',
#   'тов "торгбуд девелоп"',
#   'зареєстровано'),
#  'андрієнко сергій миколайович': (),
#  'збризький максим сергійович': (),
#  'євсєєв антон ігорович': (),
#  '24055075': ('товариство з обмеженою відповідальністю "виробничо-комерційна фірма "басско-2006"',
#   'тов в-кф "басско-2006"',
#   'зареєстровано'),
#  'шевчук віра петрівна': (),
#  'рутовський дмитро георгійович': (),
#  '33138771': ('дочірнє підприємство "юсм-майстерня холоду"',
#   'дп "юсм-майстерня холоду"',
#   'зареєстровано'),
#  'романов анатолій олексійович': (),
#  '05462751': ('комунальний заклад "хоростківська  музична школа"',
#   '',
#   'зареєстровано'),
#  'барановський микола васильович': (),
#  'хоростківська міська рада': (),
#  '40739476': ('товариство з обмеженою відповідальністю "дінерострой"',
#   '',
#   'зареєстровано'),
#  'подосян аркадій мелітосович': (),
#  'кузьменко микита володимирович': (),
#  '30662863': ('приватне підприємство "теплокомплект"',
#   'пп "теплокомплект"',
#   'в стані припинення'),
#  "погасов в'ячеслав сергійович": (),
#  '42980638': ('товариство з обмеженою відповідальністю "оліргруп"',
#   'тов "оліргруп"',
#   'зареєстровано'),
#  '41153155': ('громадська організація "всеукраїнська асоціація "турбота про діабетика"',
#   'го "вуа "турбота про діабетика"',
#   'зареєстровано'),
#  'сергеєва ірина борисівна': (),
#  '42824290': ('товариство з обмеженою відповідальністю "дедал плюс"',
#   'тов "дедал плюс"',
#   'зареєстровано'),
#  'сидорченко ірина василівна': (),
#  '40512178': ('товариство з обмеженою відповідальністю "будинок культури фпо"',
#   'тов "будинок культури фпо"',
#   'зареєстровано'),
#  'приходько тетяна василівна': (),
#  'чіжов юрій вікторович': (),
#  'малюта вікторія сергіївна': (),
#  '36823184': ('приватне підприємство "будімпекс-плюс"',
#   'пп "бпс"',
#   'зареєстровано'),
#  'прохоренко олена євгенівна': (),
#  'тютіна людмила григорівна': (),
#  'діденко марія миколаївна': (),
#  'прохоренко олександр геннадійович': (),
#  'ярмоленко валентина миколаївна': (),
#  'шаховнін артем олегович': (),
#  'матвієць маргарита олександрівна': (),
#  '30128252': ('закрите акціонерне товариство "газ"', 'зат "газ"', 'припинено'),
#  '33138745': ('дочірнє підприємство "юсм-проект"',
#   'дп "юсм-проект"',
#   'зареєстровано'),
#  '36860315': ('приватне підприємство "лісове господарство курорту сергіївка"',
#   'пп "лісове господарство курорту сергіївка"',
#   'зареєстровано'),
#  '36860336': ('приватне підприємство "сергіївська фабрика продтоварів"',
#   'пп "сергіївська фабрика продтоварів"',
#   'зареєстровано'),
#  '32989552': ('приватне підприємство "ренесанс-7"',
#   'пп"ренесанс-7"',
#   'зареєстровано'),
#  '34712289': ('товариство з обмеженою відповідальністю "швейна фабрика "діана"',
#   'тов "швейна фабрика "діана"',
#   'зареєстровано'),
#  'шевченко олег петрович': (),
#  '39773456': ('підприємство об\'єднання громадян "навчально-виробниче підприємство "промінь"',
#   'пог "нвп "промінь"',
#   'зареєстровано'),
#  '36508768': ('громадська організація "центр розвитку курорту сергіївка"',
#   'го "центр розвитку курорту сергіївка"',
#   'зареєстровано'),
#  'андронатій майя семенівна': (),
#  'супруненко діана анатоліївна': (),
#  'нестерюк павліна валентинівна': (),
#  '21114989': ('фермерське господарство "кристал"',
#   'фг "кристал"',
#   'зареєстровано'),
#  'калач марина володимирівна': (),
#  'лучанінова ірина анатоліївна': (),
#  'лучанінов володимир васильович': (),
#  '03779142': ('сільськогосподарське закрите акціонерне товариство "маяк"',
#   'сзат "маяк"',
#   'припинено'),
#  '34754596': ('приватне підприємство "техметал"',
#   'пп "техметал"',
#   'припинено'),
#  '32642131': ('комунальне підприємство "аварійна служба приморського району"',
#   'кп "ас приморського району"',
#   'в стані припинення'),
#  'одеська міська рада': (),
#  '39994485': ('товариство з обмеженою відповідальністю "управляюча компанія "відродження"',
#   'тов "управляюча компанія "відродження"',
#   'зареєстровано'),
#  'сиріцький олександр генрієвич': (),
#  'молодцов віктор васильович': (),
#  '41179613': ('благодійна організація "світовий релігійний благодійний фонд підтримки та вшанування пам\'яті сповідників рунвіри (українців-оріярусів) "дажбог і рідні пророки"',
#   'бо "фонд підтримки та вшанування пам\'яті українців-оріярусів "дажбог і рідні пророки"',
#   'зареєстровано'),
#  '05708086': ('колективне підприємство дніпропетровській науково-виробничий центр "трубосталь"',
#   'кп днвц "трубосталь"',
#   'припинено'),
#  '22805036': ('приватне  аграрно-виробниче  підприємство  "гетьман"',
#   'немає',
#   'зареєстровано'),
#  '22016987': ('садівницьке товариство "надія"', 'ст "надія"', 'зареєстровано'),
#  '26189940': ('громадська організація "всеукраїнське громадське об\'єднання оріярусів україни"',
#   'го "вгоору"',
#   'зареєстровано'),
#  'корнелюк анатолій павлович': (),
#  'буняк семен якович': (),
#  'терновий іван іванович': (),
#  'осінчук остап мирославович': (),
#  '24148842': ('"доран"', 'мкп"доран"', 'припинено'),
#  '41143058': ('громадське формування з охорони громадського порядку і державного кордону "акс-2"',
#   'гф "акс-2"',
#   'зареєстровано'),
#  'драч олег станіславович': (),
#  '05905964': ('акціонерне товариство "кіровоградське видавництво" корпоративне підприємство ат "дак "укрвидавполіграфія"',
#   'ат "кіровоградське видавництво"',
#   'зареєстровано'),
#  '42676701': ('товариство з обмеженою відповідальністю "сила карпат"',
#   'тов "сила карпат"',
#   'зареєстровано'),
#  'мартинчук роман михайлович': (),
#  'зайдуліна вікторія миколаївна': (),
#  '34031398': ('фермерське господарство "караліна"',
#   'фг"караліна"',
#   'зареєстровано'),
#  'дорошенко світлана володимирівна': (),
#  'дорошенко кароліна анатоліївна': (),
#  '34997979': ('приватне підприємство "комес-ч-2007"',
#   'пп "комес-ч-2004"',
#   'припинено'),
#  '41793436': ('товариство з обмеженою відповідальністю "адамат лтд"',
#   'тов "адамат лтд"',
#   'зареєстровано'),
#  'беркуненко євген юрійович': (),
#  'попович юлія миколаївна': (),
#  'ткачов леонід юрійович': (),
#  'захаренко леся юріївна': (),
#  'терлецький олександр валерійович': (),
#  'логінов руслан миколайович': (),
#  'одинокий микола іванович': (),
#  '42988439': ('товариство з обмеженою відповідальністю "таймс сістем"',
#   'тов "таймс сістем"',
#   'зареєстровано'),
#  'дробот віктор васильович': (),
#  'деревецький юрій леонідович': (),
#  '38711488': ('обслуговуючий кооператив "голівуд"',
#   'ок "голівуд"',
#   'зареєстровано'),
#  'євчук руслан федорович': (),
#  'шолотюк василь анатолійович': (),
#  '40219288': ('обслуговуючий кооператив "козацький."',
#   'ок "козацький."',
#   'зареєстровано'),
#  'бойчук ольга володимирівна': (),
#  'данилець роман миколайович': (),
#  'бойчук костянтин андрійович': (),
#  'мартинчук роман романович': (),
#  'бойчук кольга володимирівна': (),
#  'данилець юрій миколайович': (),
#  '39422207': ('товариство з обмеженою відповідальністю "юніфуд трейдинг"',
#   'тзов "юніфуд трейдинг"',
#   'зареєстровано'),
#  'джеймс джиліан терезія': (),
#  'зубко роман святославович': (),
#  'романюк тетяна володимирівна': (),
#  'корсак роман вікторович': (),
#  '33890483': ('товариство з обмеженою відповідальністю "укргоргаз"',
#   'тов "укргоргаз"',
#   'зареєстровано'),
#  '42289472': ('товариство з обмеженою відповідальністю "навігейт"',
#   'тов "навігейт"',
#   'зареєстровано'),
#  'кірчев петро іванович': (),
#  'мішенкова катерина валеріївна': (),
#  'цибенко ірина яківна': (),
#  'синюк вікторія юріївна': (),
#  'курінський максим васильович': (),
#  'габерстро тетяна василівна': (),
#  'томкевич владислав юрійович': (),
#  'чернишенко євген сергійович': (),
#  'кригін андрій сергійович': (),
#  'мушенко владислав володимирович': (),
#  'карпій ія олександрівна': ()}

# %%
dict_firm # словник для визначення ЄДРПОУ фірми за її назвою (сподіваюсь, дублів за повними назвами фірм немає)
# Out:
# {'товариство з обмеженою відповідальністю "комплекс інвестмент менеджмент"': '35696771',
#  'товариство з обмеженою відповідальністю "інджи"': '37761449',
#  'приватне підприємство "щедрий сад."': '38663859',
#  'фермерське господарство "соколенки"': '38141129',
#  'товариство з обмеженою відповідальністю "фірма "сезон лтд."': '21503248',
#  'мале підприємство у вигляді товариства з обмеженою відповідальністю фірма "сокол" лтд': '13904523',
#  'товариство з обмеженою відповідальністю "камидана"': '40581613',
#  'товариство з обмеженою відповідальністю "сервіс уют"': '39189177',
#  'товариство з обмеженою відповідальністю "домера"': '39119103',
#  'товариство з обмеженою відповідальністю "южспецмонтаж донбас"': '33852359',
#  'товариство з обмеженою відповідальністю "южспецмонтаж"': '30542625',
#  'дочірнє підприємство "юсм-уют"': '33138719',
#  'товариство з обмеженою відповідальністю "стройбілдінг"': '39324857',
#  'товариство з обмеженою відповідальністю "коляда софт"': '42498353',
#  'товариство з обмеженою відповідальністю "комфорт буд одеса"': '41398320',
#  'акціонерне товариство "південсільспецмонтаж" закритого типу': '05392335',
#  'товариство з обмеженою відповідальністю "навігейт україна"': '39009435',
#  'мале підприємство - товариство з обмеженою відповідальністю "онікс - лтд"': '19198523',
#  'громадська організація "організація інвалідів "новий крок"': '35930695',
#  'приватне підприємство "щедрий сад"': '32240582',
#  'виробничо - комерційна приватна фірма "тік"': '20631837',
#  'товариство з обмеженою відповідальністю виробниче підприємство "комплекс"': '20641014',
#  'приватне підприємство "міжнародний центр іноваційних технологій, інформації, підприємництва, бізнесу, організації праці та навчання"': '34845688',
#  'товариство з обмеженою відповідальністю "фірма "фрізон лтд."': '21503231',
#  'товариство з обмеженою відповідальністю "уют сервіс"': '37486625',
#  'товариство з обмеженою відповідальністю "уют-сервіс"': '37573403',
#  'товариство з обмеженою відповідальністю "еллада уют сервіс "': '42715530',
#  'товариство з обмеженою відповідальністю "житло уют сервіс"': '37893163',
#  'товариство з обмеженою відповідальністю "авіа техконтакт"': '39444367',
#  'товариство з обмеженою відповідальністю "торгбуд девелоп"': '40630906',
#  'товариство з обмеженою відповідальністю "виробничо-комерційна фірма "басско-2006"': '24055075',
#  'дочірнє підприємство "юсм-майстерня холоду"': '33138771',
#  'комунальний заклад "хоростківська  музична школа"': '05462751',
#  'товариство з обмеженою відповідальністю "дінерострой"': '40739476',
#  'приватне підприємство "теплокомплект"': '30662863',
#  'товариство з обмеженою відповідальністю "оліргруп"': '42980638',
#  'громадська організація "всеукраїнська асоціація "турбота про діабетика"': '41153155',
#  'товариство з обмеженою відповідальністю "дедал плюс"': '42824290',
#  'товариство з обмеженою відповідальністю "будинок культури фпо"': '40512178',
#  'приватне підприємство "будімпекс-плюс"': '36823184',
#  'закрите акціонерне товариство "газ"': '30128252',
#  'дочірнє підприємство "юсм-проект"': '33138745',
#  'приватне підприємство "лісове господарство курорту сергіївка"': '36860315',
#  'приватне підприємство "сергіївська фабрика продтоварів"': '36860336',
#  'приватне підприємство "ренесанс-7"': '32989552',
#  'товариство з обмеженою відповідальністю "швейна фабрика "діана"': '34712289',
#  'підприємство об\'єднання громадян "навчально-виробниче підприємство "промінь"': '39773456',
#  'громадська організація "центр розвитку курорту сергіївка"': '36508768',
#  'фермерське господарство "кристал"': '21114989',
#  'сільськогосподарське закрите акціонерне товариство "маяк"': '03779142',
#  'приватне підприємство "техметал"': '34754596',
#  'комунальне підприємство "аварійна служба приморського району"': '32642131',
#  'товариство з обмеженою відповідальністю "управляюча компанія "відродження"': '39994485',
#  'благодійна організація "світовий релігійний благодійний фонд підтримки та вшанування пам\'яті сповідників рунвіри (українців-оріярусів) "дажбог і рідні пророки"': '41179613',
#  'колективне підприємство дніпропетровській науково-виробничий центр "трубосталь"': '05708086',
#  'приватне  аграрно-виробниче  підприємство  "гетьман"': '22805036',
#  'садівницьке товариство "надія"': '22016987',
#  'громадська організація "всеукраїнське громадське об\'єднання оріярусів україни"': '26189940',
#  '"доран"': '24148842',
#  'громадське формування з охорони громадського порядку і державного кордону "акс-2"': '41143058',
#  'акціонерне товариство "кіровоградське видавництво" корпоративне підприємство ат "дак "укрвидавполіграфія"': '05905964',
#  'товариство з обмеженою відповідальністю "сила карпат"': '42676701',
#  'фермерське господарство "караліна"': '34031398',
#  'приватне підприємство "комес-ч-2007"': '34997979',
#  'товариство з обмеженою відповідальністю "адамат лтд"': '41793436',
#  'товариство з обмеженою відповідальністю "таймс сістем"': '42988439',
#  'обслуговуючий кооператив "голівуд"': '38711488',
#  'обслуговуючий кооператив "козацький."': '40219288',
#  'товариство з обмеженою відповідальністю "юніфуд трейдинг"': '39422207',
#  'товариство з обмеженою відповідальністю "укргоргаз"': '33890483',
#  'товариство з обмеженою відповідальністю "навігейт"': '42289472'}

# %%
list_type # (засновник, ЄДРПОУ заснованої фірми, частка участі засновника, чи є засновник бенефіціаром)
# Out:
# [['соколенко олександр іванович', '35696771', 0.34, 1],
#  ['рутовський дмитро олегович', '35696771', 0.33, 0],
#  ['ловчин лев юрійович', '35696771', 0.33, 0],
#  ['меламуд євген мойсейович', '37761449', 0.45, 0],
#  ['35696771', '37761449', 0.55, 0],
#  ['соколенко олександр іванович', '38663859', 1.0, 0],
#  ['соколенко олександр іванович', '38141129', 0, 0],
#  ['бернатович вадим миколайович', '21503248', 0.02, 0],
#  ['соколенко іван станіславович', '21503248', 0.04, 0],
#  ['ємельянова ольга олександрівна', '21503248', 0.9, 0],
#  ['соколенко олександр іванович', '21503248', 0.04, 0],
#  ['рутовський дмитро олегович', '40581613', 0.2792307142272753, 0],
#  ['рутовська світлана олександрівна', '40581613', 0.0837692142681826, 0],
#  ['товариство з обмеженою відповідальністю "южспецмонтаж"',
#   '40581613',
#   0.6370000715045421,
#   0],
#  ['рутовський дмитро олегович', '39189177', 1.0, 1],
#  ['товариство з обмеженою відповідальністю "южспецмонтаж"',
#   '39119103',
#   0.23026733809523808,
#   0],
#  ['рутовський дмитро олегович', '39119103', 0.6983040904761905, 1],
#  ['рутовський олег георгійович', '39119103', 0.03571428571428571, 1],
#  ['рутовська світлана олександрівна', '39119103', 0.03571428571428571, 1],
#  ['рутовський дмитро олегович', '30542625', 0.7692307692307693, 1],
#  ['рутовський олег георгійович', '30542625', 0.23076923076923078, 1],
#  ['30542625', '33138719', 1.0, 0],
#  ['рутовський олег георгійович', '33138719', 0, 1],
#  ['рутовський дмитро олегович', '33138719', 0, 1],
#  ['рутовський олег георгійович', '39324857', 0.16666666666666666, 1],
#  ['рутовський дмитро олегович', '39324857', 0.6666666666666666, 1],
#  ['жоров євген данилович', '39324857', 0.16666666666666666, 1],
#  ['рутовський дмитро олегович', '42498353', 0.165, 1],
#  ['40581613', '42498353', 0.5, 0],
#  ['гук вячеслав олександрович', '42498353', 0.17, 0],
#  ['супруненко валерій іванович', '42498353', 0.165, 0],
#  ['40581613', '41398320', 1.0, 0],
#  ['рутовська світлана олександрівна', '41398320', 0, 1],
#  ['рутовський дмитро олегович', '41398320', 0, 1],
#  ['рутовський дмитро олегович', '39009435', 0.2, 0],
#  ['плукчі петро гнатович', '39009435', 0.3333333333333333, 1],
#  ['нарольський андрій олегович', '39009435', 0.13333333333333333, 0],
#  ['саіпова наталія леонідівна', '39009435', 0.3333333333333333, 0],
#  ['меламуд євген мойсейович', '19198523', 0.5, 1],
#  ['зак вячеслав юхимович', '19198523', 0.5, 1],
#  ['стрельников андрій вікторович', '35930695', 0, 0],
#  ['шейко ольга вікторівна', '35930695', 0, 0],
#  ['кравченко валентин валерійович', '35930695', 0, 0],
#  ['шеремет олег петрович', '32240582', 1.0, 0],
#  ['соколенко сергій іванович', '20631837', 0, 1],
#  ['швачко геннадій євгенович', '20641014', 0.5, 0],
#  ['соколенко сергій іванович', '20641014', 0.5, 0],
#  ['руденко олег іванович', '34845688', 0.1, 0],
#  ['бондаренко василь павлович', '34845688', 0.7, 0],
#  ['соколенко сергій іванович', '34845688', 0.1, 0],
#  ['коваленко володимир григорович', '34845688', 0.1, 0],
#  ['майсак сергій григорович', '21503231', 0.16, 0],
#  ['майсак ігор григорович', '21503231', 0.14, 0],
#  ['соколенко іван станіславович', '21503231', 0.02, 0],
#  ['осетров валентин геннадійович', '21503231', 0.16, 0],
#  ['ємельянова ольга олександрівна', '21503231', 0.48, 0],
#  ['донченко євгеній васильович', '21503231', 0.04, 0],
#  ['олійник олег володимирович', '37486625', 1.0, 0],
#  ['ткачук валентина петрівна', '37573403', 1.0, 0],
#  ['ткачук валентина павлівна', '37573403', 0, 1],
#  ["херсоненко олена в'ячеславівна", '42715530', 1.0, 1],
#  ['товариство з обмеженою відповідальністю міжрегіональний торгово-діловий комплекс "будівельне місто"',
#   '37893163',
#   0.3333333333333333,
#   0],
#  ['приватне підприємство "делавер"', '37893163', 0.3333333333333333, 0],
#  ['приватне підприємство "альянс новобуд"', '37893163', 0.3333333333333333, 0],
#  ['богуш анна вікторівна', '37893163', 0, 1],
#  ['фруктов сергій сергійович', '37893163', 0, 1],
#  ['караванський сергій георгійович', '37893163', 0, 1],
#  ['крилов антон сергійович', '39444367', 0.003205128205128205, 1],
#  ['тітаренко євген анатолійович', '39444367', 0.9935897435897436, 0],
#  ['корольов сергій петрович', '39444367', 0.003205128205128205, 1],
#  ['товариство з обмеженою відповідальністю "лекс консалт сервіс"',
#   '40630906',
#   0.0009090909090909091,
#   0],
#  ['товариство з обмеженою відповідальністю "бізнес консалт сервіс"',
#   '40630906',
#   0.09,
#   0],
#  ['андрієнко сергій миколайович', '40630906', 0.9090909090909091, 0],
#  ['збризький максим сергійович', '40630906', 0, 1],
#  ['рутовський дмитро георгійович', '24055075', 0.5, 0],
#  ['рутовський олег георгійович', '24055075', 0.5, 0],
#  ['30542625', '33138771', 1.0, 0],
#  ['хоростківська міська рада', '05462751', 0, 0],
#  ['галак оксана василівна', '40739476', 0.5, 0],
#  ['подосян аркадій мелітосович', '40739476', 0.5, 0],
#  ['анісіфоров володимир львович', '30662863', 1.0, 0],
#  ['малюта ірина михайлівна', '42980638', 1.0, 0],
#  ['сергеєва ірина борисівна', '41153155', 0, 0],
#  ['малюта ірина михайлівна', '41153155', 0, 0],
#  ['малюта ірина михайлівна', '42824290', 1.0, 0],
#  ['приходько тетяна василівна', '40512178', 0.6666666666666666, 0],
#  ['малюта ірина михайлівна', '40512178', 0.3333333333333333, 0],
#  ['прохоренко олена євгенівна', '36823184', 0.5, 0],
#  ['матвієць маргарита олександрівна', '36823184', 0.5, 0],
#  ['тютіна людмила григорівна', '36823184', 0, 1],
#  ['діденко марія миколаївна', '36823184', 0, 1],
#  ['малюта ірина михайлівна', '36823184', 0, 1],
#  ['ярмоленко валентина миколаївна', '36823184', 0, 1],
#  ['товариство з обмеженою відповідальністю "южспецмонтраж"',
#   '33138745',
#   1.0,
#   0],
#  ['супруненко валерій іванович', '36860315', 1.0, 1],
#  ['супруненко валерій іванович', '36860336', 1.0, 1],
#  ['супруненко валерій іванович', '32989552', 1.0, 1],
#  ['32989552', '34712289', 0.5, 0],
#  ['шевченко олег петрович', '34712289', 0.5, 1],
#  ['супруненко валерій іванович', '34712289', 0, 1],
#  ['громадська організація "союз захисту інвалідів"', '39773456', 1.0, 0],
#  ['андронатій майя семенівна', '36508768', 0, 0],
#  ['нестерюк павліна валентинівна', '36508768', 0, 0],
#  ['супруненко діана анатоліївна', '36508768', 0, 0],
#  ['супруненко валерій іванович', '36508768', 0, 0],
#  ['лучанінов володимир васильович', '21114989', 0.7, 1],
#  ['калач марина володимирівна', '21114989', 0.15, 0],
#  ['лучанінова ірина анатоліївна', '21114989', 0.15, 0],
#  ['одеська міська рада', '32642131', 1.0, 0],
#  ['молодцов віктор васильович', '39994485', 0.5, 0],
#  ['товариство з обмеженою відповідальністю "ренесанс-92"', '39994485', 0.5, 0],
#  ['сиріцький олександр генрієвич', '39994485', 0, 1],
#  ['дорошенко анатолій іванович', '41179613', 0, 0],
#  ['дорошенко анатолій іванович', '22805036', 1.0, 0],
#  ['дорошенко анатолій іванович', '26189940', 0, 0],
#  ['терновий іван іванович', '26189940', 0, 0],
#  ['буняк семен якович', '26189940', 0, 0],
#  ['акціонер- державна акціонерна компанія "українське видавничо-поліграфічне об\'єднання"',
#   '05905964',
#   0.3333333333333333,
#   0],
#  ['акціонерне товариство "державна акціонерна компанія "українське видавничо-поліграфічне об\'єднання"',
#   '05905964',
#   0.3333333333333333,
#   0],
#  ['публічне акціонерне товариство "державна акціонерна компанія "українське видавничо-поліграфічне об\'єднання"',
#   '05905964',
#   0.3333333333333333,
#   0],
#  ['дорошенко анатолій іванович', '42676701', 0.333, 0],
#  ['макаревич-зайдуліна вікторія миколаївна', '42676701', 0.333, 0],
#  ['мартинчук роман михайлович', '42676701', 0.334, 0],
#  ['зайдуліна вікторія миколаївна', '42676701', 0, 0],
#  ['дорошенко світлана володимирівна', '34031398', 0.5, 1],
#  ['дорошенко кароліна анатоліївна', '34031398', 0.5, 1],
#  ['дорошенко анатолій іванович', '34031398', 0, 1],
#  ['дорошенко анатолій іванович', '41793436', 0.1272931486334706, 1],
#  ['беркуненко євген юрійович', '41793436', 0.3743916136278547, 0],
#  ['одинокий микола іванович', '41793436', 0.12354923249719206, 0],
#  ['попович юлія миколаївна', '41793436', 0.3743916136278547, 1],
#  ['товариство з обмеженою відповідальністю "енердж сістем"',
#   '41793436',
#   0.00018719580681392738,
#   0],
#  ['товариство з обмеженою відповідальністю "томрест"',
#   '41793436',
#   0.00018719580681392738,
#   0],
#  ['терлецький олександр валерійович', '41793436', 0, 1],
#  ['захаренко леся юріївна', '41793436', 0, 1],
#  ['дробот віктор васильович', '42988439', 0.47619047619047616, 1],
#  ['товариство з обмеженою відповідальністю "енердж сістем"',
#   '42988439',
#   0.047619047619047616,
#   0],
#  ['дорошенко анатолій іванович', '42988439', 0.47619047619047616, 0],
#  ['терлецький олександр валерійович', '42988439', 0, 1],
#  ['дорошенко анатолій іванович', '38711488', 0, 0],
#  ['євчук руслан федорович', '38711488', 0, 0],
#  ['шолотюк василь анатолійович', '38711488', 0, 0],
#  ['дорошенко анатолій іванович', '40219288', 0, 1],
#  ['бойчук костянтин андрійович', '40219288', 0, 1],
#  ['бойчук кольга володимирівна', '40219288', 0, 1],
#  ['мартинчук роман романович', '40219288', 0, 0],
#  ['бойчук ольга володимирівна', '40219288', 0, 0],
#  ['данилець роман миколайович', '40219288', 0, 0],
#  ['данилець юрій миколайович', '40219288', 0, 0],
#  ['приватне акціонерне товариство "компанія з управління активами "карпати-інвест"',
#   '39422207',
#   0.05263157894736842,
#   0],
#  ['корсак роман вікторович', '39422207', 0.47368421052631576, 0],
#  ['грегсон груп лтд', '39422207', 0.47368421052631576, 0],
#  ['джеймс джиліан терезія', '39422207', 0, 1],
#  ['плукчі петро гнатович', '33890483', 1.0, 0],
#  ['курінський максим васильович', '42289472', 0.2, 0],
#  ['кригін андрій сергійович', '42289472', 0.06, 0],
#  ['чернишенко євген сергійович', '42289472', 0.196, 0],
#  ['мішенкова катерина валеріївна', '42289472', 0.04, 0],
#  ['цибенко ірина яківна', '42289472', 0.06, 0],
#  ['габерстро тетяна василівна', '42289472', 0.06, 0],
#  ['томкевич владислав юрійович', '42289472', 0.06, 0],
#  ['синюк вікторія юріївна', '42289472', 0.06, 0],
#  ['карпій ія олександрівна', '42289472', 0.06, 0],
#  ['мушенко владислав володимирович', '42289472', 0.204, 0]]

# %% [markdown]
# Якщо ЄДРПОУ по якихось фірмах не підтягнулося відразу, то заміняємо зараз назву фірми на ЄДРПОУ (заміняється не завжди):

# %%
# %%time
list_type_new = list_type.copy()
for i in range(len(list_type_new)):
    if list_type_new[i][0] in list(dict_firm):
        list_type_new[i][0] = dict_firm[list_type_new[i][0]]
list_type_new
# Out:
# CPU times: user 1.11 ms, sys: 95 µs, total: 1.2 ms
# Wall time: 1.22 ms
# [['соколенко олександр іванович', '35696771', 0.34, 1],
#  ['рутовський дмитро олегович', '35696771', 0.33, 0],
#  ['ловчин лев юрійович', '35696771', 0.33, 0],
#  ['меламуд євген мойсейович', '37761449', 0.45, 0],
#  ['35696771', '37761449', 0.55, 0],
#  ['соколенко олександр іванович', '38663859', 1.0, 0],
#  ['соколенко олександр іванович', '38141129', 0, 0],
#  ['бернатович вадим миколайович', '21503248', 0.02, 0],
#  ['соколенко іван станіславович', '21503248', 0.04, 0],
#  ['ємельянова ольга олександрівна', '21503248', 0.9, 0],
#  ['соколенко олександр іванович', '21503248', 0.04, 0],
#  ['рутовський дмитро олегович', '40581613', 0.2792307142272753, 0],
#  ['рутовська світлана олександрівна', '40581613', 0.0837692142681826, 0],
#  ['30542625', '40581613', 0.6370000715045421, 0],
#  ['рутовський дмитро олегович', '39189177', 1.0, 1],
#  ['30542625', '39119103', 0.23026733809523808, 0],
#  ['рутовський дмитро олегович', '39119103', 0.6983040904761905, 1],
#  ['рутовський олег георгійович', '39119103', 0.03571428571428571, 1],
#  ['рутовська світлана олександрівна', '39119103', 0.03571428571428571, 1],
#  ['рутовський дмитро олегович', '30542625', 0.7692307692307693, 1],
#  ['рутовський олег георгійович', '30542625', 0.23076923076923078, 1],
#  ['30542625', '33138719', 1.0, 0],
#  ['рутовський олег георгійович', '33138719', 0, 1],
#  ['рутовський дмитро олегович', '33138719', 0, 1],
#  ['рутовський олег георгійович', '39324857', 0.16666666666666666, 1],
#  ['рутовський дмитро олегович', '39324857', 0.6666666666666666, 1],
#  ['жоров євген данилович', '39324857', 0.16666666666666666, 1],
#  ['рутовський дмитро олегович', '42498353', 0.165, 1],
#  ['40581613', '42498353', 0.5, 0],
#  ['гук вячеслав олександрович', '42498353', 0.17, 0],
#  ['супруненко валерій іванович', '42498353', 0.165, 0],
#  ['40581613', '41398320', 1.0, 0],
#  ['рутовська світлана олександрівна', '41398320', 0, 1],
#  ['рутовський дмитро олегович', '41398320', 0, 1],
#  ['рутовський дмитро олегович', '39009435', 0.2, 0],
#  ['плукчі петро гнатович', '39009435', 0.3333333333333333, 1],
#  ['нарольський андрій олегович', '39009435', 0.13333333333333333, 0],
#  ['саіпова наталія леонідівна', '39009435', 0.3333333333333333, 0],
#  ['меламуд євген мойсейович', '19198523', 0.5, 1],
#  ['зак вячеслав юхимович', '19198523', 0.5, 1],
#  ['стрельников андрій вікторович', '35930695', 0, 0],
#  ['шейко ольга вікторівна', '35930695', 0, 0],
#  ['кравченко валентин валерійович', '35930695', 0, 0],
#  ['шеремет олег петрович', '32240582', 1.0, 0],
#  ['соколенко сергій іванович', '20631837', 0, 1],
#  ['швачко геннадій євгенович', '20641014', 0.5, 0],
#  ['соколенко сергій іванович', '20641014', 0.5, 0],
#  ['руденко олег іванович', '34845688', 0.1, 0],
#  ['бондаренко василь павлович', '34845688', 0.7, 0],
#  ['соколенко сергій іванович', '34845688', 0.1, 0],
#  ['коваленко володимир григорович', '34845688', 0.1, 0],
#  ['майсак сергій григорович', '21503231', 0.16, 0],
#  ['майсак ігор григорович', '21503231', 0.14, 0],
#  ['соколенко іван станіславович', '21503231', 0.02, 0],
#  ['осетров валентин геннадійович', '21503231', 0.16, 0],
#  ['ємельянова ольга олександрівна', '21503231', 0.48, 0],
#  ['донченко євгеній васильович', '21503231', 0.04, 0],
#  ['олійник олег володимирович', '37486625', 1.0, 0],
#  ['ткачук валентина петрівна', '37573403', 1.0, 0],
#  ['ткачук валентина павлівна', '37573403', 0, 1],
#  ["херсоненко олена в'ячеславівна", '42715530', 1.0, 1],
#  ['товариство з обмеженою відповідальністю міжрегіональний торгово-діловий комплекс "будівельне місто"',
#   '37893163',
#   0.3333333333333333,
#   0],
#  ['приватне підприємство "делавер"', '37893163', 0.3333333333333333, 0],
#  ['приватне підприємство "альянс новобуд"', '37893163', 0.3333333333333333, 0],
#  ['богуш анна вікторівна', '37893163', 0, 1],
#  ['фруктов сергій сергійович', '37893163', 0, 1],
#  ['караванський сергій георгійович', '37893163', 0, 1],
#  ['крилов антон сергійович', '39444367', 0.003205128205128205, 1],
#  ['тітаренко євген анатолійович', '39444367', 0.9935897435897436, 0],
#  ['корольов сергій петрович', '39444367', 0.003205128205128205, 1],
#  ['товариство з обмеженою відповідальністю "лекс консалт сервіс"',
#   '40630906',
#   0.0009090909090909091,
#   0],
#  ['товариство з обмеженою відповідальністю "бізнес консалт сервіс"',
#   '40630906',
#   0.09,
#   0],
#  ['андрієнко сергій миколайович', '40630906', 0.9090909090909091, 0],
#  ['збризький максим сергійович', '40630906', 0, 1],
#  ['рутовський дмитро георгійович', '24055075', 0.5, 0],
#  ['рутовський олег георгійович', '24055075', 0.5, 0],
#  ['30542625', '33138771', 1.0, 0],
#  ['хоростківська міська рада', '05462751', 0, 0],
#  ['галак оксана василівна', '40739476', 0.5, 0],
#  ['подосян аркадій мелітосович', '40739476', 0.5, 0],
#  ['анісіфоров володимир львович', '30662863', 1.0, 0],
#  ['малюта ірина михайлівна', '42980638', 1.0, 0],
#  ['сергеєва ірина борисівна', '41153155', 0, 0],
#  ['малюта ірина михайлівна', '41153155', 0, 0],
#  ['малюта ірина михайлівна', '42824290', 1.0, 0],
#  ['приходько тетяна василівна', '40512178', 0.6666666666666666, 0],
#  ['малюта ірина михайлівна', '40512178', 0.3333333333333333, 0],
#  ['прохоренко олена євгенівна', '36823184', 0.5, 0],
#  ['матвієць маргарита олександрівна', '36823184', 0.5, 0],
#  ['тютіна людмила григорівна', '36823184', 0, 1],
#  ['діденко марія миколаївна', '36823184', 0, 1],
#  ['малюта ірина михайлівна', '36823184', 0, 1],
#  ['ярмоленко валентина миколаївна', '36823184', 0, 1],
#  ['товариство з обмеженою відповідальністю "южспецмонтраж"',
#   '33138745',
#   1.0,
#   0],
#  ['супруненко валерій іванович', '36860315', 1.0, 1],
#  ['супруненко валерій іванович', '36860336', 1.0, 1],
#  ['супруненко валерій іванович', '32989552', 1.0, 1],
#  ['32989552', '34712289', 0.5, 0],
#  ['шевченко олег петрович', '34712289', 0.5, 1],
#  ['супруненко валерій іванович', '34712289', 0, 1],
#  ['громадська організація "союз захисту інвалідів"', '39773456', 1.0, 0],
#  ['андронатій майя семенівна', '36508768', 0, 0],
#  ['нестерюк павліна валентинівна', '36508768', 0, 0],
#  ['супруненко діана анатоліївна', '36508768', 0, 0],
#  ['супруненко валерій іванович', '36508768', 0, 0],
#  ['лучанінов володимир васильович', '21114989', 0.7, 1],
#  ['калач марина володимирівна', '21114989', 0.15, 0],
#  ['лучанінова ірина анатоліївна', '21114989', 0.15, 0],
#  ['одеська міська рада', '32642131', 1.0, 0],
#  ['молодцов віктор васильович', '39994485', 0.5, 0],
#  ['товариство з обмеженою відповідальністю "ренесанс-92"', '39994485', 0.5, 0],
#  ['сиріцький олександр генрієвич', '39994485', 0, 1],
#  ['дорошенко анатолій іванович', '41179613', 0, 0],
#  ['дорошенко анатолій іванович', '22805036', 1.0, 0],
#  ['дорошенко анатолій іванович', '26189940', 0, 0],
#  ['терновий іван іванович', '26189940', 0, 0],
#  ['буняк семен якович', '26189940', 0, 0],
#  ['акціонер- державна акціонерна компанія "українське видавничо-поліграфічне об\'єднання"',
#   '05905964',
#   0.3333333333333333,
#   0],
#  ['акціонерне товариство "державна акціонерна компанія "українське видавничо-поліграфічне об\'єднання"',
#   '05905964',
#   0.3333333333333333,
#   0],
#  ['публічне акціонерне товариство "державна акціонерна компанія "українське видавничо-поліграфічне об\'єднання"',
#   '05905964',
#   0.3333333333333333,
#   0],
#  ['дорошенко анатолій іванович', '42676701', 0.333, 0],
#  ['макаревич-зайдуліна вікторія миколаївна', '42676701', 0.333, 0],
#  ['мартинчук роман михайлович', '42676701', 0.334, 0],
#  ['зайдуліна вікторія миколаївна', '42676701', 0, 0],
#  ['дорошенко світлана володимирівна', '34031398', 0.5, 1],
#  ['дорошенко кароліна анатоліївна', '34031398', 0.5, 1],
#  ['дорошенко анатолій іванович', '34031398', 0, 1],
#  ['дорошенко анатолій іванович', '41793436', 0.1272931486334706, 1],
#  ['беркуненко євген юрійович', '41793436', 0.3743916136278547, 0],
#  ['одинокий микола іванович', '41793436', 0.12354923249719206, 0],
#  ['попович юлія миколаївна', '41793436', 0.3743916136278547, 1],
#  ['товариство з обмеженою відповідальністю "енердж сістем"',
#   '41793436',
#   0.00018719580681392738,
#   0],
#  ['товариство з обмеженою відповідальністю "томрест"',
#   '41793436',
#   0.00018719580681392738,
#   0],
#  ['терлецький олександр валерійович', '41793436', 0, 1],
#  ['захаренко леся юріївна', '41793436', 0, 1],
#  ['дробот віктор васильович', '42988439', 0.47619047619047616, 1],
#  ['товариство з обмеженою відповідальністю "енердж сістем"',
#   '42988439',
#   0.047619047619047616,
#   0],
#  ['дорошенко анатолій іванович', '42988439', 0.47619047619047616, 0],
#  ['терлецький олександр валерійович', '42988439', 0, 1],
#  ['дорошенко анатолій іванович', '38711488', 0, 0],
#  ['євчук руслан федорович', '38711488', 0, 0],
#  ['шолотюк василь анатолійович', '38711488', 0, 0],
#  ['дорошенко анатолій іванович', '40219288', 0, 1],
#  ['бойчук костянтин андрійович', '40219288', 0, 1],
#  ['бойчук кольга володимирівна', '40219288', 0, 1],
#  ['мартинчук роман романович', '40219288', 0, 0],
#  ['бойчук ольга володимирівна', '40219288', 0, 0],
#  ['данилець роман миколайович', '40219288', 0, 0],
#  ['данилець юрій миколайович', '40219288', 0, 0],
#  ['приватне акціонерне товариство "компанія з управління активами "карпати-інвест"',
#   '39422207',
#   0.05263157894736842,
#   0],
#  ['корсак роман вікторович', '39422207', 0.47368421052631576, 0],
#  ['грегсон груп лтд', '39422207', 0.47368421052631576, 0],
#  ['джеймс джиліан терезія', '39422207', 0, 1],
#  ['плукчі петро гнатович', '33890483', 1.0, 0],
#  ['курінський максим васильович', '42289472', 0.2, 0],
#  ['кригін андрій сергійович', '42289472', 0.06, 0],
#  ['чернишенко євген сергійович', '42289472', 0.196, 0],
#  ['мішенкова катерина валеріївна', '42289472', 0.04, 0],
#  ['цибенко ірина яківна', '42289472', 0.06, 0],
#  ['габерстро тетяна василівна', '42289472', 0.06, 0],
#  ['томкевич владислав юрійович', '42289472', 0.06, 0],
#  ['синюк вікторія юріївна', '42289472', 0.06, 0],
#  ['карпій ія олександрівна', '42289472', 0.06, 0],
#  ['мушенко владислав володимирович', '42289472', 0.204, 0]]

# %%
list_head # (голова, ЄДРПОУ фірми)
# Out:
# [['соколенко олександр іванович', '35696771'],
#  ['кравченко валентин валерійович', '37761449'],
#  ['соколенко олександр іванович', '38663859'],
#  ['соколенко сергій іванович', '38141129'],
#  ['соколенко іван станіславович', '21503248'],
#  ['рутовський дмитро олегович', '40581613'],
#  ['корольов сергій петрович', '39189177'],
#  ['рутовський дмитро олегович', '39119103'],
#  ['анісіфоров володимир львович', '30542625'],
#  ['корольов петро васильович', '30542625'],
#  ['галак оксана василівна', '30542625'],
#  ['малюта ірина михайлівна', '30542625'],
#  ['саіпова наталія леонідівна', '33138719'],
#  ['жоров євген данилович', '39324857'],
#  ['тростянецький володимир васильович', '42498353'],
#  ['гук вячеслав олександрович', '42498353'],
#  ['діланян самвел авакович', '41398320'],
#  ['дорошенко анатолій іванович', '41398320'],
#  ['тростянецький володимир васильович', '41398320'],
#  ['анісіфоров володимир львович', '39009435'],
#  ['корольов петро васильович', '39009435'],
#  ['нарольський андрій олегович', '39009435'],
#  ['меламуд євген мойсейович', '19198523'],
#  ['стрельников андрій вікторович', '35930695'],
#  ['шеремет олег петрович', '32240582'],
#  ['соколенко іван сергійович', '20631837'],
#  ['соколенко сергій іванович', '20631837'],
#  ['швачко геннадій євгенович', '20641014'],
#  ['бондаренко василь павлович', '34845688'],
#  ['соколенко іван станіславович', '21503231'],
#  ['олійник олег володимирович', '37486625'],
#  ['ткачук валентина петрівна', '37573403'],
#  ["херсоненко олена в'ячеславівна", '42715530'],
#  ['голубовський олександр павлович', '37893163'],
#  ['корольов сергій петрович', '39444367'],
#  ['крилов антон сергійович', '39444367'],
#  ['корольова тетяна едуардівна', '39444367'],
#  ['старшова наталія вікторівна', '39444367'],
#  ['євдокімова олена миколаївна', '39444367'],
#  ['корольов сергій петрович', '40630906'],
#  ['андрієнко сергій миколайович', '40630906'],
#  ['євсєєв антон ігорович', '40630906'],
#  ['шевчук віра петрівна', '24055075'],
#  ['романов анатолій олексійович', '33138771'],
#  ['барановський микола васильович', '05462751'],
#  ['галак оксана василівна', '05462751'],
#  ['плукчі петро гнатович', '40739476'],
#  ['кузьменко микита володимирович', '40739476'],
#  ["погасов в'ячеслав сергійович", '30662863'],
#  ['малюта ірина михайлівна', '42980638'],
#  ['малюта ірина михайлівна', '41153155'],
#  ['сидорченко ірина василівна', '42824290'],
#  ['чіжов юрій вікторович', '40512178'],
#  ['малюта вікторія сергіївна', '40512178'],
#  ['матвієць маргарита олександрівна', '36823184'],
#  ['шаховнін артем олегович', '36823184'],
#  ['прохоренко олександр геннадійович', '36823184'],
#  ['жоров євген данилович', '33138745'],
#  ['супруненко валерій іванович', '36860315'],
#  ['супруненко валерій іванович', '36860336'],
#  ['супруненко валерій іванович', '32989552'],
#  ['супруненко валерій іванович', '34712289'],
#  ['супруненко валерій іванович', '39773456'],
#  ['супруненко діана анатоліївна', '36508768'],
#  ['лучанінов володимир васильович', '21114989'],
#  ['діланян самвел авакович', '32642131'],
#  ['діланян самвел авакович', '39994485'],
#  ['дорошенко анатолій іванович', '41179613'],
#  ['дорошенко анатолій іванович', '22805036'],
#  ['дорошенко анатолій іванович', '22016987'],
#  ['дорошенко анатолій іванович', '26189940'],
#  ['осінчук остап мирославович', '26189940'],
#  ['корнелюк анатолій павлович', '26189940'],
#  ['драч олег станіславович', '41143058'],
#  ['дорошенко анатолій іванович', '41143058'],
#  ['дорошенко анатолій іванович', '05905964'],
#  ['мартинчук роман михайлович', '42676701'],
#  ['дорошенко анатолій іванович', '34031398'],
#  ['дорошенко світлана володимирівна', '34031398'],
#  ['дорошенко анатолій іванович', '41793436'],
#  ['попович юлія миколаївна', '41793436'],
#  ['ткачов леонід юрійович', '41793436'],
#  ['логінов руслан миколайович', '41793436'],
#  ['одинокий микола іванович', '41793436'],
#  ['дорошенко анатолій іванович', '42988439'],
#  ['дробот віктор васильович', '42988439'],
#  ['деревецький юрій леонідович', '42988439'],
#  ['євчук руслан федорович', '38711488'],
#  ['данилець юрій миколайович', '40219288'],
#  ['дорошенко анатолій іванович', '39422207'],
#  ['зубко роман святославович', '39422207'],
#  ['романюк тетяна володимирівна', '39422207'],
#  ['плукчі петро гнатович', '33890483'],
#  ['кірчев петро іванович', '42289472'],
#  ['чернишенко євген сергійович', '42289472'],
#  ['нарольський андрій олегович', '42289472']]

# %%
list_temp # список контрагентів, за якими здійснювався пошук на останньому рівні
# Out:
# ['товариство з обмеженою відповідальністю "інджи"',
#  'меламуд євген мойсейович',
#  'кравченко валентин валерійович',
#  'приватне підприємство "щедрий сад."',
#  'фермерське господарство "соколенки"',
#  'соколенко сергій іванович',
#  'товариство з обмеженою відповідальністю "фірма "сезон лтд."',
#  'бернатович вадим миколайович',
#  'ємельянова ольга олександрівна',
#  'соколенко іван станіславович',
#  'товариство з обмеженою відповідальністю "камидана"',
#  'рутовська світлана олександрівна',
#  'товариство з обмеженою відповідальністю "сервіс уют"',
#  'корольов сергій петрович',
#  'товариство з обмеженою відповідальністю "домера"',
#  'рутовський олег георгійович',
#  'товариство з обмеженою відповідальністю "южспецмонтаж"',
#  'галак оксана василівна',
#  'анісіфоров володимир львович',
#  'малюта ірина михайлівна',
#  'корольов петро васильович',
#  'дочірнє підприємство "юсм-уют"',
#  'саіпова наталія леонідівна',
#  'товариство з обмеженою відповідальністю "стройбілдінг"',
#  'жоров євген данилович',
#  'товариство з обмеженою відповідальністю "коляда софт"',
#  'супруненко валерій іванович',
#  'тростянецький володимир васильович',
#  'гук вячеслав олександрович',
#  'товариство з обмеженою відповідальністю "комфорт буд одеса"',
#  'діланян самвел авакович',
#  'дорошенко анатолій іванович',
#  'товариство з обмеженою відповідальністю "навігейт україна"',
#  'плукчі петро гнатович',
#  'нарольський андрій олегович']

# %%
list_next # список контрагентів для пошуку на наступному рівні (непорожній, якщо було задано максимальний рівень)
# Out:
# ['мале підприємство - товариство з обмеженою відповідальністю "онікс - лтд"',
#  'зак вячеслав юхимович',
#  'громадська організація "організація інвалідів "новий крок"',
#  'стрельников андрій вікторович',
#  'шейко ольга вікторівна',
#  'приватне підприємство "щедрий сад"',
#  'шеремет олег петрович',
#  'виробничо - комерційна приватна фірма "тік"',
#  'соколенко іван сергійович',
#  'товариство з обмеженою відповідальністю виробниче підприємство "комплекс"',
#  'швачко геннадій євгенович',
#  'приватне підприємство "міжнародний центр іноваційних технологій, інформації, підприємництва, бізнесу, організації праці та навчання"',
#  'коваленко володимир григорович',
#  'руденко олег іванович',
#  'бондаренко василь павлович',
#  'товариство з обмеженою відповідальністю "фірма "фрізон лтд."',
#  'майсак сергій григорович',
#  'осетров валентин геннадійович',
#  'донченко євгеній васильович',
#  'майсак ігор григорович',
#  'товариство з обмеженою відповідальністю "уют сервіс"',
#  'олійник олег володимирович',
#  'товариство з обмеженою відповідальністю "уют-сервіс"',
#  'ткачук валентина павлівна',
#  'ткачук валентина петрівна',
#  'товариство з обмеженою відповідальністю "еллада уют сервіс "',
#  "херсоненко олена в'ячеславівна",
#  'товариство з обмеженою відповідальністю "житло уют сервіс"',
#  'голубовський олександр павлович',
#  'фруктов сергій сергійович',
#  'богуш анна вікторівна',
#  'караванський сергій георгійович',
#  'товариство з обмеженою відповідальністю "авіа техконтакт"',
#  'крилов антон сергійович',
#  'тітаренко євген анатолійович',
#  'корольова тетяна едуардівна',
#  'старшова наталія вікторівна',
#  'євдокімова олена миколаївна',
#  'товариство з обмеженою відповідальністю "торгбуд девелоп"',
#  'андрієнко сергій миколайович',
#  'збризький максим сергійович',
#  'євсєєв антон ігорович',
#  'товариство з обмеженою відповідальністю "виробничо-комерційна фірма "басско-2006"',
#  'шевчук віра петрівна',
#  'рутовський дмитро георгійович',
#  'дочірнє підприємство "юсм-майстерня холоду"',
#  'романов анатолій олексійович',
#  'комунальний заклад "хоростківська  музична школа"',
#  'барановський микола васильович',
#  'хоростківська міська рада',
#  'товариство з обмеженою відповідальністю "дінерострой"',
#  'подосян аркадій мелітосович',
#  'кузьменко микита володимирович',
#  'приватне підприємство "теплокомплект"',
#  "погасов в'ячеслав сергійович",
#  'товариство з обмеженою відповідальністю "оліргруп"',
#  'громадська організація "всеукраїнська асоціація "турбота про діабетика"',
#  'сергеєва ірина борисівна',
#  'товариство з обмеженою відповідальністю "дедал плюс"',
#  'сидорченко ірина василівна',
#  'товариство з обмеженою відповідальністю "будинок культури фпо"',
#  'приходько тетяна василівна',
#  'чіжов юрій вікторович',
#  'малюта вікторія сергіївна',
#  'приватне підприємство "будімпекс-плюс"',
#  'прохоренко олена євгенівна',
#  'тютіна людмила григорівна',
#  'діденко марія миколаївна',
#  'прохоренко олександр геннадійович',
#  'ярмоленко валентина миколаївна',
#  'шаховнін артем олегович',
#  'матвієць маргарита олександрівна',
#  'дочірнє підприємство "юсм-проект"',
#  'приватне підприємство "лісове господарство курорту сергіївка"',
#  'приватне підприємство "сергіївська фабрика продтоварів"',
#  'приватне підприємство "ренесанс-7"',
#  'товариство з обмеженою відповідальністю "швейна фабрика "діана"',
#  'шевченко олег петрович',
#  'підприємство об\'єднання громадян "навчально-виробниче підприємство "промінь"',
#  'громадська організація "центр розвитку курорту сергіївка"',
#  'андронатій майя семенівна',
#  'супруненко діана анатоліївна',
#  'нестерюк павліна валентинівна',
#  'фермерське господарство "кристал"',
#  'калач марина володимирівна',
#  'лучанінова ірина анатоліївна',
#  'лучанінов володимир васильович',
#  'комунальне підприємство "аварійна служба приморського району"',
#  'одеська міська рада',
#  'товариство з обмеженою відповідальністю "управляюча компанія "відродження"',
#  'сиріцький олександр генрієвич',
#  'молодцов віктор васильович',
#  'благодійна організація "світовий релігійний благодійний фонд підтримки та вшанування пам\'яті сповідників рунвіри (українців-оріярусів) "дажбог і рідні пророки"',
#  'приватне  аграрно-виробниче  підприємство  "гетьман"',
#  'садівницьке товариство "надія"',
#  'громадська організація "всеукраїнське громадське об\'єднання оріярусів україни"',
#  'корнелюк анатолій павлович',
#  'буняк семен якович',
#  'терновий іван іванович',
#  'осінчук остап мирославович',
#  'громадське формування з охорони громадського порядку і державного кордону "акс-2"',
#  'драч олег станіславович',
#  'акціонерне товариство "кіровоградське видавництво" корпоративне підприємство ат "дак "укрвидавполіграфія"',
#  'товариство з обмеженою відповідальністю "сила карпат"',
#  'мартинчук роман михайлович',
#  'зайдуліна вікторія миколаївна',
#  'фермерське господарство "караліна"',
#  'дорошенко світлана володимирівна',
#  'дорошенко кароліна анатоліївна',
#  'товариство з обмеженою відповідальністю "адамат лтд"',
#  'беркуненко євген юрійович',
#  'попович юлія миколаївна',
#  'ткачов леонід юрійович',
#  'захаренко леся юріївна',
#  'терлецький олександр валерійович',
#  'логінов руслан миколайович',
#  'одинокий микола іванович',
#  'товариство з обмеженою відповідальністю "таймс сістем"',
#  'дробот віктор васильович',
#  'деревецький юрій леонідович',
#  'обслуговуючий кооператив "голівуд"',
#  'євчук руслан федорович',
#  'шолотюк василь анатолійович',
#  'обслуговуючий кооператив "козацький."',
#  'бойчук ольга володимирівна',
#  'данилець роман миколайович',
#  'бойчук костянтин андрійович',
#  'мартинчук роман романович',
#  'бойчук кольга володимирівна',
#  'данилець юрій миколайович',
#  'товариство з обмеженою відповідальністю "юніфуд трейдинг"',
#  'джеймс джиліан терезія',
#  'зубко роман святославович',
#  'романюк тетяна володимирівна',
#  'корсак роман вікторович',
#  'товариство з обмеженою відповідальністю "укргоргаз"',
#  'товариство з обмеженою відповідальністю "навігейт"',
#  'кірчев петро іванович',
#  'мішенкова катерина валеріївна',
#  'цибенко ірина яківна',
#  'синюк вікторія юріївна',
#  'курінський максим васильович',
#  'габерстро тетяна василівна',
#  'томкевич владислав юрійович',
#  'чернишенко євген сергійович',
#  'кригін андрій сергійович',
#  'мушенко владислав володимирович',
#  'карпій ія олександрівна']
