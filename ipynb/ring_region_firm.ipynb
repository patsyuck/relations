# %%
import pandas as pd
import requests
import json

# %%
def req(obj):
    url = 'https://ring.org.ua/search?q=' + obj + '&datasources=edrdr&format=json'
    response = requests.get(url) # надсилаємо get-запит на сервер ring.org.ua
    #response = requests.get(url, verify=False) # якщо матюкається на SSL-сертифікат
    if response.status_code == 200:
        dict_resp = response.json()
        items = dict_resp['search_results']['paginator']['count'] # кількість пов'язаних фірм
        pages = dict_resp['search_results']['paginator']['num_pages'] # кількість сторінок у результаті
        result = dict_resp['search_results']['object_list'] # формуємо список даних про фірми
        if pages > 1: # якщо результати запиту не вмістилися на одну сторінку (не може бути більше 1000?)
            for i in range(2, pages+1): # повторюємо запит для всіх сторінок, починаючи з другої
                url = 'https://ring.org.ua/search?q=' + obj + '&datasources=edrdr&format=json&page=' + str(i)
                response = requests.get(url) # надсилаємо get-запит на сервер ring.org.ua
                #response = requests.get(url, verify=False) # якщо матюкається на SSL-сертифікат
                if response.status_code == 200:
                    dict_resp = response.json()
                    result += dict_resp['search_results']['object_list'] # поповнюємо список даних про фірми
                else:
                    print('Error: requested url ' + url + ' is not available!')
        if len(result) == items: # перевіряємо, чи нам вдалося отримати інформацію про всі пов'язані фірми
            return (items, result)
        else:
            print('Warning: parsed url ' + url.split('&page=')[0] + ' is not full!')
            return (len(result), result)
    else:
        print('Error: requested url ' + url + ' is not available!')
        return (0, ['error'])

# %%
def reg(loc):
    if (loc.find('київська область') != -1) or (loc.find('київська обл.') != -1):
        return 1
    elif (loc.find('дніпропетровська область') != -1) or (loc.find('дніпропетровська обл.') != -1):
        return 2
    elif (loc.find('донецька область') != -1) or (loc.find('донецька обл.') != -1):
        return 3
    elif (loc.find('харківська область') != -1) or (loc.find('харківська обл.') != -1):
        return 4
    elif (loc.find('одеська область') != -1) or (loc.find('одеська обл.') != -1):
        return 5
    elif (loc.find('львівська область') != -1) or (loc.find('львівська обл.') != -1):
        return 6
    elif (loc.find('миколаївська область') != -1) or (loc.find('миколаївська обл.') != -1):
        return 7
    elif (loc.find('запорізька область') != -1) or (loc.find('запорізька обл.') != -1):
        return 8
    elif (loc.find('хмельницька область') != -1) or (loc.find('хмельницька обл.') != -1):
        return 9
    elif (loc.find('полтавська область') != -1) or (loc.find('полтавська обл.') != -1):
        return 10
    elif (loc.find('луганська область') != -1) or (loc.find('луганська обл.') != -1):
        return 11
    elif (loc.find('вінницька область') != -1) or (loc.find('вінницька обл.') != -1):
        return 12
    elif (loc.find('житомирська область') != -1) or (loc.find('житомирська обл.') != -1):
        return 13
    elif (loc.find('черкаська область') != -1) or (loc.find('черкаська обл.') != -1):
        return 14
    elif (loc.find('херсонська область') != -1) or (loc.find('херсонська обл.') != -1):
        return 15
    elif (loc.find('кіровоградська область') != -1) or (loc.find('кіровоградська обл.') != -1):
        return 16
    elif (loc.find('сумська область') != -1) or (loc.find('сумська обл.') != -1):
        return 17
    elif (loc.find('івано-франківська область') != -1) or (loc.find('івано-франківська обл.') != -1):
        return 18
    elif (loc.find('тернопільська область') != -1) or (loc.find('тернопільська обл.') != -1):
        return 19
    elif (loc.find('чернігівська область') != -1) or (loc.find('чернігівська обл.') != -1):
        return 20
    elif (loc.find('волинська область') != -1) or (loc.find('волинська обл.') != -1):
        return 21
    elif (loc.find('рівненська область') != -1) or (loc.find('рівненська обл.') != -1):
        return 22
    elif (loc.find('закарпатська область') != -1) or (loc.find('закарпатська обл.') != -1):
        return 23
    elif (loc.find('чернівецька область') != -1) or (loc.find('чернівецька обл.') != -1):
        return 24
    elif (loc.find('республіка крим') != -1) or (loc.find(' арк ') != -1) or (loc.find(' арк,') != -1):
        return 25
    elif (loc.find(' київ ') != -1) or (loc.find(' київ,') != -1):
        return 1
    elif (loc.find(' севастополь ') != -1) or (loc.find(' севастополь,') != -1):
        return 25
    else:
        return 0 # адреса не підходить під жодну з наших масок, тому на неї далі не звертатимемо уваги

# %%
def add_info(firm, info=0):
    next_step = False
    if type(info) == str:
        records = firm['raw_records'] # тут міститься інформація про засновників
        if info in [record.split(',')[0].lower().replace('  ', ' ') for record in records]:
            location = firm['latest_record']['location'].lower().replace('  ', ' ')
            region = reg(location) # знаходимо регіон, де розташована фірма
            next_step = True
    else:
        location = firm['latest_record']['location'].lower().replace('  ', ' ')
        region = reg(location) # знаходимо регіон, де розташована фірма
        if (info == 0) or (info == region): # фірми з іншого регіону не розглядаємо (засновники -- однофамільці?)
            next_step = True
    if next_step:
        # додаємо фірму до словника знайдених контрагентів
        edrpou = firm['full_edrpou']
        name = firm['latest_record']['name'].lower().replace('  ', ' ')
        short_name = firm['latest_record']['short_name'].lower().replace('  ', ' ')
        status = firm['latest_record']['status'].lower().replace('  ', ' ')
        dict_find[edrpou] = (name, short_name, status) # додаємо інформацію про фірму: назва, повна назва, статус
        dict_firm[name] = edrpou # якщо будуть дублі за повною назвою фірми, то запишеться лише останній ЄДРПОУ!
        if (status != 'припинено') and (name not in list_temp) and (name not in list_next): # якщо фірма функціонує
            list_next.append((name, -1)) # на наступному рівні шукатимемо засновані цією фірмою фірми
            # додаємо інформацію про засновників фірми
            list_all = list(set([person[0].lower().replace('  ', ' ') for person in firm['raw_persons']])) # фізособи
            for person in list_all:
                if person not in set(dict_find.keys()): # якщо ця особа ще не засвітилася раніше
                    dict_find[person] = () # додаємо її П.І.Б. до словника знайдених контрагентів
                if (person not in list_temp) and (person not in list_next): # і якщо вона не включена до пошуку
                    list_next.append((person, region)) # на наступному рівні шукатимемо засновані цією особою фірми
            list_master = list(set([person[0].lower().replace('  ', ' ') for person in firm['raw_persons'] 
                                    if person[1] == 'Голова'])) # список голів фірми (голова тільки один?)
            list_founder = list(set([person[0].lower().replace('  ', ' ') for person in firm['raw_persons'] 
                                     if person[1] == 'Засновник'])) # список засновників (вносили кошти)
            list_benef = list(set([person[0].lower().replace('  ', ' ') for person in firm['raw_persons'] 
                                   if person[1] == 'Бенефіціарний власник'])) # список бенефіціарів
            for head in list_master: # додаємо інформацію про голів фірм, вони можуть не бути засновниками
                list_head.append([head, edrpou])
            if type(info) == int:
                records = firm['raw_records'] # тут міститься інформація про частки участі засновників (у грн.)
            part = dict()
            for record in records: # відбираємо інформацію тільки про ненульові внески
                if (record.find(' грн.')!=-1) and (record.find(' 0.00 грн.')==-1) and (record.find(' 0,00 грн.')==-1):
                    part[record.split(',')[0].lower().replace('  ', ' ')] = float(
                        record.split('-')[-1].split('грн')[0].strip().replace(',', '.')) # засновник і його внесок
            if len(part) > 0: # якщо є інформація хоча б про один ненульовий внесок до статутного капіталу
                capital = sum(part.values())
                for founder in list(part):
                    if founder in list_all: # засновник -- фізична особа
                        if founder in list_benef: # засновник є бенефіціаром
                            list_type.append([founder, edrpou, part[founder]/capital, 1])
                        else: # засновник не є бенефіціаром
                            list_type.append([founder, edrpou, part[founder]/capital, 0])
                    else: # засновник -- юридична особа (фірма)
                        if founder in list(dict_firm): # і для цієї фірми ми вже маємо інформації про її ЄДРПОУ
                            list_type.append([dict_firm[founder], edrpou, part[founder]/capital, 0])
                        else: # інакше записуємо просто назву фірми
                            list_type.append([founder, edrpou, part[founder]/capital, 0])
            # якщо бенефіціар не вносив кошти до статутного капіталу, додаємо інформацію про нього
            zero_benef = list(set(list_benef) - set(list(part)))
            if len(zero_benef) > 0:
                for founder in zero_benef:
                    list_type.append([founder, edrpou, 0, 1])
            # якщо засновник не є бенефіціаром і не вносив кошти до статутного капіталу, додаємо інформацію про нього
            zero_founder = list(set(list_founder) - set(list_benef) - set(list(part)))
            if len(zero_founder) > 0:
                for founder in zero_founder:
                    list_type.append([founder, edrpou, 0, 0])

# %%
dict_find = dict() # словник знайдених контрагентів
dict_firm = dict() # словник назва фірми --> ЄДРПОУ
list_type = [] # список зв'язків між знайденими контрагентами
list_head = [] # список голів фірм
list_temp = [] # список контрагентів на поточному рівні
list_next = [] # список контрагентів наступного рівня -- кортежі: назва фірми або П.І.Б., регіон (-1 для фірми)
i = 0 # лічильник (номер рівня відносно початкового об'єкта)

# %%
# ці дані буде задавати користувач під час запуску
start = '35696771' # задаємо ЄДРПОУ початкової фірми
level = 3 # задаємо максимальну кількість рівнів

# %%
# %%time
list_next.append((start, 0)) # 0 -- для вказівки на те, що нам не важливо, з якого регіону дана фірма
while (len(list_next) > 0) and (i < level):
    list_temp = list_next.copy()
    list_next = []
    for obj in list_temp:
        resp = req(obj[0])
        num = resp[0] # кількість знайдених фірм, пов'язаних із даним об'єктом (ЄДРПОУ, назва фірми, П.І.Б.)
        if num != 0:
            list_obj = resp[1] # список даних по знайдених фірмах
            for n in range(num):
                edrpou = list_obj[n]['full_edrpou'] # підтягуємо ЄДРПОУ фірми (що робити, якщо його немає?)
                if edrpou not in set(dict_find.keys()): # якщо ми ще не обробляли інформацію про дану фірму
                    if obj[1] == -1: # додаємо інформацію про засновників фірми та нові об'єкти для пошуку
                        add_info(list_obj[n], obj[0]) # тут передаємо для перевірки рядок -- назву фірми
                    else: # додаємо те ж саме, тільки для фірм із певної області
                        add_info(list_obj[n], obj[1]) # а тут передаємо ціле число -- номер регіону (або 0)
        else:
            if req(obj)[1] == ['error']:
                print('Error request for object = ', obj)
    i += 1
# Out:
# CPU times: user 2.81 s, sys: 214 ms, total: 3.03 s
# Wall time: 29.4 s

# %%
dict_find # знайдені контрагенти (вершини графа), для фірм додаємо повну назву, скорочену назву і стан
# Out:
# {'35696771': ('товариство з обмеженою відповідальністю "комплекс інвестмент менеджмент"',
#   'тов "кім"',
#   'зареєстровано'),
#  'ловчин лев юрійович': (),
#  'соколенко олександр іванович': (),
#  'рутовський дмитро олегович': (),
#  '37761449': ('товариство з обмеженою відповідальністю "інджи"',
#   'тов "інджи"',
#   'зареєстровано'),
#  'кравченко валентин валерійович': (),
#  'меламуд євген мойсейович': (),
#  '13904523': ('мале підприємство у вигляді товариства з обмеженою відповідальністю фірма "сокол" лтд',
#   'мп тов "сокол" лтд',
#   'припинено'),
#  '40581613': ('товариство з обмеженою відповідальністю "камидана"',
#   'тов "камидана"',
#   'зареєстровано'),
#  'рутовська світлана олександрівна': (),
#  '39189177': ('товариство з обмеженою відповідальністю "сервіс уют"',
#   'тов "сервіс уют"',
#   'зареєстровано'),
#  'корольов сергій петрович': (),
#  '39119103': ('товариство з обмеженою відповідальністю "домера"',
#   'тов "домера"',
#   'зареєстровано'),
#  'рутовський олег георгійович': (),
#  '30542625': ('товариство з обмеженою відповідальністю "южспецмонтаж"',
#   'тов "южспецмонтаж"',
#   'зареєстровано'),
#  'анісіфоров володимир львович': (),
#  'корольов петро васильович': (),
#  'галак оксана василівна': (),
#  'малюта ірина михайлівна': (),
#  '33138719': ('дочірнє підприємство "юсм-уют"', '', 'зареєстровано'),
#  'саіпова наталія леонідівна': (),
#  '39324857': ('товариство з обмеженою відповідальністю "стройбілдінг"',
#   'тов "стройбілдінг"',
#   'зареєстровано'),
#  'жоров євген данилович': (),
#  '42498353': ('товариство з обмеженою відповідальністю "коляда софт"',
#   'тов "коляда софт"',
#   'зареєстровано'),
#  'супруненко валерій іванович': (),
#  'тростянецький володимир васильович': (),
#  'гук вячеслав олександрович': (),
#  '41398320': ('товариство з обмеженою відповідальністю "комфорт буд одеса"',
#   'тов "комфорт буд одеса"',
#   'зареєстровано'),
#  'дорошенко анатолій іванович': (),
#  'діланян самвел авакович': (),
#  '05392335': ('акціонерне товариство "південсільспецмонтаж" закритого типу',
#   'ат "пссм"зт',
#   'припинено'),
#  '39009435': ('товариство з обмеженою відповідальністю "навігейт україна"',
#   'тов "навігейт україна"',
#   'зареєстровано'),
#  'плукчі петро гнатович': (),
#  'нарольський андрій олегович': (),
#  '35930695': ('громадська організація "організація інвалідів "новий крок"',
#   'го "організація інвалідів "новий крок"',
#   'зареєстровано'),
#  'стрельников андрій вікторович': (),
#  'шейко ольга вікторівна': (),
#  '19198523': ('мале підприємство - товариство з обмеженою відповідальністю "онікс - лтд"',
#   '',
#   'в стані припинення'),
#  'зак вячеслав юхимович': (),
#  '33138771': ('дочірнє підприємство "юсм-майстерня холоду"',
#   'дп "юсм-майстерня холоду"',
#   'зареєстровано'),
#  'романов анатолій олексійович': (),
#  '30662863': ('приватне підприємство "теплокомплект"',
#   'пп "теплокомплект"',
#   'в стані припинення'),
#  "погасов в'ячеслав сергійович": (),
#  '40739476': ('товариство з обмеженою відповідальністю "дінерострой"',
#   '',
#   'зареєстровано'),
#  'подосян аркадій мелітосович': (),
#  'кузьменко микита володимирович': (),
#  '42980638': ('товариство з обмеженою відповідальністю "оліргруп"',
#   'тов "оліргруп"',
#   'зареєстровано'),
#  '42824290': ('товариство з обмеженою відповідальністю "дедал плюс"',
#   'тов "дедал плюс"',
#   'зареєстровано'),
#  'сидорченко ірина василівна': (),
#  '40512178': ('товариство з обмеженою відповідальністю "будинок культури фпо"',
#   'тов "будинок культури фпо"',
#   'зареєстровано'),
#  'чіжов юрій вікторович': (),
#  'приходько тетяна василівна': (),
#  'малюта вікторія сергіївна': (),
#  '30128252': ('закрите акціонерне товариство "газ"', 'зат "газ"', 'припинено'),
#  '33138745': ('дочірнє підприємство "юсм-проект"',
#   'дп "юсм-проект"',
#   'зареєстровано'),
#  '36860315': ('приватне підприємство "лісове господарство курорту сергіївка"',
#   'пп "лісове господарство курорту сергіївка"',
#   'зареєстровано'),
#  '36860336': ('приватне підприємство "сергіївська фабрика продтоварів"',
#   'пп "сергіївська фабрика продтоварів"',
#   'зареєстровано'),
#  '32989552': ('приватне підприємство "ренесанс-7"',
#   'пп"ренесанс-7"',
#   'зареєстровано'),
#  '34712289': ('товариство з обмеженою відповідальністю "швейна фабрика "діана"',
#   'тов "швейна фабрика "діана"',
#   'зареєстровано'),
#  'шевченко олег петрович': (),
#  '39773456': ('підприємство об\'єднання громадян "навчально-виробниче підприємство "промінь"',
#   'пог "нвп "промінь"',
#   'зареєстровано'),
#  '36508768': ('громадська організація "центр розвитку курорту сергіївка"',
#   'го "центр розвитку курорту сергіївка"',
#   'зареєстровано'),
#  'андронатій майя семенівна': (),
#  'супруненко діана анатоліївна': (),
#  'нестерюк павліна валентинівна': (),
#  '41793436': ('товариство з обмеженою відповідальністю "адамат лтд"',
#   'тов "адамат лтд"',
#   'зареєстровано'),
#  'логінов руслан миколайович': (),
#  'захаренко леся юріївна': (),
#  'попович юлія миколаївна': (),
#  'беркуненко євген юрійович': (),
#  'ткачов леонід юрійович': (),
#  'одинокий микола іванович': (),
#  'терлецький олександр валерійович': (),
#  '32642131': ('комунальне підприємство "аварійна служба приморського району"',
#   'кп "ас приморського району"',
#   'в стані припинення'),
#  'одеська міська рада': (),
#  '39994485': ('товариство з обмеженою відповідальністю "управляюча компанія "відродження"',
#   'тов "управляюча компанія "відродження"',
#   'зареєстровано'),
#  'сиріцький олександр генрієвич': (),
#  'молодцов віктор васильович': (),
#  '33890483': ('товариство з обмеженою відповідальністю "укргоргаз"',
#   'тов "укргоргаз"',
#   'зареєстровано'),
#  '42289472': ('товариство з обмеженою відповідальністю "навігейт"',
#   'тов "навігейт"',
#   'зареєстровано'),
#  'курінський максим васильович': (),
#  'габерстро тетяна василівна': (),
#  'карпій ія олександрівна': (),
#  'цибенко ірина яківна': (),
#  'синюк вікторія юріївна': (),
#  'мішенкова катерина валеріївна': (),
#  'мушенко владислав володимирович': (),
#  'чернишенко євген сергійович': (),
#  'кригін андрій сергійович': (),
#  'томкевич владислав юрійович': (),
#  'кірчев петро іванович': ()}

# %%
dict_firm # словник для визначення ЄДРПОУ фірми за її назвою (сподіваюсь, дублів за повними назвами фірм немає)
# Out:
# {'товариство з обмеженою відповідальністю "комплекс інвестмент менеджмент"': '35696771',
#  'товариство з обмеженою відповідальністю "інджи"': '37761449',
#  'мале підприємство у вигляді товариства з обмеженою відповідальністю фірма "сокол" лтд': '13904523',
#  'товариство з обмеженою відповідальністю "камидана"': '40581613',
#  'товариство з обмеженою відповідальністю "сервіс уют"': '39189177',
#  'товариство з обмеженою відповідальністю "домера"': '39119103',
#  'товариство з обмеженою відповідальністю "южспецмонтаж"': '30542625',
#  'дочірнє підприємство "юсм-уют"': '33138719',
#  'товариство з обмеженою відповідальністю "стройбілдінг"': '39324857',
#  'товариство з обмеженою відповідальністю "коляда софт"': '42498353',
#  'товариство з обмеженою відповідальністю "комфорт буд одеса"': '41398320',
#  'акціонерне товариство "південсільспецмонтаж" закритого типу': '05392335',
#  'товариство з обмеженою відповідальністю "навігейт україна"': '39009435',
#  'громадська організація "організація інвалідів "новий крок"': '35930695',
#  'мале підприємство - товариство з обмеженою відповідальністю "онікс - лтд"': '19198523',
#  'дочірнє підприємство "юсм-майстерня холоду"': '33138771',
#  'приватне підприємство "теплокомплект"': '30662863',
#  'товариство з обмеженою відповідальністю "дінерострой"': '40739476',
#  'товариство з обмеженою відповідальністю "оліргруп"': '42980638',
#  'товариство з обмеженою відповідальністю "дедал плюс"': '42824290',
#  'товариство з обмеженою відповідальністю "будинок культури фпо"': '40512178',
#  'закрите акціонерне товариство "газ"': '30128252',
#  'дочірнє підприємство "юсм-проект"': '33138745',
#  'приватне підприємство "лісове господарство курорту сергіївка"': '36860315',
#  'приватне підприємство "сергіївська фабрика продтоварів"': '36860336',
#  'приватне підприємство "ренесанс-7"': '32989552',
#  'товариство з обмеженою відповідальністю "швейна фабрика "діана"': '34712289',
#  'підприємство об\'єднання громадян "навчально-виробниче підприємство "промінь"': '39773456',
#  'громадська організація "центр розвитку курорту сергіївка"': '36508768',
#  'товариство з обмеженою відповідальністю "адамат лтд"': '41793436',
#  'комунальне підприємство "аварійна служба приморського району"': '32642131',
#  'товариство з обмеженою відповідальністю "управляюча компанія "відродження"': '39994485',
#  'товариство з обмеженою відповідальністю "укргоргаз"': '33890483',
#  'товариство з обмеженою відповідальністю "навігейт"': '42289472'}

# %%
list_type # (засновник, ЄДРПОУ заснованої фірми, частка участі засновника, чи є засновник бенефіціаром)
# Out:
# [['соколенко олександр іванович', '35696771', 0.34, 1],
#  ['рутовський дмитро олегович', '35696771', 0.33, 0],
#  ['ловчин лев юрійович', '35696771', 0.33, 0],
#  ['меламуд євген мойсейович', '37761449', 0.45, 0],
#  ['35696771', '37761449', 0.55, 0],
#  ['рутовський дмитро олегович', '40581613', 0.2792307142272753, 0],
#  ['рутовська світлана олександрівна', '40581613', 0.0837692142681826, 0],
#  ['товариство з обмеженою відповідальністю "южспецмонтаж"',
#   '40581613',
#   0.6370000715045421,
#   0],
#  ['рутовський дмитро олегович', '39189177', 1.0, 1],
#  ['товариство з обмеженою відповідальністю "южспецмонтаж"',
#   '39119103',
#   0.23026733809523808,
#   0],
#  ['рутовський дмитро олегович', '39119103', 0.6983040904761905, 1],
#  ['рутовський олег георгійович', '39119103', 0.03571428571428571, 1],
#  ['рутовська світлана олександрівна', '39119103', 0.03571428571428571, 1],
#  ['рутовський дмитро олегович', '30542625', 0.7692307692307693, 1],
#  ['рутовський олег георгійович', '30542625', 0.23076923076923078, 1],
#  ['30542625', '33138719', 1.0, 0],
#  ['рутовський дмитро олегович', '33138719', 0, 1],
#  ['рутовський олег георгійович', '33138719', 0, 1],
#  ['рутовський олег георгійович', '39324857', 0.16666666666666666, 1],
#  ['рутовський дмитро олегович', '39324857', 0.6666666666666666, 1],
#  ['жоров євген данилович', '39324857', 0.16666666666666666, 1],
#  ['рутовський дмитро олегович', '42498353', 0.165, 1],
#  ['40581613', '42498353', 0.5, 0],
#  ['гук вячеслав олександрович', '42498353', 0.17, 0],
#  ['супруненко валерій іванович', '42498353', 0.165, 0],
#  ['40581613', '41398320', 1.0, 0],
#  ['рутовська світлана олександрівна', '41398320', 0, 1],
#  ['рутовський дмитро олегович', '41398320', 0, 1],
#  ['рутовський дмитро олегович', '39009435', 0.2, 0],
#  ['плукчі петро гнатович', '39009435', 0.3333333333333333, 1],
#  ['нарольський андрій олегович', '39009435', 0.13333333333333333, 0],
#  ['саіпова наталія леонідівна', '39009435', 0.3333333333333333, 0],
#  ['стрельников андрій вікторович', '35930695', 0, 0],
#  ['кравченко валентин валерійович', '35930695', 0, 0],
#  ['шейко ольга вікторівна', '35930695', 0, 0],
#  ['меламуд євген мойсейович', '19198523', 0.5, 1],
#  ['зак вячеслав юхимович', '19198523', 0.5, 1],
#  ['30542625', '33138771', 1.0, 0],
#  ['анісіфоров володимир львович', '30662863', 1.0, 0],
#  ['галак оксана василівна', '40739476', 0.5, 0],
#  ['подосян аркадій мелітосович', '40739476', 0.5, 0],
#  ['малюта ірина михайлівна', '42980638', 1.0, 0],
#  ['малюта ірина михайлівна', '42824290', 1.0, 0],
#  ['приходько тетяна василівна', '40512178', 0.6666666666666666, 0],
#  ['малюта ірина михайлівна', '40512178', 0.3333333333333333, 0],
#  ['товариство з обмеженою відповідальністю "южспецмонтраж"',
#   '33138745',
#   1.0,
#   0],
#  ['супруненко валерій іванович', '36860315', 1.0, 1],
#  ['супруненко валерій іванович', '36860336', 1.0, 1],
#  ['супруненко валерій іванович', '32989552', 1.0, 1],
#  ['32989552', '34712289', 0.5, 0],
#  ['шевченко олег петрович', '34712289', 0.5, 1],
#  ['супруненко валерій іванович', '34712289', 0, 1],
#  ['громадська організація "союз захисту інвалідів"', '39773456', 1.0, 0],
#  ['супруненко валерій іванович', '36508768', 0, 0],
#  ['андронатій майя семенівна', '36508768', 0, 0],
#  ['нестерюк павліна валентинівна', '36508768', 0, 0],
#  ['супруненко діана анатоліївна', '36508768', 0, 0],
#  ['дорошенко анатолій іванович', '41793436', 0.1272931486334706, 1],
#  ['беркуненко євген юрійович', '41793436', 0.3743916136278547, 0],
#  ['одинокий микола іванович', '41793436', 0.12354923249719206, 0],
#  ['попович юлія миколаївна', '41793436', 0.3743916136278547, 1],
#  ['товариство з обмеженою відповідальністю "енердж сістем"',
#   '41793436',
#   0.00018719580681392738,
#   0],
#  ['товариство з обмеженою відповідальністю "томрест"',
#   '41793436',
#   0.00018719580681392738,
#   0],
#  ['терлецький олександр валерійович', '41793436', 0, 1],
#  ['захаренко леся юріївна', '41793436', 0, 1],
#  ['одеська міська рада', '32642131', 1.0, 0],
#  ['молодцов віктор васильович', '39994485', 0.5, 0],
#  ['товариство з обмеженою відповідальністю "ренесанс-92"', '39994485', 0.5, 0],
#  ['сиріцький олександр генрієвич', '39994485', 0, 1],
#  ['плукчі петро гнатович', '33890483', 1.0, 0],
#  ['курінський максим васильович', '42289472', 0.2, 0],
#  ['кригін андрій сергійович', '42289472', 0.06, 0],
#  ['чернишенко євген сергійович', '42289472', 0.196, 0],
#  ['мішенкова катерина валеріївна', '42289472', 0.04, 0],
#  ['цибенко ірина яківна', '42289472', 0.06, 0],
#  ['габерстро тетяна василівна', '42289472', 0.06, 0],
#  ['томкевич владислав юрійович', '42289472', 0.06, 0],
#  ['синюк вікторія юріївна', '42289472', 0.06, 0],
#  ['карпій ія олександрівна', '42289472', 0.06, 0],
#  ['мушенко владислав володимирович', '42289472', 0.204, 0]]

# %% [markdown]
# Якщо ЄДРПОУ по якихось фірмах не підтягнулося відразу, то заміняємо зараз назву фірми на ЄДРПОУ (заміняється не завжди):

# %%
# %%time
list_type_new = list_type.copy()
for i in range(len(list_type_new)):
    if list_type_new[i][0] in list(dict_firm):
        list_type_new[i][0] = dict_firm[list_type_new[i][0]]
list_type_new
# Out:
# CPU times: user 189 µs, sys: 0 ns, total: 189 µs
# Wall time: 194 µs
# [['соколенко олександр іванович', '35696771', 0.34, 1],
#  ['рутовський дмитро олегович', '35696771', 0.33, 0],
#  ['ловчин лев юрійович', '35696771', 0.33, 0],
#  ['меламуд євген мойсейович', '37761449', 0.45, 0],
#  ['35696771', '37761449', 0.55, 0],
#  ['рутовський дмитро олегович', '40581613', 0.2792307142272753, 0],
#  ['рутовська світлана олександрівна', '40581613', 0.0837692142681826, 0],
#  ['30542625', '40581613', 0.6370000715045421, 0],
#  ['рутовський дмитро олегович', '39189177', 1.0, 1],
#  ['30542625', '39119103', 0.23026733809523808, 0],
#  ['рутовський дмитро олегович', '39119103', 0.6983040904761905, 1],
#  ['рутовський олег георгійович', '39119103', 0.03571428571428571, 1],
#  ['рутовська світлана олександрівна', '39119103', 0.03571428571428571, 1],
#  ['рутовський дмитро олегович', '30542625', 0.7692307692307693, 1],
#  ['рутовський олег георгійович', '30542625', 0.23076923076923078, 1],
#  ['30542625', '33138719', 1.0, 0],
#  ['рутовський дмитро олегович', '33138719', 0, 1],
#  ['рутовський олег георгійович', '33138719', 0, 1],
#  ['рутовський олег георгійович', '39324857', 0.16666666666666666, 1],
#  ['рутовський дмитро олегович', '39324857', 0.6666666666666666, 1],
#  ['жоров євген данилович', '39324857', 0.16666666666666666, 1],
#  ['рутовський дмитро олегович', '42498353', 0.165, 1],
#  ['40581613', '42498353', 0.5, 0],
#  ['гук вячеслав олександрович', '42498353', 0.17, 0],
#  ['супруненко валерій іванович', '42498353', 0.165, 0],
#  ['40581613', '41398320', 1.0, 0],
#  ['рутовська світлана олександрівна', '41398320', 0, 1],
#  ['рутовський дмитро олегович', '41398320', 0, 1],
#  ['рутовський дмитро олегович', '39009435', 0.2, 0],
#  ['плукчі петро гнатович', '39009435', 0.3333333333333333, 1],
#  ['нарольський андрій олегович', '39009435', 0.13333333333333333, 0],
#  ['саіпова наталія леонідівна', '39009435', 0.3333333333333333, 0],
#  ['стрельников андрій вікторович', '35930695', 0, 0],
#  ['кравченко валентин валерійович', '35930695', 0, 0],
#  ['шейко ольга вікторівна', '35930695', 0, 0],
#  ['меламуд євген мойсейович', '19198523', 0.5, 1],
#  ['зак вячеслав юхимович', '19198523', 0.5, 1],
#  ['30542625', '33138771', 1.0, 0],
#  ['анісіфоров володимир львович', '30662863', 1.0, 0],
#  ['галак оксана василівна', '40739476', 0.5, 0],
#  ['подосян аркадій мелітосович', '40739476', 0.5, 0],
#  ['малюта ірина михайлівна', '42980638', 1.0, 0],
#  ['малюта ірина михайлівна', '42824290', 1.0, 0],
#  ['приходько тетяна василівна', '40512178', 0.6666666666666666, 0],
#  ['малюта ірина михайлівна', '40512178', 0.3333333333333333, 0],
#  ['товариство з обмеженою відповідальністю "южспецмонтраж"',
#   '33138745',
#   1.0,
#   0],
#  ['супруненко валерій іванович', '36860315', 1.0, 1],
#  ['супруненко валерій іванович', '36860336', 1.0, 1],
#  ['супруненко валерій іванович', '32989552', 1.0, 1],
#  ['32989552', '34712289', 0.5, 0],
#  ['шевченко олег петрович', '34712289', 0.5, 1],
#  ['супруненко валерій іванович', '34712289', 0, 1],
#  ['громадська організація "союз захисту інвалідів"', '39773456', 1.0, 0],
#  ['супруненко валерій іванович', '36508768', 0, 0],
#  ['андронатій майя семенівна', '36508768', 0, 0],
#  ['нестерюк павліна валентинівна', '36508768', 0, 0],
#  ['супруненко діана анатоліївна', '36508768', 0, 0],
#  ['дорошенко анатолій іванович', '41793436', 0.1272931486334706, 1],
#  ['беркуненко євген юрійович', '41793436', 0.3743916136278547, 0],
#  ['одинокий микола іванович', '41793436', 0.12354923249719206, 0],
#  ['попович юлія миколаївна', '41793436', 0.3743916136278547, 1],
#  ['товариство з обмеженою відповідальністю "енердж сістем"',
#   '41793436',
#   0.00018719580681392738,
#   0],
#  ['товариство з обмеженою відповідальністю "томрест"',
#   '41793436',
#   0.00018719580681392738,
#   0],
#  ['терлецький олександр валерійович', '41793436', 0, 1],
#  ['захаренко леся юріївна', '41793436', 0, 1],
#  ['одеська міська рада', '32642131', 1.0, 0],
#  ['молодцов віктор васильович', '39994485', 0.5, 0],
#  ['товариство з обмеженою відповідальністю "ренесанс-92"', '39994485', 0.5, 0],
#  ['сиріцький олександр генрієвич', '39994485', 0, 1],
#  ['плукчі петро гнатович', '33890483', 1.0, 0],
#  ['курінський максим васильович', '42289472', 0.2, 0],
#  ['кригін андрій сергійович', '42289472', 0.06, 0],
#  ['чернишенко євген сергійович', '42289472', 0.196, 0],
#  ['мішенкова катерина валеріївна', '42289472', 0.04, 0],
#  ['цибенко ірина яківна', '42289472', 0.06, 0],
#  ['габерстро тетяна василівна', '42289472', 0.06, 0],
#  ['томкевич владислав юрійович', '42289472', 0.06, 0],
#  ['синюк вікторія юріївна', '42289472', 0.06, 0],
#  ['карпій ія олександрівна', '42289472', 0.06, 0],
#  ['мушенко владислав володимирович', '42289472', 0.204, 0]]

# %%
list_head # (голова, ЄДРПОУ фірми)
# Out:
# [['соколенко олександр іванович', '35696771'],
#  ['кравченко валентин валерійович', '37761449'],
#  ['рутовський дмитро олегович', '40581613'],
#  ['корольов сергій петрович', '39189177'],
#  ['рутовський дмитро олегович', '39119103'],
#  ['корольов петро васильович', '30542625'],
#  ['галак оксана василівна', '30542625'],
#  ['анісіфоров володимир львович', '30542625'],
#  ['малюта ірина михайлівна', '30542625'],
#  ['саіпова наталія леонідівна', '33138719'],
#  ['жоров євген данилович', '39324857'],
#  ['тростянецький володимир васильович', '42498353'],
#  ['гук вячеслав олександрович', '42498353'],
#  ['дорошенко анатолій іванович', '41398320'],
#  ['тростянецький володимир васильович', '41398320'],
#  ['діланян самвел авакович', '41398320'],
#  ['корольов петро васильович', '39009435'],
#  ['нарольський андрій олегович', '39009435'],
#  ['анісіфоров володимир львович', '39009435'],
#  ['стрельников андрій вікторович', '35930695'],
#  ['меламуд євген мойсейович', '19198523'],
#  ['романов анатолій олексійович', '33138771'],
#  ["погасов в'ячеслав сергійович", '30662863'],
#  ['плукчі петро гнатович', '40739476'],
#  ['кузьменко микита володимирович', '40739476'],
#  ['малюта ірина михайлівна', '42980638'],
#  ['сидорченко ірина василівна', '42824290'],
#  ['чіжов юрій вікторович', '40512178'],
#  ['малюта вікторія сергіївна', '40512178'],
#  ['жоров євген данилович', '33138745'],
#  ['супруненко валерій іванович', '36860315'],
#  ['супруненко валерій іванович', '36860336'],
#  ['супруненко валерій іванович', '32989552'],
#  ['супруненко валерій іванович', '34712289'],
#  ['супруненко валерій іванович', '39773456'],
#  ['супруненко діана анатоліївна', '36508768'],
#  ['логінов руслан миколайович', '41793436'],
#  ['попович юлія миколаївна', '41793436'],
#  ['ткачов леонід юрійович', '41793436'],
#  ['дорошенко анатолій іванович', '41793436'],
#  ['одинокий микола іванович', '41793436'],
#  ['діланян самвел авакович', '32642131'],
#  ['діланян самвел авакович', '39994485'],
#  ['плукчі петро гнатович', '33890483'],
#  ['нарольський андрій олегович', '42289472'],
#  ['чернишенко євген сергійович', '42289472'],
#  ['кірчев петро іванович', '42289472']]

# %%
list_temp # список контрагентів, за якими здійснювався пошук на останньому рівні
# Out:
# [('товариство з обмеженою відповідальністю "інджи"', -1),
#  ('кравченко валентин валерійович', 5),
#  ('меламуд євген мойсейович', 5),
#  ('товариство з обмеженою відповідальністю "камидана"', -1),
#  ('рутовська світлана олександрівна', 5),
#  ('рутовський дмитро олегович', 5),
#  ('товариство з обмеженою відповідальністю "сервіс уют"', -1),
#  ('корольов сергій петрович', 5),
#  ('рутовський дмитро олегович', 5),
#  ('товариство з обмеженою відповідальністю "домера"', -1),
#  ('рутовська світлана олександрівна', 5),
#  ('рутовський дмитро олегович', 5),
#  ('рутовський олег георгійович', 5),
#  ('товариство з обмеженою відповідальністю "южспецмонтаж"', -1),
#  ('анісіфоров володимир львович', 5),
#  ('корольов петро васильович', 5),
#  ('рутовський олег георгійович', 5),
#  ('рутовський дмитро олегович', 5),
#  ('галак оксана василівна', 5),
#  ('малюта ірина михайлівна', 5),
#  ('дочірнє підприємство "юсм-уют"', -1),
#  ('саіпова наталія леонідівна', 5),
#  ('рутовський дмитро олегович', 5),
#  ('рутовський олег георгійович', 5),
#  ('товариство з обмеженою відповідальністю "стройбілдінг"', -1),
#  ('рутовський дмитро олегович', 5),
#  ('рутовський олег георгійович', 5),
#  ('жоров євген данилович', 5),
#  ('товариство з обмеженою відповідальністю "коляда софт"', -1),
#  ('супруненко валерій іванович', 5),
#  ('рутовський дмитро олегович', 5),
#  ('тростянецький володимир васильович', 5),
#  ('гук вячеслав олександрович', 5),
#  ('товариство з обмеженою відповідальністю "комфорт буд одеса"', -1),
#  ('дорошенко анатолій іванович', 5),
#  ('рутовська світлана олександрівна', 5),
#  ('тростянецький володимир васильович', 5),
#  ('рутовський дмитро олегович', 5),
#  ('діланян самвел авакович', 5),
#  ('товариство з обмеженою відповідальністю "навігейт україна"', -1),
#  ('анісіфоров володимир львович', 5),
#  ('корольов петро васильович', 5),
#  ('плукчі петро гнатович', 5),
#  ('саіпова наталія леонідівна', 5),
#  ('нарольський андрій олегович', 5),
#  ('рутовський дмитро олегович', 5)]

# %%
list_next # список контрагентів для пошуку на наступному рівні (непорожній, якщо було задано максимальний рівень)
# Out:
# [('громадська організація "організація інвалідів "новий крок"', -1),
#  ('стрельников андрій вікторович', 5),
#  ('кравченко валентин валерійович', 5),
#  ('шейко ольга вікторівна', 5),
#  ('мале підприємство - товариство з обмеженою відповідальністю "онікс - лтд"',
#   -1),
#  ('меламуд євген мойсейович', 5),
#  ('зак вячеслав юхимович', 5),
#  ('дочірнє підприємство "юсм-майстерня холоду"', -1),
#  ('романов анатолій олексійович', 5),
#  ('приватне підприємство "теплокомплект"', -1),
#  ('анісіфоров володимир львович', 5),
#  ("погасов в'ячеслав сергійович", 5),
#  ('товариство з обмеженою відповідальністю "дінерострой"', -1),
#  ('плукчі петро гнатович', 5),
#  ('галак оксана василівна', 5),
#  ('подосян аркадій мелітосович', 5),
#  ('кузьменко микита володимирович', 5),
#  ('товариство з обмеженою відповідальністю "оліргруп"', -1),
#  ('малюта ірина михайлівна', 5),
#  ('товариство з обмеженою відповідальністю "дедал плюс"', -1),
#  ('сидорченко ірина василівна', 5),
#  ('малюта ірина михайлівна', 5),
#  ('товариство з обмеженою відповідальністю "будинок культури фпо"', -1),
#  ('чіжов юрій вікторович', 5),
#  ('приходько тетяна василівна', 5),
#  ('малюта вікторія сергіївна', 5),
#  ('малюта ірина михайлівна', 5),
#  ('дочірнє підприємство "юсм-проект"', -1),
#  ('жоров євген данилович', 5),
#  ('приватне підприємство "лісове господарство курорту сергіївка"', -1),
#  ('супруненко валерій іванович', 5),
#  ('приватне підприємство "сергіївська фабрика продтоварів"', -1),
#  ('супруненко валерій іванович', 5),
#  ('приватне підприємство "ренесанс-7"', -1),
#  ('супруненко валерій іванович', 5),
#  ('товариство з обмеженою відповідальністю "швейна фабрика "діана"', -1),
#  ('супруненко валерій іванович', 5),
#  ('шевченко олег петрович', 5),
#  ('підприємство об\'єднання громадян "навчально-виробниче підприємство "промінь"',
#   -1),
#  ('супруненко валерій іванович', 5),
#  ('громадська організація "центр розвитку курорту сергіївка"', -1),
#  ('супруненко валерій іванович', 5),
#  ('андронатій майя семенівна', 5),
#  ('супруненко діана анатоліївна', 5),
#  ('нестерюк павліна валентинівна', 5),
#  ('товариство з обмеженою відповідальністю "адамат лтд"', -1),
#  ('логінов руслан миколайович', 5),
#  ('захаренко леся юріївна', 5),
#  ('попович юлія миколаївна', 5),
#  ('беркуненко євген юрійович', 5),
#  ('ткачов леонід юрійович', 5),
#  ('дорошенко анатолій іванович', 5),
#  ('одинокий микола іванович', 5),
#  ('терлецький олександр валерійович', 5),
#  ('комунальне підприємство "аварійна служба приморського району"', -1),
#  ('одеська міська рада', 5),
#  ('діланян самвел авакович', 5),
#  ('товариство з обмеженою відповідальністю "управляюча компанія "відродження"',
#   -1),
#  ('сиріцький олександр генрієвич', 5),
#  ('діланян самвел авакович', 5),
#  ('молодцов віктор васильович', 5),
#  ('товариство з обмеженою відповідальністю "укргоргаз"', -1),
#  ('плукчі петро гнатович', 5),
#  ('товариство з обмеженою відповідальністю "навігейт"', -1),
#  ('курінський максим васильович', 5),
#  ('габерстро тетяна василівна', 5),
#  ('карпій ія олександрівна', 5),
#  ('цибенко ірина яківна', 5),
#  ('синюк вікторія юріївна', 5),
#  ('мішенкова катерина валеріївна', 5),
#  ('нарольський андрій олегович', 5),
#  ('мушенко владислав володимирович', 5),
#  ('чернишенко євген сергійович', 5),
#  ('кригін андрій сергійович', 5),
#  ('томкевич владислав юрійович', 5),
#  ('кірчев петро іванович', 5)]
