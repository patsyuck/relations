# %%
import pandas as pd
import requests
import json

# %%
from networkx.readwrite.json_graph import node_link_data, node_link_graph
from networkx.classes.function import degree

# %% [markdown]
# Функції для роботи з графом:

# %%
def read_json(json_name):
    with open(json_name, 'r') as infile:
        data = json.load(infile)
    g = node_link_graph(data, directed=True) # directed or undirected
    return g

# %%
def write_json(g, json_name, graph=True):
    if graph:
        g = node_link_data(g)
    with open(json_name, 'w') as outfile:
        json.dump(g, outfile)

# %%
def nodes_degree(g):
    dct = dict(degree(g.to_undirected()))
    for i in dct:
        g.nodes[i]['degree'] = dct[i]
    return g

# %% [markdown]
# Функції для роботи з парсингом:

# %%
def req(obj): # витягуємо дані ЄДР із сайту ring.org.ua для даного об'єкта
    url = 'https://ring.org.ua/search?q=' + obj + '&datasources=edrdr&format=json'
    response = requests.get(url) # надсилаємо get-запит на сервер ring.org.ua
    #response = requests.get(url, verify=False) # якщо матюкається на SSL-сертифікат
    if response.status_code == 200:
        dict_resp = response.json()
        items = dict_resp['search_results']['paginator']['count'] # кількість пов'язаних фірм
        pages = dict_resp['search_results']['paginator']['num_pages'] # кількість сторінок у результаті
        result = dict_resp['search_results']['object_list'] # формуємо список даних про фірми
        if pages > 1: # якщо результати запиту не вмістилися на одну сторінку (не може бути більше 1000?)
            for i in range(2, pages+1): # повторюємо запит для всіх сторінок, починаючи з другої
                url = 'https://ring.org.ua/search?q=' + obj + '&datasources=edrdr&format=json&page=' + str(i)
                response = requests.get(url) # надсилаємо get-запит на сервер ring.org.ua
                #response = requests.get(url, verify=False) # якщо матюкається на SSL-сертифікат
                if response.status_code == 200:
                    dict_resp = response.json()
                    result += dict_resp['search_results']['object_list'] # поповнюємо список даних про фірми
                else:
                    print('Error: requested url ' + url + ' is not available!')
        if len(result) == items: # перевіряємо, чи нам вдалося отримати інформацію про всі пов'язані фірми
            return (items, result)
        else:
            print('Warning: parsed url ' + url.split('&page=')[0] + ' is not full!')
            return (len(result), result)
    else:
        print('Error: requested url ' + url + ' is not available!')
        return (0, ['error'])

# %%
def reg(loc): # визначаємо номер регіону за повною адресою фірми
    if (loc.find('київська область') != -1) or (loc.find('київська обл.') != -1):
        return 1
    elif (loc.find('дніпропетровська область') != -1) or (loc.find('дніпропетровська обл.') != -1):
        return 2
    elif (loc.find('донецька область') != -1) or (loc.find('донецька обл.') != -1):
        return 3
    elif (loc.find('харківська область') != -1) or (loc.find('харківська обл.') != -1):
        return 4
    elif (loc.find('одеська область') != -1) or (loc.find('одеська обл.') != -1):
        return 5
    elif (loc.find('львівська область') != -1) or (loc.find('львівська обл.') != -1):
        return 6
    elif (loc.find('миколаївська область') != -1) or (loc.find('миколаївська обл.') != -1):
        return 7
    elif (loc.find('запорізька область') != -1) or (loc.find('запорізька обл.') != -1):
        return 8
    elif (loc.find('хмельницька область') != -1) or (loc.find('хмельницька обл.') != -1):
        return 9
    elif (loc.find('полтавська область') != -1) or (loc.find('полтавська обл.') != -1):
        return 10
    elif (loc.find('луганська область') != -1) or (loc.find('луганська обл.') != -1):
        return 11
    elif (loc.find('вінницька область') != -1) or (loc.find('вінницька обл.') != -1):
        return 12
    elif (loc.find('житомирська область') != -1) or (loc.find('житомирська обл.') != -1):
        return 13
    elif (loc.find('черкаська область') != -1) or (loc.find('черкаська обл.') != -1):
        return 14
    elif (loc.find('херсонська область') != -1) or (loc.find('херсонська обл.') != -1):
        return 15
    elif (loc.find('кіровоградська область') != -1) or (loc.find('кіровоградська обл.') != -1):
        return 16
    elif (loc.find('сумська область') != -1) or (loc.find('сумська обл.') != -1):
        return 17
    elif (loc.find('івано-франківська область') != -1) or (loc.find('івано-франківська обл.') != -1):
        return 18
    elif (loc.find('тернопільська область') != -1) or (loc.find('тернопільська обл.') != -1):
        return 19
    elif (loc.find('чернігівська область') != -1) or (loc.find('чернігівська обл.') != -1):
        return 20
    elif (loc.find('волинська область') != -1) or (loc.find('волинська обл.') != -1):
        return 21
    elif (loc.find('рівненська область') != -1) or (loc.find('рівненська обл.') != -1):
        return 22
    elif (loc.find('закарпатська область') != -1) or (loc.find('закарпатська обл.') != -1):
        return 23
    elif (loc.find('чернівецька область') != -1) or (loc.find('чернівецька обл.') != -1):
        return 24
    elif (loc.find('республіка крим') != -1) or (loc.find(' арк ') != -1) or (loc.find(' арк,') != -1):
        return 25
    elif (loc.find(' київ ') != -1) or (loc.find(' київ,') != -1):
        return 1
    elif (loc.find(' севастополь ') != -1) or (loc.find(' севастополь,') != -1):
        return 25
    else:
        return 0 # адреса не підходить під жодну з наших масок, тому на неї далі не звертатимемо уваги

# %%
def find_addr(addresses_cut, records_cut, person): # знаходимо список адрес бенефіціара
    list_addr = []
    for address in addresses_cut:
        for record in records_cut:
            if record.find(person.replace(' ', '').replace('-', '')) != -1 and record.find(address) != -1:
                list_addr.append(address)
    return list(set(list_addr)) # видаляємо дублі, які могли утворитися протягом обробки

# %%
def add_info(firm, info=0, list_addr=None): # головна підпрограма -- обробляє картку даних однієї фірми
    next_step = False
    # додаємо фірму до словника знайдених контрагентів
    edrpou = firm['full_edrpou']
    name = firm['latest_record']['name'].lower().replace('  ', ' ')
    short_name = firm['latest_record']['short_name'].lower().replace('  ', ' ')
    status = firm['latest_record']['status'].lower().replace('  ', ' ') 
    dict_find[edrpou] = (name, short_name, status) # додаємо інформацію про фірму: назва, повна назва, статус
    dict_firm[name] = edrpou # якщо будуть дублі за повною назвою фірми, то запишеться лише останній ЄДРПОУ!
    if status != 'припинено': # якщо фірма функціонує
        try:
            records = firm['raw_records'] # тут міститься інформація про частки участі засновників (у грн.)
            if type(info) == str: # перевірка № 1 -- за співпадінням назв фірм
                if info in [record.split(',')[0].lower().replace('  ', ' ') for record in records]:
                    location = firm['latest_record']['location'].lower().replace('  ', ' ')
                    region = reg(location) # знаходимо регіон, де розташована фірма
                    next_step = True
            else: # перевірка № 2 -- за співпадінням адрес при спільному П.І.Б. бенефіціарів
                if list_addr != None and len(list([person[0] for person in firm['raw_persons'] 
                                                   if person[1] == 'Бенефіціарний власник'])) > 0: # є адреса і бенефіціари
                    for addr in list_addr: # перебираємо список адрес (можуть відрізнятися незначним чином)
                        if not next_step:
                            for record in records: # для кожного запису про частку участі засновника
                                if record.lower().replace(' ', '').replace('-', '').find(addr) != -1: # адреси співпали
                                    location = firm['latest_record']['location'].lower().replace('  ', ' ')
                                    region = reg(location) # знаходимо регіон, де розташована фірма
                                    next_step = True
                                    break
                else: # перевірка № 3 -- за співпадінням регіонів фірм при спільному П.І.Б. засновників
                    location = firm['latest_record']['location'].lower().replace('  ', ' ')
                    region = reg(location) # знаходимо регіон, де розташована фірма
                    if (info == 0) or (info == region): # фірми з іншого регіону не розглядаємо (засновники -- однофамільці?)
                        next_step = True
        except:
            print('Warning: Detail information about firm {0} is absend, status = {1}.'.format(edrpou, status))
    if next_step:
        # якщо ця фірма ще не включена до списку пошуку (поточного або наступного)
        if (name not in [x[0] for x in list_temp]) and (name not in [x[0] for x in list_next]):
        #if (name not in list_temp) and (name not in list_next): # якщо ця фірма ще не включена до списку пошуку
            list_next.append((name, -1)) # на наступному рівні шукатимемо засновані цією фірмою фірми
            # додаємо інформацію про засновників фірми
            list_all = list(set([person[0].lower().replace('  ', ' ') for person in firm['raw_persons']])) # фізособи
            list_master = list(set([person[0].lower().replace('  ', ' ') for person in firm['raw_persons'] 
                                    if person[1] == 'Голова'])) # список голів фірми (голова тільки один?)
            list_founder = list(set([person[0].lower().replace('  ', ' ') for person in firm['raw_persons'] 
                                     if person[1] == 'Засновник'])) # список засновників (вносили кошти)
            list_benef = list(set([person[0].lower().replace('  ', ' ') for person in firm['raw_persons'] 
                                   if person[1] == 'Бенефіціарний власник'])) # список бенефіціарів
            if len(list_benef) > 0: # адреси засновників вказуються зазвичай тільки для бенефіціарів
                addresses = firm['addresses']
                addresses = [address.lower().replace(' ', '').replace('-', '') for address in addresses if 
                             len(address.split(',')) > 1] # вилучаємо всі пробіли й дефіси та адреси з одного слова
                records_new = [record.lower().replace(' ', '').replace('-', '') for record in records]
                addresses_cut = []
                for address in addresses: # лишаємо ті адреси, які є в записах про частку участі засновників
                    if sum([False if record.find(address) == -1 else True for record in records_new]) > 0:
                        addresses_cut.append(address)
                addresses_cut = list(set(addresses_cut)) # видаляємо дублі, які могли утворитися протягом обробки
                records_cut = []
                for record in records_new: # лишаємо тільки ті записи про частку участі, у яких є адреси
                    if sum([False if record.find(address) == -1 else True for address in addresses_cut]) > 0:
                        records_cut.append(record)
            for person in list_all:
                if person not in set(dict_find.keys()): # якщо ця особа ще не засвітилася раніше
                    dict_find[person] = () # додаємо її П.І.Б. до словника знайдених контрагентів
                    # і якщо ця особа не включена до списку пошуку (поточного або наступного)
                    if (person not in [x[0] for x in list_temp]) and (person not in [x[0] for x in list_next]): 
                    #if (person not in list_temp) and (person not in list_next): # і якщо вона не включена до пошуку
                        if person not in list_benef: # список бенефіціарів може бути порожнім
                            list_next.append((person, region)) # на наступному рівні шукатимемо засновані цією особою фірми
                        else: # якщо ми маємо справу з бенефіціаром, додаємо також його адресу
                            list_next.append((person, region, find_addr(addresses_cut, records_cut, person)))
            for head in list_master: # додаємо інформацію про голів фірм, вони можуть не бути засновниками
                list_head.append([head, edrpou])
            part = dict()
            for record in records: # відбираємо інформацію тільки про ненульові внески
                if (record.find(' грн.')!=-1) and (record.find(' 0.00 грн.')==-1) and (record.find(' 0,00 грн.')==-1):
                    part[record.split(',')[0].lower().replace('  ', ' ')] = float(
                        record.split('-')[-1].split('грн')[0].strip().replace(',', '.')) # засновник і його внесок
            if len(part) > 0: # якщо є інформація хоча б про один ненульовий внесок до статутного капіталу
                capital = sum(part.values())
                for founder in list(part):
                    if founder in list_all: # засновник -- фізична особа
                        if founder in list_benef: # засновник є бенефіціаром
                            list_type.append([founder, edrpou, part[founder]/capital, 1])
                        else: # засновник не є бенефіціаром
                            list_type.append([founder, edrpou, part[founder]/capital, 0])
                    else: # засновник -- юридична особа (фірма)
                        if founder in list(dict_firm): # і для цієї фірми ми вже маємо інформації про її ЄДРПОУ
                            list_type.append([dict_firm[founder], edrpou, part[founder]/capital, 0])
                        else: # інакше записуємо просто назву фірми
                            list_type.append([founder, edrpou, part[founder]/capital, 0])
            # якщо бенефіціар не вносив кошти до статутного капіталу, додаємо інформацію про нього
            zero_benef = list(set(list_benef) - set(list(part)))
            if len(zero_benef) > 0:
                for founder in zero_benef:
                    list_type.append([founder, edrpou, 0, 1])
            # якщо засновник не є бенефіціаром і не вносив кошти до статутного капіталу, додаємо інформацію про нього
            zero_founder = list(set(list_founder) - set(list_benef) - set(list(part)))
            if len(zero_founder) > 0:
                for founder in zero_founder:
                    list_type.append([founder, edrpou, 0, 0])

# %%
dict_find = dict() # словник знайдених контрагентів
dict_firm = dict() # словник назва фірми --> ЄДРПОУ
list_type = [] # список зв'язків між знайденими контрагентами
list_head = [] # список голів фірм
list_temp = [] # список контрагентів на поточному рівні
list_next = [] # список контрагентів наступного рівня -- кортежі: назва фірми або П.І.Б., регіон (-1 для фірми)
i = 0 # лічильник (номер рівня відносно початкового об'єкта)

# %%
# ці дані буде задавати користувач під час запуску
start = '31382665' # задаємо ЄДРПОУ початкової фірми
level = 3 # задаємо максимальну кількість рівнів

# %%
# %%time
list_next.append((start, 0)) # 0 -- для вказівки на те, що нам не важливо, з якого регіону дана фірма
while (len(list_next) > 0) and (i < level):
    list_temp = list_next.copy()
    list_next = []
    for obj in list_temp:
        resp = req(obj[0])
        num = resp[0] # кількість знайдених фірм, пов'язаних із даним об'єктом (ЄДРПОУ, назва фірми, П.І.Б.)
        if num != 0:
            list_obj = resp[1] # список даних по знайдених фірмах
            for n in range(num):
                edrpou = list_obj[n]['full_edrpou'] # підтягуємо ЄДРПОУ фірми (що робити, якщо його немає?)
                if edrpou not in set(dict_find.keys()): # якщо ми ще не обробляли інформацію про дану фірму
                    if obj[1] == -1: # додаємо інформацію про засновників фірми та нові об'єкти для пошуку
                        add_info(list_obj[n], obj[0]) # тут передаємо для перевірки рядок -- назву фірми
                    elif len(obj) == 2: # додаємо те ж саме, тільки для фірм із певної області
                        add_info(list_obj[n], obj[1]) # тут передаємо ціле число -- номер регіону (або 0)
                    else:
                        add_info(list_obj[n], obj[1], obj[2]) # а тут додаємо ще й адресу засновника
        else:
            if resp[1] == ['error']:
                print('Error request for object = ', obj[0])
    i += 1
# Out:
# CPU times: user 3.31 s, sys: 129 ms, total: 3.44 s
# Wall time: 35.1 s

# %%
dict_find # знайдені контрагенти (вершини графа), для фірм додаємо повну назву, скорочену назву і стан
# Out:
# {'31382665': ('товариство з обмеженою відповідальністю "сигарний дім фортуна"',
#   'тов "сигарний дім фортуна"',
#   'зареєстровано'),
#  'білоус вікторія віталіївна': (),
#  'білоус віталій григорійович': (),
#  'єлісєєв олександр': (),
#  '42275040': ('товариство з обмеженою відповідальністю "хіт-трейд"',
#   'тов "хіт-трейд"',
#   'зареєстровано'),
#  'погорєлов вячеслав іванович': (),
#  'погорелов вячеслав іванович': (),
#  '35050706': ('товариство з обмеженою відповідальністю "фортуна інвест"',
#   'тов "фортуна інвест"',
#   'зареєстровано'),
#  'хотякова олена': (),
#  'бадюл ігор анатолійович': (),
#  'чайковський сергій олександрович': (),
#  'хотякова неллі євгеніївна': (),
#  'хаіт олександр леонідович': (),
#  '39892402': ('товариство з обмеженою відповідальністю "лакант"',
#   'тов "лакант"',
#   'припинено'),
#  '35818426': ('приватне підприємство "атп-15101"',
#   'пп"атп-15101"',
#   'зареєстровано'),
#  '42229743': ('товариство з обмеженою відповідальністю "автопарк-юг"',
#   'тов "автопарк-юг"',
#   'зареєстровано'),
#  '32478379': ('приватне підприємство "аврора"', 'пп "аврора"', 'припинено'),
#  '24526422': ('товариство з обмеженою відповідальністю "аріадна."',
#   'тов "аріадна."',
#   'зареєстровано'),
#  'зарх микита': (),
#  'зарх данііл': (),
#  'звєрєв сергій валерійович': (),
#  'зарх владислав': (),
#  '42557980': ('товариство з обмеженою відповідальністю "рент-ол"',
#   'тов "рент-ол"',
#   'зареєстровано'),
#  'будницький максим валерійович': (),
#  'кручко галина володимирівна': (),
#  '41424397': ('товариство з обмеженою відповідальністю "актив естейт"',
#   'тов "актив естейт"',
#   'зареєстровано'),
#  'мартиненко михайло сергійович': (),
#  'зарх даніїл': (),
#  'кочергіна світлана олександрівна': (),
#  '34873867': ('товариство з обмеженою відповідальністю "елітстройпроект"',
#   'тов"елітстройпроект"',
#   'зареєстровано'),
#  'будницька катерина сергіївна': (),
#  'пасечник ганна олексіївна': (),
#  'сабідо оскар алонцо': (),
#  '41680460': ('товариство з обмеженою відповідальністю "рент-естейт"',
#   'тов "рент-естейт"',
#   'зареєстровано'),
#  'затона максим миколайович': (),
#  '43376508': ('товариство з обмеженою відповідальністю "проект-ф"',
#   'тов "проект-ф"',
#   'зареєстровано'),
#  '41365887': ('товариство з обмеженою відповідальністю "спот юг"',
#   'тов "спот юг"',
#   'зареєстровано'),
#  'лаврентьєв олександр васильович': (),
#  'наумов олег євгенович': (),
#  'сокол алла олександрівна': (),
#  '42771752': ('товариство з обмеженою відповідальністю "ленд юг"',
#   'тов "ленд юг"',
#   'зареєстровано'),
#  '34553117': ('товариство з обмеженою відповідальністю "кофемолка"',
#   'тов "кофемолка"',
#   'припинено'),
#  '41770234': ('товариство з обмеженою відповідальністю "гал естейт"',
#   'тов "гал естейт"',
#   'припинено'),
#  '41196618': ('товариство з обмеженою відповідальністю "руд рент"',
#   'тов "руд рент"',
#   'зареєстровано'),
#  'будяну олександр георгійович': (),
#  'коляда оксана олександрівна': (),
#  '36503216': ('товариство з обмеженою відповідальністю "вимпел-сіті"',
#   'тов "вимпел-сіті"',
#   'зареєстровано'),
#  'гудима наталя володимирівна': (),
#  'нащубська алла борисівна': (),
#  '42084769': ('товариство з обмеженою відповідальністю "лакрос юг"',
#   'тов "лакрос юг"',
#   'зареєстровано'),
#  'волянська наталія борисівна': (),
#  'волкова надія анатоліївна': (),
#  'ніколаєв роман вячеславович': (),
#  'волянська євгенія олександрівна': (),
#  '41133715': ('товариство з обмеженою відповідальністю "бон буассон естейт"',
#   'тов "бон буассон естейт"',
#   'зареєстровано'),
#  'василі олена володимирівна': (),
#  'циганова олена василівна': (),
#  'будяну оксана валеріївна': (),
#  '35359137': ('приватне підприємство "джерело - 1"',
#   'пп "джерело - 1"',
#   'зареєстровано'),
#  'сапожніченко андрій павлович': (),
#  'сокол валерій анатолійович': (),
#  'корчаченко алла олегівна': (),
#  '43012721': ('товариство з обмеженою відповідальністю "еос естейт"',
#   'тов "еос естейт"',
#   'зареєстровано'),
#  '43028946': ('товариство з обмеженою відповідальністю "троя юг"',
#   'тов "троя юг"',
#   'зареєстровано'),
#  'кузьменко андрій васильович': (),
#  'рокотова вікторія олександрівна': (),
#  '40748323': ('товариство з обмеженою відповідальністю "буклет-юг"',
#   'тов "буклет-юг"',
#   'зареєстровано'),
#  '36492837': ('товариство з обмеженою відповідальністю "бон буассон беверідж"',
#   'тов "бон буассон беверідж"',
#   'зареєстровано'),
#  '34253609': ('товариство з обмеженою відповідальністю "карнавал-юг"',
#   'тов "карнавал-юг"',
#   'зареєстровано'),
#  'білоконь ігор іванович': (),
#  'боярчук ірина володимирівна': (),
#  'ардашев андрій олександрович': (),
#  '30964391': ('приватне підприємство "три корони"',
#   'пп "три корони"',
#   'припинено'),
#  '37638238': ('товариство з обмеженою відповідальністю "лекс хімік"',
#   'тов "лекс хімік"',
#   'зареєстровано'),
#  '24203661': ('фермерське господарство "єлісейські поля"', '', 'припинено'),
#  '32437809': ('приватне підприємство "холстрой"',
#   'пп "холстрой"',
#   'зареєстровано'),
#  '32950237': ('приватне підприємство "вектор аттракцион"',
#   'пп "вектор аттракцион"',
#   'зареєстровано'),
#  '30654574': ('підприємство "вектор" у формі товариства з обмеженою відповідальністю',
#   'підприємство "вектор" у формі тов',
#   'зареєстровано'),
#  '35034630': ('приватне підприємство "механізатор-сд"',
#   'пп "механізатор-сд"',
#   'зареєстровано'),
#  '37769830': ('товариство з обмеженою відповідальністю "будсервісавто"',
#   'тов "будсервісавто"',
#   'зареєстровано'),
#  '26560618': ('дніпропетровський обласний благодійний фонд "фонд ветеранів правоохоронних органів"',
#   'добф "фонд ветеранів правоохоронних органів"',
#   'припинено'),
#  '22394689': ('мале виробниче підприємство "імпульс-2"',
#   'мвп"імпульс-2"',
#   'в стані припинення'),
#  '36893953': ('товариство з обмеженою відповідальністю "еліттех-україна"',
#   'тов "елліттех-україна"',
#   'зареєстровано'),
#  '42550215': ('товариство з обмеженою відповідальністю "данера"',
#   'тов "данера"',
#   'зареєстровано'),
#  'зайков володимир іванович': (),
#  '31593989': ('товариство з обмеженою відповідальністю "світ сервіс"',
#   'тов "світ сервіс"',
#   'зареєстровано'),
#  '42088276': ('громадська організація "чесно та справедливо"',
#   'го "чтс"',
#   'зареєстровано'),
#  '21950668': ('торгово-виробнича фірма "антарес"',
#   'тов твф "антарес"',
#   'припинено'),
#  '00334824': ('державне підприємство "дослідне господарство "степове" національного інституту винограду і вина "магарач"',
#   'дп дг "степове" нівів "магарач"',
#   'зареєстровано'),
#  '13756975': ('повне товариство фірма "квк"', 'пт фірма "квк"', 'припинено'),
#  '16304245': ('товариство з обмеженою відповідальністю "мсп-арго"',
#   'тов "мсп-арго"',
#   'зареєстровано'),
#  '40489558': ('громадська організація "вкладники проти розкрадання "фінініціативи""',
#   'го "вкладники проти розкрадання "фінініціативи""',
#   'зареєстровано'),
#  '24511863': ('українсько-германське товариство з обмеженою відповідальністю "друк-уніон"',
#   'уг тов "друк-уніон"',
#   'зареєстровано'),
#  '24519818': ('товариство з обмеженою відповідальністю "науково-виробнича компанія "інтер-м"',
#   'тов "науково-виробнича компанія "інтер-м"',
#   'зареєстровано'),
#  '35812680': ('товариство з обмеженою відповідальністю "підприємство українського агропромислового холдингу №1"',
#   'тов "підприємство українського агропромислового холдингу №1"',
#   'зареєстровано'),
#  '37211624': ('товариство з обмеженою відповідальністю "ділова безпека"',
#   'тов "ділова безпека"',
#   'зареєстровано'),
#  '34411028': ('товариство з обмеженою відповідальністю "охоронне підприємство "захист зет"',
#   'тов"оп"захист зет"',
#   'зареєстровано'),
#  '34055691': ('товариство з обмеженою відповідальністю "софія інвест"',
#   'тов "софія інвест"',
#   'зареєстровано'),
#  '40642749': ('об\'єднання співвласників багатоквартирного будинку "свобода-10"',
#   'осбб "свобода-10"',
#   'зареєстровано'),
#  '40288786': ('товариство з обмеженою відповідальністю "хіта-трейд"',
#   'тов "хіта-трейд"',
#   'зареєстровано'),
#  '40488685': ('товариство з обмеженою відповідальністю "хіт трейд"',
#   'тов "хіт трейд"',
#   'зареєстровано'),
#  '39012158': ('товариство з обмеженою відповідальністю "хіт-глобал трейд"',
#   'тов "хіт-глобал трейд"',
#   'зареєстровано'),
#  '41448224': ('товариство з обмеженою відповідальністю "фортуна-прод-інвест"',
#   'тов "фортуна-прод-інвест"',
#   'скасовано'),
#  '42190381': ('товариство з обмеженою відповідальністю "ельпасо-трейд"',
#   'тов "ельпасо-трейд"',
#   'зареєстровано'),
#  '39974432': ('товариство з обмеженою відповідальністю "фортуна-інвест-групп"',
#   'тов "фортуна-інвест-групп"',
#   'зареєстровано'),
#  '40435633': ('товариство з обмеженою відповідальністю "фортуна-інвест-буд"',
#   'тов "фортуна-інвест-буд"',
#   'зареєстровано'),
#  '33641097': ('товариство з обмеженою відповідальністю "фортуна інвест 3000"',
#   '',
#   'зареєстровано'),
#  '41448690': ('товариство з обмеженою відповідальністю "метал-транс плюс"',
#   'тов "метал-транс плюс"',
#   'зареєстровано'),
#  '43628994': ('товариство з обмеженою відповідальністю "фортуна систем інвест"',
#   'тов "фортуна систем інвест"',
#   'зареєстровано'),
#  '41285896': ('товариство з обмеженою відповідальністю "будівельна компанія "фортуна-інвест"',
#   'тов "будівельна компанія "фортуна-інвест"',
#   'зареєстровано'),
#  '24628068': ('товариство з обмеженою відповідальністю "тернопіль онлайн"',
#   'тов "тернопіль онлайн"',
#   'зареєстровано'),
#  '25935890': ('товариство з обмеженою відповідальністю "дошкільний навчальний заклад (дитячий ясла-садок) "затишок"',
#   '',
#   'зареєстровано'),
#  '35565102': ('товариство з обмеженою відповідальністю "укрбізнесавто"',
#   'тов "укрбізнесавто"',
#   'зареєстровано'),
#  'сироткіна ірина георгіївна': (),
#  '32810920': ('"віраж плюс"', 'пп ""віраж плюс"', 'припинено'),
#  '31716034': ('приватне підприємство "фенікс"', 'пп "фенікс"', 'припинено'),
#  '40551992': ('приватне підприємство "управитель"',
#   'пп "управитель"',
#   'зареєстровано'),
#  'крамаренко вікторія георгіївна': (),
#  '43690342': ('громадська організація "одеський музей авіаційної техніки"',
#   'го "одеський музей авіаційної техніки"',
#   'зареєстровано'),
#  'оробей сергій ігорович': (),
#  'дівєєв олександр володимирович': (),
#  'наливайко валерій валентинович': (),
#  'більтяєв олексій юрійович': (),
#  '32859479': ('"материк плюс"', 'тов "материк плюс"', 'зареєстровано'),
#  '40897545': ('товариство з обмеженою відповідальністю "виробнича компанія гуд фуд"',
#   'тов "виробнича компанія гуд фуд"',
#   'зареєстровано'),
#  '32792734': ('товариство з обмеженою відповідальністю "альянс - буд"',
#   'тов "альянс - буд"',
#   'припинено'),
#  '37758991': ('товариство з обмеженою відповідальністю "бєнєфіт ав"',
#   'тов "бєнєфіт ав"',
#   'зареєстровано'),
#  'хвостова тетяна михайлівна': (),
#  '36775534': ('канівський міськрайонний благодійний фонд "мир вашій оселі"',
#   'бф "мир вашій оселі"',
#   'зареєстровано'),
#  '38928432': ('товариство з обмеженою відповідальністю "виробниче об\'єднання "завод безалкогольних напоїв"',
#   'тов "во "завод безалкогольних напоїв"',
#   'зареєстровано'),
#  '33137610': ('приватне підприємство "маранта плюс"',
#   'пп"маранта плюс"',
#   'зареєстровано'),
#  'заволокіна олена григорівна': (),
#  '38440508': ('товариство з обмеженою відповідальністю "вагонпром"',
#   'тов "вагонпром"',
#   'зареєстровано'),
#  '31022588': ('приватне підприємство "фуд-массив"', '', 'припинено'),
#  '40961400': ('товариство з обмеженою відповідальністю "ленд естейт"',
#   'тов "ленд естейт"',
#   'зареєстровано'),
#  'заїчко інна олександрівна': (),
#  'стаматова неля іванівна': (),
#  '32207257': ('товариство з обмеженою відповідальністю "аріадна"',
#   '',
#   'в стані припинення'),
#  '34629683': ('товариство з обмеженою відповідальністю "аріадна-харків"',
#   '"аріадна-харків"',
#   'зареєстровано'),
#  '30093969': ('товариство з обмеженою відповідальністю "аріадна"',
#   '',
#   'припинено'),
#  '20922144': ('фірма у формі товариства з обмеженою відповідальністю "аріадна-2"',
#   '',
#   'зареєстровано, свідоцтво про державну реєстрацію недійсне'),
#  '38517093': ('товариство з обмеженою відповідальністю "інформаційне агентство"112 україна"',
#   'тов "іа"112 україна"',
#   'зареєстровано'),
#  '38993370': ('товариство з обмеженою відповідальністю "інформаційне агентство "112.юей"',
#   'тов "іа "112.юей"',
#   'зареєстровано'),
#  '37771169': ('товариство з обмеженою відповідальністю "новий формат тв"',
#   'тов "новий формат тв"',
#   'зареєстровано'),
#  '38590676': ('товариство з обмеженою відповідальністю "телерадіокомпанія "112-тв"',
#   'тов "трк "112-тв"',
#   'зареєстровано'),
#  '30304628': ('товариство з обмеженою відповідальністю "сей.тв системз"',
#   'тов "сей.тв системз"',
#   'зареєстровано'),
#  '37717618': ('товариство з обмеженою відповідальністю "тв вибір"',
#   'тов "тв вибір"',
#   'зареєстровано'),
#  '21236764': ('товариство з обмеженою відповідальністю мале підприємство "аріадна,лтд"',
#   'тов мале підприємство "аріадна,лтд"',
#   'зареєстровано, свідоцтво про державну реєстрацію недійсне'),
#  '37725945': ('товариство з обмеженою відповідальністю "лідер тв"',
#   'тов "лідер тв"',
#   'зареєстровано'),
#  '34167138': ('товариство з обмеженою відповідальністю "аріадна-інвест"',
#   'тзов "аріадна-інвест"',
#   'зареєстровано'),
#  '22769422': ('товариство з обмеженою відповідальністю "аріадна-тур"',
#   'тзов "аріадна-тур"',
#   'зареєстровано'),
#  '43490571': ('товариство з обмеженою відповідальністю "аріадна групп"',
#   '',
#   'зареєстровано'),
#  '39726364': ('товариство з обмеженою відповідальністю "аріадна шиппінг компані"',
#   'тов "аріадна шиппінг компані"',
#   'зареєстровано'),
#  '41706483': ('товариство з обмеженою відповідальністю "аріадна еволюшн"',
#   'тов "аріадна еволюшн"',
#   'зареєстровано'),
#  '36084389': ('товариство з обмеженою відповідальністю "аріадна шиппінг кампані"',
#   'тов "аріадна шиппінг кампані"',
#   'зареєстровано'),
#  '19398494': ('товариство з обмеженою відповідальністю "аріадна"',
#   'тзов "аріадна"',
#   'припинено'),
#  '41504152': ('товариство з обмеженою відповідальністю "аріадна пром"',
#   'тов "аріадна пром"',
#   'зареєстровано'),
#  '24540534': ('товариство з обмеженою відповідальністю "аріадна"',
#   'тов "аріадна"',
#   'зареєстровано'),
#  '36626574': ('товариство з обмеженою відповідальністю "аріадна голд"',
#   'тов "аріадна голд"',
#   'зареєстровано'),
#  '35791094': ('товариство з обмеженою відповідальністю "аріадна-плюс"',
#   'тов "аріадна-плюс"',
#   'зареєстровано'),
#  '31449457': ('товариство з обмеженою відповідальністю "аріадна плюс"',
#   'тов "аріадна плюс"',
#   'в стані припинення'),
#  '20785960': ('товариство з обмеженою відповідальністю "аріадна"',
#   'тзов "аріадна"',
#   'зареєстровано'),
#  '37052384': ('товариство з обмеженою відповідальністю "аріадна суми лтд"',
#   'тов "аріадна суми лтд"',
#   'зареєстровано'),
#  '41367554': ('товариство з обмеженою відповідальністю "аріадна ві"',
#   'тов "аріадна ві"',
#   'зареєстровано'),
#  '40258463': ('товариство з обмеженою відповідальністю "аріадна-полісся"',
#   'тов "аріадна-полісся"',
#   'зареєстровано'),
#  '43380514': ('товариство з обмеженою відповідальністю "аріадна сервіс компані"',
#   'тов "аск"',
#   'зареєстровано'),
#  '19004549': ('товариство з обмеженою відповідальністю "аріадна"',
#   'тов "аріадна"',
#   'зареєстровано'),
#  '37122566': ('товариство з обмеженою відповідальністю "аріадна україна см"',
#   'тов "аріадна україна см"',
#   'зареєстровано'),
#  '33493047': ('товариство з обмеженою відповідальністю "аріадна-фінанс"',
#   'тов "аріадна-фінанс"',
#   'припинено'),
#  '31317858': ('товариство з обмеженою відповідальністю "аріадна-стар"',
#   'тов "аріадна-стар"',
#   'зареєстровано'),
#  '38048831': ('товариство з обмеженою відповідальністю "аріадна текс"',
#   'тов "аріадна текс"',
#   'зареєстровано'),
#  '31538981': ('товариство з обмеженою відповідальністю "аріадна"',
#   'тов "аріадна"',
#   'зареєстровано'),
#  '38180194': ('товариство з обмеженою відповідальністю "аріадна трейд"',
#   'тов "аріадна трейд"',
#   'зареєстровано'),
#  '19232440': ('товариство з обмеженою відповідальністю тов "аріадна"',
#   '"аріадна"',
#   'в стані припинення'),
#  '40780718': ('товариство з обмеженою відповідальністю "інформаційне агентство "112-україна"',
#   'тов " іа "112-україна"',
#   'зареєстровано'),
#  '23635282': ('товариство з обмеженою відповідальністю фірма "дпт-аріадна"',
#   '',
#   'зареєстровано, свідоцтво про державну реєстрацію недійсне'),
#  '39451290': ('товариство з обмеженою відповідальністю "аріадна тм"',
#   'тов "аріадна тм"',
#   'зареєстровано'),
#  '36111925': ('товариство з обмеженою відповідальністю "аріадна - іі"',
#   'тов "аріадна - іі"',
#   'зареєстровано'),
#  '30576429': ('товариство з обмеженою відповідальністю "аріадна"',
#   'тов "аріадна"',
#   'зареєстровано'),
#  '13916491': ('товариство з обмеженою відповідальністю "аріадна - юг"',
#   'тов "аріадна - юг"',
#   'зареєстровано'),
#  '39954547': ('товариство з обмеженою відповідальністю "стандарт лайн трейдинг"',
#   'тов "стандарт лайн трейдинг"',
#   'зареєстровано'),
#  '13573849': ('товариство з обмеженою відповідальністю "аріадна"',
#   'тов "аріадна"',
#   'зареєстровано'),
#  '22173385': ('товариство з обмеженою відповідальністю "аріадна"',
#   'тов "аріадна"',
#   'зареєстровано'),
#  '39926855': ('товариство з обмеженою відповідальністю "торгівельна агенція "канон"',
#   'тов "торгівельна агенція "канон"',
#   'зареєстровано'),
#  '13812165': ('товариство з обмеженою відповідальністю "аріадна"',
#   'тзов "аріадна"',
#   'зареєстровано'),
#  '20347102': ('товариство з обмеженою відповідальністю виробничо-комерційна фірма "аріадна"',
#   '',
#   'зареєстровано, свідоцтво про державну реєстрацію недійсне'),
#  '19377919': ('товариство з обмеженою відповідальністю мале багатопрофільне підприїмство "аріадна"',
#   '',
#   'зареєстровано, свідоцтво про державну реєстрацію недійсне'),
#  '36356252': ('товариство з обмеженою відповідальністю "нить аріадни"',
#   'тов "нить аріадни"',
#   'зареєстровано'),
#  '33807332': ('товариство з обмеженою відповідальністю "компанія аріадна"',
#   'тов "компанія аріадна"',
#   'припинено'),
#  '43505425': ('товариство з обмеженою відповідальністю "аріадна консалтинг"',
#   'тов "аріадна консалтинг"',
#   'зареєстровано'),
#  '38984556': ('товариство з обмеженою відповідальністю "аріадна тревел"',
#   'тов "аріадна тревел"',
#   'зареєстровано'),
#  '37771263': ('товариство з обмеженою відповідальністю "юридична компанія "олстен партнерс"',
#   'тов "юридична компанія "олстен партнерс"',
#   'зареєстровано'),
#  '39133517': ('товариство з обмеженою відповідальністю "нік аріадна"',
#   'тов"нік аріадна"',
#   'зареєстровано'),
#  '40903333': ('товариство з обмеженою відповідальністю "нтк "аріадна"',
#   'тов "нтк "аріадна"',
#   'зареєстровано'),
#  '37689415': ('товариство з обмеженою відповідальністю "аріадна логістік"',
#   'тов "аріадна логістік"',
#   'зареєстровано'),
#  '30344262': ('товариство з обмеженою відповідальністю "аріадна плюс"',
#   'тов "аріадна плюс"',
#   'зареєстровано'),
#  '36474907': ('товариство з обмеженою відповідальністю "аріадна ххі"',
#   'тов "аріадна ххі"',
#   'зареєстровано'),
#  '37771216': ('товариство з обмеженою відповідальністю "аріадна тв "',
#   'тов "аріадна тв "',
#   'зареєстровано'),
#  '31892672': ('товариство з обмеженою відповідальністю "аріадна"',
#   'тов "аріадна"',
#   'зареєстровано'),
#  '31080050': ('товариство з обмеженою відповідальністю "аріадна"',
#   'тов"аріадна"',
#   'зареєстровано'),
#  '40023169': ('товариство з обмеженою відповідальністю "оріон компані"',
#   'тов "оріон компані"',
#   'зареєстровано'),
#  '32006993': ('товариство з обмеженою відповідальністю "аріадна"',
#   'тов "аріадна"',
#   'зареєстровано'),
#  '03001939': ('товариство з обмеженою відповідальністю "аріадна"',
#   '',
#   'зареєстровано'),
#  '38373814': ('товариство з обмеженою відповідальністю "аріадна ріалті"',
#   'тов "аріадна ріалті"',
#   'зареєстровано'),
#  '38741789': ('товариство з обмеженою відповідальністю "сп"аріадна св"',
#   'тов "сп"аріадна св"',
#   'зареєстровано'),
#  '23079731': ('товариство з обмеженою відповідальністю фірма "аріадна плюс"',
#   '',
#   'припинено'),
#  '37676343': ('товариство з обмеженою відповідальністю "консалтингова компанія аріадна"',
#   'тов "консалтингова компанія аріадна"',
#   'зареєстровано'),
#  '19266522': ('товариство з обмеженою відповідальністю "аріадна"',
#   'тов " аріадна"',
#   'припинено'),
#  '22038954': ('товариство з обмеженою відповідальністю "азов-аріадна"',
#   'тов "азов-аріадна"',
#   'припинено'),
#  '30921864': ('товариство з обмеженою відповідальністю "аріадна"',
#   'тов "аріадна"',
#   'зареєстровано'),
#  '31358365': ('товариство з обмеженою відповідальністю "копіцентр-аріадна"',
#   'тов "копіцентр-аріадна"',
#   'зареєстровано'),
#  '33218851': ('товариство з обмеженою відповідальністю "аріадна суми"',
#   'тов "аріадна суми"',
#   'зареєстровано'),
#  '35631269': ('товариство з обмеженою відповідальністю "аріадна сервіс"',
#   'тов "аріадна сервіс"',
#   'зареєстровано'),
#  '35072042': ('товариство з обмеженою відповідальністю фірма "аріадна-асс"',
#   'тов фірма "аріадна-асс"',
#   'зареєстровано'),
#  '13832446': ('товариство з обмеженою відповідальністю "аріадна"',
#   'тзов "аріадна"',
#   'зареєстровано'),
#  '30234163': ('товариство з обмеженою відповідальністю "аріадна"',
#   'тов "аріадна"',
#   'зареєстровано'),
#  '13470919': ('товариство з обмеженою відповідальністю "магазин №76 "аріадна"',
#   '',
#   'в стані припинення'),
#  '30215769': ('товариство з обмеженою відповідальністю "текстильний дім "нитка аріадни"',
#   'тов "текстильний дім "нитка аріадни"',
#   'зареєстровано'),
#  '38212655': ('товариство з обмеженою відповідальністю "генічеська ткацька фабрика "ніть аріадни"',
#   'тов "гтф "ніть аріадни"',
#   'зареєстровано'),
#  '31858432': ('товариство з обмеженою відповідальністю "аріадна"',
#   'тов "аріадна"',
#   'зареєстровано'),
#  '31034548': ('товариство з обмеженою відповідальністю "науково-виробниче підприємство "аріадна"',
#   'тов нвп "аріадна"',
#   'зареєстровано'),
#  '24836358': ('товариство з обмеженою відповідальністю "спільне підприємство "чексіл-аріадна"',
#   'тов "сп "чексіл-аріадна"',
#   'зареєстровано'),
#  '30514514': ('товариство з обмеженою відповідальністю центр ринкових технологій "аріадна"',
#   'тов црт "аріадна"',
#   'зареєстровано'),
#  '14171745': ('товариство з обмеженою відповідальністю "магазин № 34 "аріадна"',
#   'тов "магазин № 34 "аріадна"',
#   'зареєстровано'),
#  '38608080': ('споживче товариство "аква 2013"',
#   'ст "аква 2013"',
#   'зареєстровано'),
#  '34055644': ('товариство з обмеженою відповідальністю "льодова зірка"',
#   'тов "льодова зірка"',
#   'в стані припинення'),
#  'сарабєєв юрій миколайович': (),
#  '39135315': ('товариство з обмеженою відповідальністю "амстор трейд"',
#   'тов "амстор трейд"',
#   'зареєстровано'),
#  '40961615': ('товариство з обмеженою відповідальністю "авіва-гранд"',
#   'тов "авіва-гранд"',
#   'припинено'),
#  '34552506': ('приватне підприємство "свінг1"', 'пп "свінг1"', 'припинено'),
#  '40952930': ('товариство з обмеженою відповідальністю "форт естейт"',
#   'тов "форт естейт"',
#   'припинено'),
#  '43269310': ('благодійна організація "дитячий благодійний фонд "сприяння"',
#   'дитячий благодійний фонд "сприяння"',
#   'зареєстровано'),
#  'ардашева олександра іларіонівна': (),
#  '35302599': ('приватне підприємство "гаріус плюс"',
#   'пп"гаріус плюс"',
#   'припинено'),
#  '43691977': ('приватне підприємство "нікатед"',
#   'пп "нікатед"',
#   'в стані припинення'),
#  'карпенко ірина віталіївна': (),
#  '42301845': ('товариство з обмеженою відповідальністю "естейт-актив"',
#   'тов "естейт-актив"',
#   'зареєстровано'),
#  '41101526': ('товариство з обмеженою відповідальністю "карна"',
#   'тов "карна"',
#   'припинено'),
#  '41153312': ('товариство з обмеженою відповідальністю "мінос."',
#   'тов "мінос."',
#   'припинено'),
#  '38926325': ('громадська організація "славне місто"', '', 'зареєстровано'),
#  '41151713': ('товариство з обмеженою відповідальністю "тесей-юг"',
#   'тов "тесей-юг"',
#   'припинено'),
#  '32780341': ('приватне підприємство "прометей 1 "',
#   'пп "прометей 1"',
#   'в стані припинення'),
#  '32430850': ('приватне підприємство "трейд"', 'пп "трейд"', 'зареєстровано'),
#  '40045555': ('товариство з обмеженою відповідальністю "рент естейт"',
#   'тзов "рент естейт"',
#   'зареєстровано'),
#  '41921416': ('товариство з обмеженою відповідальністю "реалті рент сервіс"',
#   'тов "реалті рент сервіс"',
#   'зареєстровано'),
#  '43397567': ('товариство з обмеженою відповідальністю "плант сайд"',
#   'тов "плант сайд"',
#   'зареєстровано'),
#  '43179002': ('товариство з обмеженою відповідальністю "блумінг ярд"',
#   'тов "блумінг ярд"',
#   'зареєстровано'),
#  '41921380': ('товариство з обмеженою відповідальністю "рент-естейт 2018"',
#   'тов "рент-естейт 2018"',
#   'зареєстровано'),
#  '42645212': ('товариство з обмеженою відповідальністю "ріал естейт рент"',
#   'тов "рер"',
#   'зареєстровано'),
#  '42499133': ('товариство з обмеженою відповідальністю "крістал рент естейт"',
#   'тов "крістал рент естейт"',
#   'зареєстровано'),
#  '43594138': ('товариство з обмеженою відповідальністю "бранд рент естейт"',
#   'тов "бранд рент естейт"',
#   'зареєстровано'),
#  '40390797': ('товариство з обмеженою відповідальністю "ненні рент естейт"',
#   'тов "ненні рент естейт"',
#   'зареєстровано'),
#  '43648649': ('товариство з обмеженою відповідальністю "естейт рент сервіс"',
#   'тов "естейт рент сервіс"',
#   'зареєстровано'),
#  '41629095': ('товариство з обмеженою відповідальністю "київ естейт рент"',
#   'тов "київ естейт рент"',
#   'зареєстровано'),
#  '33348165': ('товариство з обмеженою відповідальністю "ф-проект"',
#   'тов "ф-проект"',
#   'зареєстровано'),
#  '41880684': ('товариство з обмеженою відповідальністю "сейлс енд логістікс сервісес."',
#   'тов "сейлс енд логістікс сервісес."',
#   'зареєстровано'),
#  '43363881': ('товариство з обмеженою відповідальністю "сейлс енд логістікс сервісес"',
#   'тов"сейлс енд логістікс сервісес"',
#   'зареєстровано'),
#  '35003272': ('товариство з обмеженою відповідальністю "юг-ленд"',
#   'тов "юг-ленд"',
#   'в стані припинення'),
#  '25964747': ('одеська обласна організація всеукраїнської федерації гольфу',
#   'одеська федерація гольфу',
#   'зареєстровано'),
#  '39818491': ('адвокатське об\'єднання "меморандум"',
#   'ао "меморандум"',
#   'зареєстровано'),
#  '41168643': ('товариство з обмеженою відповідальністю "буден естейт"',
#   'тов "буден естейт"',
#   'припинено'),
#  '41935167': ('товариство з обмеженою відповідальністю "лідер-актив"',
#   'тов "лідер-актив"',
#   'зареєстровано'),
#  '40699093': ('товариство з обмеженою відповідальністю "алкогольна виробничо-дистриб\'юторська компанія"',
#   'тов "авдк"',
#   'зареєстровано'),
#  '41341122': ('товариство з обмеженою відповідальністю "крас-естейт"',
#   'тов "крас-естейт"',
#   'припинено'),
#  '44082243': ('товариство з обмеженою відповідальністю "стронг-актив"',
#   'тов "стронг-актив"',
#   'зареєстровано'),
#  '43022038': ('товариство з обмеженою відповідальністю "алко-проперті"',
#   'тов "алко-проперті"',
#   'зареєстровано'),
#  '42881385': ('громадська організація "фізкультурно-спортивний клуб "максимум"',
#   'го "фск "максимум"',
#   'зареєстровано'),
#  '42670872': ('товариство з обмеженою відповідальністю "інвест-актив про"',
#   'тов "інвест-актив про"',
#   'зареєстровано'),
#  '43665346': ('товариство з обмеженою відповідальністю "рент-ленд компані"',
#   'тов "рент-ленд компані"',
#   'зареєстровано'),
#  '40932872': ('товариство з обмеженою відповідальністю "стронгдрінк"',
#   'тов"стронгдрінк"',
#   'в стані припинення'),
#  '38654362': ('товариство з обмеженою відповідальністю "будівельна компанія україни"',
#   'тов "бку"',
#   'зареєстровано'),
#  '21942166': ('приватне підприємство "джерело-1"',
#   'пп "джерело-1"',
#   'припинено'),
#  '13981494': ('товариство з обмеженою відповідальністю "полюс-сервіс"',
#   'тов "полюс-сервіс"',
#   'зареєстровано'),
#  '30233531': ('товариство з обмеженою відповідальністю "полісся-старт"',
#   'тов "полісся-старт"',
#   'зареєстровано'),
#  '38504152': ('товариство з обмеженою відповідальністю "національна алкогольна компанія"',
#   'тов "нак"',
#   'зареєстровано'),
#  '35383594': ('товариство з обмеженою відповідальністю "троя-юг"',
#   'тов "троя-юг"',
#   'зареєстровано')}

# %%
dict_firm # словник для визначення ЄДРПОУ фірми за її назвою (сподіваюсь, дублів за повними назвами фірм немає)
# Out:
# {'товариство з обмеженою відповідальністю "сигарний дім фортуна"': '31382665',
#  'товариство з обмеженою відповідальністю "хіт-трейд"': '42275040',
#  'товариство з обмеженою відповідальністю "фортуна інвест"': '35050706',
#  'товариство з обмеженою відповідальністю "лакант"': '39892402',
#  'приватне підприємство "атп-15101"': '35818426',
#  'товариство з обмеженою відповідальністю "автопарк-юг"': '42229743',
#  'приватне підприємство "аврора"': '32478379',
#  'товариство з обмеженою відповідальністю "аріадна."': '24526422',
#  'товариство з обмеженою відповідальністю "рент-ол"': '42557980',
#  'товариство з обмеженою відповідальністю "актив естейт"': '41424397',
#  'товариство з обмеженою відповідальністю "елітстройпроект"': '34873867',
#  'товариство з обмеженою відповідальністю "рент-естейт"': '41680460',
#  'товариство з обмеженою відповідальністю "проект-ф"': '43376508',
#  'товариство з обмеженою відповідальністю "спот юг"': '41365887',
#  'товариство з обмеженою відповідальністю "ленд юг"': '42771752',
#  'товариство з обмеженою відповідальністю "кофемолка"': '34553117',
#  'товариство з обмеженою відповідальністю "гал естейт"': '41770234',
#  'товариство з обмеженою відповідальністю "руд рент"': '41196618',
#  'товариство з обмеженою відповідальністю "вимпел-сіті"': '36503216',
#  'товариство з обмеженою відповідальністю "лакрос юг"': '42084769',
#  'товариство з обмеженою відповідальністю "бон буассон естейт"': '41133715',
#  'приватне підприємство "джерело - 1"': '35359137',
#  'товариство з обмеженою відповідальністю "еос естейт"': '43012721',
#  'товариство з обмеженою відповідальністю "троя юг"': '43028946',
#  'товариство з обмеженою відповідальністю "буклет-юг"': '40748323',
#  'товариство з обмеженою відповідальністю "бон буассон беверідж"': '36492837',
#  'товариство з обмеженою відповідальністю "карнавал-юг"': '34253609',
#  'приватне підприємство "три корони"': '30964391',
#  'товариство з обмеженою відповідальністю "лекс хімік"': '37638238',
#  'фермерське господарство "єлісейські поля"': '24203661',
#  'приватне підприємство "холстрой"': '32437809',
#  'приватне підприємство "вектор аттракцион"': '32950237',
#  'підприємство "вектор" у формі товариства з обмеженою відповідальністю': '30654574',
#  'приватне підприємство "механізатор-сд"': '35034630',
#  'товариство з обмеженою відповідальністю "будсервісавто"': '37769830',
#  'дніпропетровський обласний благодійний фонд "фонд ветеранів правоохоронних органів"': '26560618',
#  'мале виробниче підприємство "імпульс-2"': '22394689',
#  'товариство з обмеженою відповідальністю "еліттех-україна"': '36893953',
#  'товариство з обмеженою відповідальністю "данера"': '42550215',
#  'товариство з обмеженою відповідальністю "світ сервіс"': '31593989',
#  'громадська організація "чесно та справедливо"': '42088276',
#  'торгово-виробнича фірма "антарес"': '21950668',
#  'державне підприємство "дослідне господарство "степове" національного інституту винограду і вина "магарач"': '00334824',
#  'повне товариство фірма "квк"': '13756975',
#  'товариство з обмеженою відповідальністю "мсп-арго"': '16304245',
#  'громадська організація "вкладники проти розкрадання "фінініціативи""': '40489558',
#  'українсько-германське товариство з обмеженою відповідальністю "друк-уніон"': '24511863',
#  'товариство з обмеженою відповідальністю "науково-виробнича компанія "інтер-м"': '24519818',
#  'товариство з обмеженою відповідальністю "підприємство українського агропромислового холдингу №1"': '35812680',
#  'товариство з обмеженою відповідальністю "ділова безпека"': '37211624',
#  'товариство з обмеженою відповідальністю "охоронне підприємство "захист зет"': '34411028',
#  'товариство з обмеженою відповідальністю "софія інвест"': '34055691',
#  'об\'єднання співвласників багатоквартирного будинку "свобода-10"': '40642749',
#  'товариство з обмеженою відповідальністю "хіта-трейд"': '40288786',
#  'товариство з обмеженою відповідальністю "хіт трейд"': '40488685',
#  'товариство з обмеженою відповідальністю "хіт-глобал трейд"': '39012158',
#  'товариство з обмеженою відповідальністю "фортуна-прод-інвест"': '41448224',
#  'товариство з обмеженою відповідальністю "ельпасо-трейд"': '42190381',
#  'товариство з обмеженою відповідальністю "фортуна-інвест-групп"': '39974432',
#  'товариство з обмеженою відповідальністю "фортуна-інвест-буд"': '40435633',
#  'товариство з обмеженою відповідальністю "фортуна інвест 3000"': '33641097',
#  'товариство з обмеженою відповідальністю "метал-транс плюс"': '41448690',
#  'товариство з обмеженою відповідальністю "фортуна систем інвест"': '43628994',
#  'товариство з обмеженою відповідальністю "будівельна компанія "фортуна-інвест"': '41285896',
#  'товариство з обмеженою відповідальністю "тернопіль онлайн"': '24628068',
#  'товариство з обмеженою відповідальністю "дошкільний навчальний заклад (дитячий ясла-садок) "затишок"': '25935890',
#  'товариство з обмеженою відповідальністю "укрбізнесавто"': '35565102',
#  '"віраж плюс"': '32810920',
#  'приватне підприємство "фенікс"': '31716034',
#  'приватне підприємство "управитель"': '40551992',
#  'громадська організація "одеський музей авіаційної техніки"': '43690342',
#  '"материк плюс"': '32859479',
#  'товариство з обмеженою відповідальністю "виробнича компанія гуд фуд"': '40897545',
#  'товариство з обмеженою відповідальністю "альянс - буд"': '32792734',
#  'товариство з обмеженою відповідальністю "бєнєфіт ав"': '37758991',
#  'канівський міськрайонний благодійний фонд "мир вашій оселі"': '36775534',
#  'товариство з обмеженою відповідальністю "виробниче об\'єднання "завод безалкогольних напоїв"': '38928432',
#  'приватне підприємство "маранта плюс"': '33137610',
#  'товариство з обмеженою відповідальністю "вагонпром"': '38440508',
#  'приватне підприємство "фуд-массив"': '31022588',
#  'товариство з обмеженою відповідальністю "ленд естейт"': '40961400',
#  'товариство з обмеженою відповідальністю "аріадна"': '31858432',
#  'товариство з обмеженою відповідальністю "аріадна-харків"': '34629683',
#  'фірма у формі товариства з обмеженою відповідальністю "аріадна-2"': '20922144',
#  'товариство з обмеженою відповідальністю "інформаційне агентство"112 україна"': '38517093',
#  'товариство з обмеженою відповідальністю "інформаційне агентство "112.юей"': '38993370',
#  'товариство з обмеженою відповідальністю "новий формат тв"': '37771169',
#  'товариство з обмеженою відповідальністю "телерадіокомпанія "112-тв"': '38590676',
#  'товариство з обмеженою відповідальністю "сей.тв системз"': '30304628',
#  'товариство з обмеженою відповідальністю "тв вибір"': '37717618',
#  'товариство з обмеженою відповідальністю мале підприємство "аріадна,лтд"': '21236764',
#  'товариство з обмеженою відповідальністю "лідер тв"': '37725945',
#  'товариство з обмеженою відповідальністю "аріадна-інвест"': '34167138',
#  'товариство з обмеженою відповідальністю "аріадна-тур"': '22769422',
#  'товариство з обмеженою відповідальністю "аріадна групп"': '43490571',
#  'товариство з обмеженою відповідальністю "аріадна шиппінг компані"': '39726364',
#  'товариство з обмеженою відповідальністю "аріадна еволюшн"': '41706483',
#  'товариство з обмеженою відповідальністю "аріадна шиппінг кампані"': '36084389',
#  'товариство з обмеженою відповідальністю "аріадна пром"': '41504152',
#  'товариство з обмеженою відповідальністю "аріадна голд"': '36626574',
#  'товариство з обмеженою відповідальністю "аріадна-плюс"': '35791094',
#  'товариство з обмеженою відповідальністю "аріадна плюс"': '30344262',
#  'товариство з обмеженою відповідальністю "аріадна суми лтд"': '37052384',
#  'товариство з обмеженою відповідальністю "аріадна ві"': '41367554',
#  'товариство з обмеженою відповідальністю "аріадна-полісся"': '40258463',
#  'товариство з обмеженою відповідальністю "аріадна сервіс компані"': '43380514',
#  'товариство з обмеженою відповідальністю "аріадна україна см"': '37122566',
#  'товариство з обмеженою відповідальністю "аріадна-фінанс"': '33493047',
#  'товариство з обмеженою відповідальністю "аріадна-стар"': '31317858',
#  'товариство з обмеженою відповідальністю "аріадна текс"': '38048831',
#  'товариство з обмеженою відповідальністю "аріадна трейд"': '38180194',
#  'товариство з обмеженою відповідальністю тов "аріадна"': '19232440',
#  'товариство з обмеженою відповідальністю "інформаційне агентство "112-україна"': '40780718',
#  'товариство з обмеженою відповідальністю фірма "дпт-аріадна"': '23635282',
#  'товариство з обмеженою відповідальністю "аріадна тм"': '39451290',
#  'товариство з обмеженою відповідальністю "аріадна - іі"': '36111925',
#  'товариство з обмеженою відповідальністю "аріадна - юг"': '13916491',
#  'товариство з обмеженою відповідальністю "стандарт лайн трейдинг"': '39954547',
#  'товариство з обмеженою відповідальністю "торгівельна агенція "канон"': '39926855',
#  'товариство з обмеженою відповідальністю виробничо-комерційна фірма "аріадна"': '20347102',
#  'товариство з обмеженою відповідальністю мале багатопрофільне підприїмство "аріадна"': '19377919',
#  'товариство з обмеженою відповідальністю "нить аріадни"': '36356252',
#  'товариство з обмеженою відповідальністю "компанія аріадна"': '33807332',
#  'товариство з обмеженою відповідальністю "аріадна консалтинг"': '43505425',
#  'товариство з обмеженою відповідальністю "аріадна тревел"': '38984556',
#  'товариство з обмеженою відповідальністю "юридична компанія "олстен партнерс"': '37771263',
#  'товариство з обмеженою відповідальністю "нік аріадна"': '39133517',
#  'товариство з обмеженою відповідальністю "нтк "аріадна"': '40903333',
#  'товариство з обмеженою відповідальністю "аріадна логістік"': '37689415',
#  'товариство з обмеженою відповідальністю "аріадна ххі"': '36474907',
#  'товариство з обмеженою відповідальністю "аріадна тв "': '37771216',
#  'товариство з обмеженою відповідальністю "оріон компані"': '40023169',
#  'товариство з обмеженою відповідальністю "аріадна ріалті"': '38373814',
#  'товариство з обмеженою відповідальністю "сп"аріадна св"': '38741789',
#  'товариство з обмеженою відповідальністю фірма "аріадна плюс"': '23079731',
#  'товариство з обмеженою відповідальністю "консалтингова компанія аріадна"': '37676343',
#  'товариство з обмеженою відповідальністю "азов-аріадна"': '22038954',
#  'товариство з обмеженою відповідальністю "копіцентр-аріадна"': '31358365',
#  'товариство з обмеженою відповідальністю "аріадна суми"': '33218851',
#  'товариство з обмеженою відповідальністю "аріадна сервіс"': '35631269',
#  'товариство з обмеженою відповідальністю фірма "аріадна-асс"': '35072042',
#  'товариство з обмеженою відповідальністю "магазин №76 "аріадна"': '13470919',
#  'товариство з обмеженою відповідальністю "текстильний дім "нитка аріадни"': '30215769',
#  'товариство з обмеженою відповідальністю "генічеська ткацька фабрика "ніть аріадни"': '38212655',
#  'товариство з обмеженою відповідальністю "науково-виробниче підприємство "аріадна"': '31034548',
#  'товариство з обмеженою відповідальністю "спільне підприємство "чексіл-аріадна"': '24836358',
#  'товариство з обмеженою відповідальністю центр ринкових технологій "аріадна"': '30514514',
#  'товариство з обмеженою відповідальністю "магазин № 34 "аріадна"': '14171745',
#  'споживче товариство "аква 2013"': '38608080',
#  'товариство з обмеженою відповідальністю "льодова зірка"': '34055644',
#  'товариство з обмеженою відповідальністю "амстор трейд"': '39135315',
#  'товариство з обмеженою відповідальністю "авіва-гранд"': '40961615',
#  'приватне підприємство "свінг1"': '34552506',
#  'товариство з обмеженою відповідальністю "форт естейт"': '40952930',
#  'благодійна організація "дитячий благодійний фонд "сприяння"': '43269310',
#  'приватне підприємство "гаріус плюс"': '35302599',
#  'приватне підприємство "нікатед"': '43691977',
#  'товариство з обмеженою відповідальністю "естейт-актив"': '42301845',
#  'товариство з обмеженою відповідальністю "карна"': '41101526',
#  'товариство з обмеженою відповідальністю "мінос."': '41153312',
#  'громадська організація "славне місто"': '38926325',
#  'товариство з обмеженою відповідальністю "тесей-юг"': '41151713',
#  'приватне підприємство "прометей 1 "': '32780341',
#  'приватне підприємство "трейд"': '32430850',
#  'товариство з обмеженою відповідальністю "рент естейт"': '40045555',
#  'товариство з обмеженою відповідальністю "реалті рент сервіс"': '41921416',
#  'товариство з обмеженою відповідальністю "плант сайд"': '43397567',
#  'товариство з обмеженою відповідальністю "блумінг ярд"': '43179002',
#  'товариство з обмеженою відповідальністю "рент-естейт 2018"': '41921380',
#  'товариство з обмеженою відповідальністю "ріал естейт рент"': '42645212',
#  'товариство з обмеженою відповідальністю "крістал рент естейт"': '42499133',
#  'товариство з обмеженою відповідальністю "бранд рент естейт"': '43594138',
#  'товариство з обмеженою відповідальністю "ненні рент естейт"': '40390797',
#  'товариство з обмеженою відповідальністю "естейт рент сервіс"': '43648649',
#  'товариство з обмеженою відповідальністю "київ естейт рент"': '41629095',
#  'товариство з обмеженою відповідальністю "ф-проект"': '33348165',
#  'товариство з обмеженою відповідальністю "сейлс енд логістікс сервісес."': '41880684',
#  'товариство з обмеженою відповідальністю "сейлс енд логістікс сервісес"': '43363881',
#  'товариство з обмеженою відповідальністю "юг-ленд"': '35003272',
#  'одеська обласна організація всеукраїнської федерації гольфу': '25964747',
#  'адвокатське об\'єднання "меморандум"': '39818491',
#  'товариство з обмеженою відповідальністю "буден естейт"': '41168643',
#  'товариство з обмеженою відповідальністю "лідер-актив"': '41935167',
#  'товариство з обмеженою відповідальністю "алкогольна виробничо-дистриб\'юторська компанія"': '40699093',
#  'товариство з обмеженою відповідальністю "крас-естейт"': '41341122',
#  'товариство з обмеженою відповідальністю "стронг-актив"': '44082243',
#  'товариство з обмеженою відповідальністю "алко-проперті"': '43022038',
#  'громадська організація "фізкультурно-спортивний клуб "максимум"': '42881385',
#  'товариство з обмеженою відповідальністю "інвест-актив про"': '42670872',
#  'товариство з обмеженою відповідальністю "рент-ленд компані"': '43665346',
#  'товариство з обмеженою відповідальністю "стронгдрінк"': '40932872',
#  'товариство з обмеженою відповідальністю "будівельна компанія україни"': '38654362',
#  'приватне підприємство "джерело-1"': '21942166',
#  'товариство з обмеженою відповідальністю "полюс-сервіс"': '13981494',
#  'товариство з обмеженою відповідальністю "полісся-старт"': '30233531',
#  'товариство з обмеженою відповідальністю "національна алкогольна компанія"': '38504152',
#  'товариство з обмеженою відповідальністю "троя-юг"': '35383594'}

# %%
len(dict_firm)
# Out:
# 197

# %%
list_type # (засновник, ЄДРПОУ заснованої фірми, частка участі засновника, чи є засновник бенефіціаром)
# Out:
# [['єлісєєв олександр', '31382665', 0.5, 1],
#  ['білоус вікторія віталіївна', '31382665', 0.5, 1],
#  ['31382665', '42275040', 1.0, 0],
#  ['білоус вікторія віталіївна', '42275040', 0, 1],
#  ['єлісєєв олександр', '35050706', 0.2539348392481973, 1],
#  ['хотякова олена', '35050706', 0.13075368759157163, 0],
#  ['бадюл ігор анатолійович', '35050706', 0.15382786858359165, 1],
#  ['хаіт олександр леонідович', '35050706', 0.15382786858359165, 0],
#  ['хотякова неллі євгеніївна', '35050706', 0.13075368759157163, 0],
#  ['білоус вікторія віталіївна', '35050706', 0.17690204840147622, 1],
#  ['зарх микита', '24526422', 0.028204235166345293, 1],
#  ['бадюл ігор анатолійович', '24526422', 0.08285007025437408, 1],
#  ['білоус віталій григорійович', '24526422', 0.32989358206736075, 0],
#  ['хаіт олександр леонідович', '24526422', 0.09545156594006436, 0],
#  ['єлісєєв олександр', '24526422', 0.32989358206736075, 0],
#  ['беллкор інвестмент лімітед (bellkor investment limited)',
#   '24526422',
#   0.0038587420220974724,
#   0],
#  ['зарх данііл', '24526422', 0.0047725782970032184, 0],
#  ['зарх владислав', '24526422', 0.045339493821530574, 0],
#  ['хотякова неллі євгеніївна', '24526422', 0.07973615036386342, 0],
#  ['білоус віталій григорійович', '42557980', 1.0, 0],
#  ['хаіт олександр леонідович', '41424397', 0.10298696358872116, 0],
#  ['зарх микита', '41424397', 0.04482541204966203, 0],
#  ['зарх данііл', '41424397', 0.004718464271807466, 0],
#  ['білоус віталій григорійович', '41424397', 0.09436928837113152, 0],
#  ['бадюл ігор анатолійович', '41424397', 0.09434972182302141, 0],
#  ['єлісєєв олександр', '41424397', 0.09436928837113152, 0],
#  ['товариство з обмеженою відповідальністю "форт естейт"',
#   '41424397',
#   0.5148369852030552,
#   0],
#  ['зарх владислав', '41424397', 0.04482541204966203, 0],
#  ['зарх даніїл', '41424397', 0.004718464271807466, 0],
#  ['кочергіна світлана олександрівна', '41424397', 0, 1],
#  ['бадюл ігор анатолійович', '34873867', 0.11233037747958388, 0],
#  ['зарх владислав', '34873867', 0.0027955166015315542, 0],
#  ['єлісєєв олександр', '34873867', 0.006212259815813824, 0],
#  ['хаіт олександр леонідович', '34873867', 0.11233037747958388, 0],
#  ['білоус віталій григорійович', '34873867', 0.08986430180333302, 0],
#  ['зарх микита', '34873867', 0.0024849046476619107, 0],
#  ['компанія "беллкор інвестмен лімітед"', '34873867', 0.5616518855945785, 0],
#  ['беллкор інвестмен лімітед (bellkor investment limited)',
#   '34873867',
#   0.11233037657791341,
#   0],
#  ['сабідо оскар алонцо', '34873867', 0, 1],
#  ['єлісєєв олександр', '41680460', 0.18099547697263657, 0],
#  ['білоус віталій григорійович', '41680460', 0.18099547697263657, 0],
#  ['зарх владислав', '41680460', 0.18099547697263657, 0],
#  ['зарх микита', '41680460', 0.08597284128818541, 0],
#  ['зарх данііл', '41680460', 0.009049773848631829, 0],
#  ['хаіт олександр леонідович', '41680460', 0.18099547697263657, 0],
#  ['бадюл ігор анатолійович', '41680460', 0.18099547697263657, 0],
#  ['хаіт олександр леонідович', '43376508', 0.2000000006797486, 0],
#  ['єлісєєв олександр', '43376508', 0.2000000006797486, 0],
#  ['зарх микита', '43376508', 0.07999999959215087, 0],
#  ['бадюл ігор анатолійович', '43376508', 0.2000000006797486, 0],
#  ['білоус віталій григорійович', '43376508', 0.2299999967032195, 0],
#  ['зарх владислав', '43376508', 0.090000001665384, 0],
#  ['зарх владислав', '41365887', 0.1429, 0],
#  ['лаврентьєв олександр васильович', '41365887', 0.1428, 0],
#  ['білоус віталій григорійович', '41365887', 0.1429, 0],
#  ['бадюл ігор анатолійович', '41365887', 0.1429, 0],
#  ['наумов олег євгенович', '41365887', 0.1428, 0],
#  ['хаіт олександр леонідович', '41365887', 0.1428, 0],
#  ['єлісєєв олександр', '41365887', 0.1429, 0],
#  ['білоус віталій григорійович', '42771752', 0.10019585284187661, 0],
#  ['зарх владислав', '42771752', 0.04759302789656896, 0],
#  ['єлісєєв олександр', '42771752', 0.10019585284187661, 0],
#  ['зарх данііл', '42771752', 0.005009787256194539, 0],
#  ['хаіт олександр леонідович', '42771752', 0.10019585284187661, 0],
#  ['бадюл ігор анатолійович', '42771752', 0.10019585284187661, 0],
#  ['зарх микита', '42771752', 0.04759302789656896, 0],
#  ['товариство з обмеженою відповідальністю "руд рент"',
#   '42771752',
#   0.49902074558316106,
#   0],
#  ['хаіт олександр леонідович', '41196618', 0.01582479612535139, 0],
#  ['білоус віталій григорійович', '41196618', 0.01582479612535139, 0],
#  ['коляда оксана олександрівна', '41196618', 0.168212572911891, 0],
#  ['зарх данііл', '41196618', 0.0007912404236001217, 0],
#  ['зарх владислав', '41196618', 0.007516778732779281, 0],
#  ['хотякова неллі євгеніївна', '41196618', 0.033801257238662924, 0],
#  ['єлісєєв олександр', '41196618', 0.01582479612535139, 0],
#  ['зарх микита', '41196618', 0.007516778732779281, 0],
#  ['будяну олександр георгійович', '41196618', 0.5326731534336792, 0],
#  ['бадюл ігор анатолійович', '41196618', 0.033801257238662924, 0],
#  ['товариство з обмеженою відповідальністю "рінсвінд"',
#   '41196618',
#   0.168212572911891,
#   0],
#  ['хаіт олександр леонідович', '36503216', 0.05037783369204123, 0],
#  ['беллкор інвестмент лімітед (bellkor investment limited)',
#   '36503216',
#   0.2518891687560553,
#   0],
#  ['зарх владислав', '36503216', 0.02267002536851299, 0],
#  ['білоус віталій григорійович', '36503216', 0.05037783369204123, 0],
#  ['нащубська алла борисівна', '36503216', 0.2518891687560553, 0],
#  ['бадюл ігор анатолійович', '36503216', 0.05037783369204123, 1],
#  ['зарх микита', '36503216', 0.020151133595156173, 0],
#  ['єлісєєв олександр', '36503216', 0.05037783369204123, 0],
#  ['гудима наталя володимирівна', '36503216', 0.2518891687560553, 0],
#  ['сабідо оскар алонцо', '36503216', 0, 1],
#  ['єлісєєв олександр', '42084769', 0.06666666666666667, 0],
#  ['хаіт олександр леонідович', '42084769', 0.06666666666666667, 0],
#  ['зарх владислав', '42084769', 0.03, 0],
#  ['білоус віталій григорійович', '42084769', 0.07666666666666666, 0],
#  ['зарх микита', '42084769', 0.02666666666666667, 0],
#  ['бадюл ігор анатолійович', '42084769', 0.06666666666666667, 1],
#  ['беллкор інвестмент лімітед (bellkor investment limited)',
#   '42084769',
#   0.3333333333333333,
#   0],
#  ['нащубська алла борисівна', '42084769', 0.3333333333333333, 0],
#  ['будницька катерина сергіївна', '42084769', 0, 1],
#  ['бадюл ігор анатолійович', '41133715', 0.09950248756218906, 0],
#  ['білоус віталій григорійович', '41133715', 0.09950248756218906, 0],
#  ['товариство з обмеженою відповідальністю "ленд естейт"',
#   '41133715',
#   0.4975124378109453,
#   0],
#  ['хаіт олександр леонідович', '41133715', 0.09950248756218906, 0],
#  ['зарх владислав', '41133715', 0.0472636815920398, 0],
#  ['зарх микита', '41133715', 0.0472636815920398, 0],
#  ['єлісєєв олександр', '41133715', 0.09950248756218906, 0],
#  ['зарх даніїл', '41133715', 0.004975124378109453, 0],
#  ['зарх данііл', '41133715', 0.004975124378109453, 0],
#  ['будяну оксана валеріївна', '41133715', 0, 1],
#  ['беллкор інвестмент лімітед (bellkor investment limited)',
#   '35359137',
#   0.24999999999999997,
#   0],
#  ['зарх владислав', '35359137', 0.023750000384199617, 0],
#  ['єлісєєв олександр', '35359137', 0.049999999999999996, 0],
#  ['зарх микита', '35359137', 0.018749998847401132, 0],
#  ['корчаченко алла олегівна', '35359137', 0.24999999999999997, 0],
#  ['білоус віталій григорійович', '35359137', 0.057500000768399236, 0],
#  ['хаіт олександр леонідович', '35359137', 0.049999999999999996, 0],
#  ['бадюл ігор анатолійович', '35359137', 0.049999999999999996, 0],
#  ['сапожніченко андрій павлович', '35359137', 0.24999999999999997, 0],
#  ['будницька катерина сергіївна', '35359137', 0, 1],
#  ['зарх владислав', '43012721', 0.0929, 0],
#  ['зарх микита', '43012721', 0.05, 0],
#  ['лаврентьєв олександр васильович', '43012721', 0.1428, 0],
#  ['білоус віталій григорійович', '43012721', 0.1429, 0],
#  ['бадюл ігор анатолійович', '43012721', 0.1429, 0],
#  ['наумов олег євгенович', '43012721', 0.1428, 0],
#  ['хаіт олександр леонідович', '43012721', 0.1428, 0],
#  ['єлісєєв олександр', '43012721', 0.1429, 0],
#  ['єлісєєв олександр', '43028946', 0.06666666666666667, 0],
#  ['хаіт олександр леонідович', '43028946', 0.06666666666666667, 0],
#  ['зарх владислав', '43028946', 0.03, 0],
#  ['зарх микита', '43028946', 0.02666666666666667, 0],
#  ['бадюл ігор анатолійович', '43028946', 0.06666666666666667, 0],
#  ['білоус віталій григорійович', '43028946', 0.07666666666666666, 0],
#  ['мялковська-рокотова вікторія олександрівна',
#   '43028946',
#   0.3333333333333333,
#   0],
#  ['кузьменко андрій васильович', '43028946', 0.3333333333333333, 0],
#  ['рокотова вікторія олександрівна', '43028946', 0, 0],
#  ['білоус віталій григорійович', '40748323', 0.1, 0],
#  ['хаіт олександр леонідович', '40748323', 0.1, 0],
#  ['зарх владислав', '40748323', 0.0475, 0],
#  ['зарх данііл', '40748323', 0.005, 0],
#  ['бадюл ігор анатолійович', '40748323', 0.1, 0],
#  ['єлісєєв олександр', '40748323', 0.1, 0],
#  ['зарх микита', '40748323', 0.0475, 0],
#  ['24526422', '40748323', 0.5, 0],
#  ['приватна компанія з обмеженою відповідальністю "белвіт інвест лімітед"',
#   '34253609',
#   0.24084014525270095,
#   0],
#  ['зарх микита', '34253609', 0.0202442627968022, 0],
#  ['беллкор інвестмент лімітед (bellkor investment limiter)',
#   '34253609',
#   0.00628214644026389,
#   0],
#  ['бадюл ігор анатолійович', '34253609', 0.05061065694774435, 1],
#  ['ардашев андрій олександрович', '34253609', 0.24084014525270095, 1],
#  ['білоус віталій григорійович', '34253609', 0.05820225559613275, 0],
#  ['приватне підприємство "трейд"', '34253609', 0.005930993222801523, 0],
#  ['хаіт олександр леонідович', '34253609', 0.05061065694774435, 0],
#  ['єлісєєв олександр', '34253609', 0.05061065694774435, 0],
#  ['зарх владислав', '34253609', 0.02277479567959833, 0],
#  ['хотякова неллі євгеніївна', '34253609', 0.25305328491576634, 0],
#  ['будницька катерина сергіївна', '34253609', 0, 1],
#  ['сабідо оскар алонцо', '34253609', 0, 1],
#  ['єлісєєв олександр', '42550215', 1.0, 0],
#  ['хотякова олена', '35565102', 0.5, 0],
#  ['хотякова неллі євгеніївна', '35565102', 0.5, 1],
#  ['зарх владислав', '40551992', 0.5, 0],
#  ['бадюл ігор анатолійович', '40551992', 0.5, 0],
#  ['наливайко валерій валентинович', '43690342', 0, 0],
#  ['оробей сергій ігорович', '43690342', 0, 0],
#  ['більтяєв олексій юрійович', '43690342', 0, 0],
#  ['бадюл ігор анатолійович', '43690342', 0, 0],
#  ['дівєєв олександр володимирович', '43690342', 0, 0],
#  ['хвостова тетяна михайлівна', '37758991', 0.5, 0],
#  ['чайковський сергій олександрович', '37758991', 0.5, 0],
#  ['хотякова неллі євгеніївна', '33137610', 1.0, 0],
#  ['хаіт олександр леонідович', '40961400', 0.5, 0],
#  ['будяну оксана валеріївна', '40961400', 0.5, 0],
#  ['міжнародна комерційна компанія bon enterprises ltd.', '34055644', 1.0, 0],
#  ['зарх владислав', '43269310', 0, 0],
#  ['карпенко ірина віталіївна', '43691977', 0.5, 1],
#  ['43012721', '43691977', 0.5, 0],
#  ['будяну олександр георгійович', '25964747', 0, 1]]

# %% [markdown]
# Якщо ЄДРПОУ по якихось фірмах не підтягнулося відразу, то заміняємо зараз назву фірми на ЄДРПОУ (заміняється не завжди):

# %%
# %%time
list_type_new = list_type.copy()
for i in range(len(list_type_new)):
    if list_type_new[i][0] in list(dict_firm):
        list_type_new[i][0] = dict_firm[list_type_new[i][0]]
list_type_new
# Out:
# CPU times: user 3.33 ms, sys: 0 ns, total: 3.33 ms
# Wall time: 3.23 ms
# [['єлісєєв олександр', '31382665', 0.5, 1],
#  ['білоус вікторія віталіївна', '31382665', 0.5, 1],
#  ['31382665', '42275040', 1.0, 0],
#  ['білоус вікторія віталіївна', '42275040', 0, 1],
#  ['єлісєєв олександр', '35050706', 0.2539348392481973, 1],
#  ['хотякова олена', '35050706', 0.13075368759157163, 0],
#  ['бадюл ігор анатолійович', '35050706', 0.15382786858359165, 1],
#  ['хаіт олександр леонідович', '35050706', 0.15382786858359165, 0],
#  ['хотякова неллі євгеніївна', '35050706', 0.13075368759157163, 0],
#  ['білоус вікторія віталіївна', '35050706', 0.17690204840147622, 1],
#  ['зарх микита', '24526422', 0.028204235166345293, 1],
#  ['бадюл ігор анатолійович', '24526422', 0.08285007025437408, 1],
#  ['білоус віталій григорійович', '24526422', 0.32989358206736075, 0],
#  ['хаіт олександр леонідович', '24526422', 0.09545156594006436, 0],
#  ['єлісєєв олександр', '24526422', 0.32989358206736075, 0],
#  ['беллкор інвестмент лімітед (bellkor investment limited)',
#   '24526422',
#   0.0038587420220974724,
#   0],
#  ['зарх данііл', '24526422', 0.0047725782970032184, 0],
#  ['зарх владислав', '24526422', 0.045339493821530574, 0],
#  ['хотякова неллі євгеніївна', '24526422', 0.07973615036386342, 0],
#  ['білоус віталій григорійович', '42557980', 1.0, 0],
#  ['хаіт олександр леонідович', '41424397', 0.10298696358872116, 0],
#  ['зарх микита', '41424397', 0.04482541204966203, 0],
#  ['зарх данііл', '41424397', 0.004718464271807466, 0],
#  ['білоус віталій григорійович', '41424397', 0.09436928837113152, 0],
#  ['бадюл ігор анатолійович', '41424397', 0.09434972182302141, 0],
#  ['єлісєєв олександр', '41424397', 0.09436928837113152, 0],
#  ['40952930', '41424397', 0.5148369852030552, 0],
#  ['зарх владислав', '41424397', 0.04482541204966203, 0],
#  ['зарх даніїл', '41424397', 0.004718464271807466, 0],
#  ['кочергіна світлана олександрівна', '41424397', 0, 1],
#  ['бадюл ігор анатолійович', '34873867', 0.11233037747958388, 0],
#  ['зарх владислав', '34873867', 0.0027955166015315542, 0],
#  ['єлісєєв олександр', '34873867', 0.006212259815813824, 0],
#  ['хаіт олександр леонідович', '34873867', 0.11233037747958388, 0],
#  ['білоус віталій григорійович', '34873867', 0.08986430180333302, 0],
#  ['зарх микита', '34873867', 0.0024849046476619107, 0],
#  ['компанія "беллкор інвестмен лімітед"', '34873867', 0.5616518855945785, 0],
#  ['беллкор інвестмен лімітед (bellkor investment limited)',
#   '34873867',
#   0.11233037657791341,
#   0],
#  ['сабідо оскар алонцо', '34873867', 0, 1],
#  ['єлісєєв олександр', '41680460', 0.18099547697263657, 0],
#  ['білоус віталій григорійович', '41680460', 0.18099547697263657, 0],
#  ['зарх владислав', '41680460', 0.18099547697263657, 0],
#  ['зарх микита', '41680460', 0.08597284128818541, 0],
#  ['зарх данііл', '41680460', 0.009049773848631829, 0],
#  ['хаіт олександр леонідович', '41680460', 0.18099547697263657, 0],
#  ['бадюл ігор анатолійович', '41680460', 0.18099547697263657, 0],
#  ['хаіт олександр леонідович', '43376508', 0.2000000006797486, 0],
#  ['єлісєєв олександр', '43376508', 0.2000000006797486, 0],
#  ['зарх микита', '43376508', 0.07999999959215087, 0],
#  ['бадюл ігор анатолійович', '43376508', 0.2000000006797486, 0],
#  ['білоус віталій григорійович', '43376508', 0.2299999967032195, 0],
#  ['зарх владислав', '43376508', 0.090000001665384, 0],
#  ['зарх владислав', '41365887', 0.1429, 0],
#  ['лаврентьєв олександр васильович', '41365887', 0.1428, 0],
#  ['білоус віталій григорійович', '41365887', 0.1429, 0],
#  ['бадюл ігор анатолійович', '41365887', 0.1429, 0],
#  ['наумов олег євгенович', '41365887', 0.1428, 0],
#  ['хаіт олександр леонідович', '41365887', 0.1428, 0],
#  ['єлісєєв олександр', '41365887', 0.1429, 0],
#  ['білоус віталій григорійович', '42771752', 0.10019585284187661, 0],
#  ['зарх владислав', '42771752', 0.04759302789656896, 0],
#  ['єлісєєв олександр', '42771752', 0.10019585284187661, 0],
#  ['зарх данііл', '42771752', 0.005009787256194539, 0],
#  ['хаіт олександр леонідович', '42771752', 0.10019585284187661, 0],
#  ['бадюл ігор анатолійович', '42771752', 0.10019585284187661, 0],
#  ['зарх микита', '42771752', 0.04759302789656896, 0],
#  ['41196618', '42771752', 0.49902074558316106, 0],
#  ['хаіт олександр леонідович', '41196618', 0.01582479612535139, 0],
#  ['білоус віталій григорійович', '41196618', 0.01582479612535139, 0],
#  ['коляда оксана олександрівна', '41196618', 0.168212572911891, 0],
#  ['зарх данііл', '41196618', 0.0007912404236001217, 0],
#  ['зарх владислав', '41196618', 0.007516778732779281, 0],
#  ['хотякова неллі євгеніївна', '41196618', 0.033801257238662924, 0],
#  ['єлісєєв олександр', '41196618', 0.01582479612535139, 0],
#  ['зарх микита', '41196618', 0.007516778732779281, 0],
#  ['будяну олександр георгійович', '41196618', 0.5326731534336792, 0],
#  ['бадюл ігор анатолійович', '41196618', 0.033801257238662924, 0],
#  ['товариство з обмеженою відповідальністю "рінсвінд"',
#   '41196618',
#   0.168212572911891,
#   0],
#  ['хаіт олександр леонідович', '36503216', 0.05037783369204123, 0],
#  ['беллкор інвестмент лімітед (bellkor investment limited)',
#   '36503216',
#   0.2518891687560553,
#   0],
#  ['зарх владислав', '36503216', 0.02267002536851299, 0],
#  ['білоус віталій григорійович', '36503216', 0.05037783369204123, 0],
#  ['нащубська алла борисівна', '36503216', 0.2518891687560553, 0],
#  ['бадюл ігор анатолійович', '36503216', 0.05037783369204123, 1],
#  ['зарх микита', '36503216', 0.020151133595156173, 0],
#  ['єлісєєв олександр', '36503216', 0.05037783369204123, 0],
#  ['гудима наталя володимирівна', '36503216', 0.2518891687560553, 0],
#  ['сабідо оскар алонцо', '36503216', 0, 1],
#  ['єлісєєв олександр', '42084769', 0.06666666666666667, 0],
#  ['хаіт олександр леонідович', '42084769', 0.06666666666666667, 0],
#  ['зарх владислав', '42084769', 0.03, 0],
#  ['білоус віталій григорійович', '42084769', 0.07666666666666666, 0],
#  ['зарх микита', '42084769', 0.02666666666666667, 0],
#  ['бадюл ігор анатолійович', '42084769', 0.06666666666666667, 1],
#  ['беллкор інвестмент лімітед (bellkor investment limited)',
#   '42084769',
#   0.3333333333333333,
#   0],
#  ['нащубська алла борисівна', '42084769', 0.3333333333333333, 0],
#  ['будницька катерина сергіївна', '42084769', 0, 1],
#  ['бадюл ігор анатолійович', '41133715', 0.09950248756218906, 0],
#  ['білоус віталій григорійович', '41133715', 0.09950248756218906, 0],
#  ['40961400', '41133715', 0.4975124378109453, 0],
#  ['хаіт олександр леонідович', '41133715', 0.09950248756218906, 0],
#  ['зарх владислав', '41133715', 0.0472636815920398, 0],
#  ['зарх микита', '41133715', 0.0472636815920398, 0],
#  ['єлісєєв олександр', '41133715', 0.09950248756218906, 0],
#  ['зарх даніїл', '41133715', 0.004975124378109453, 0],
#  ['зарх данііл', '41133715', 0.004975124378109453, 0],
#  ['будяну оксана валеріївна', '41133715', 0, 1],
#  ['беллкор інвестмент лімітед (bellkor investment limited)',
#   '35359137',
#   0.24999999999999997,
#   0],
#  ['зарх владислав', '35359137', 0.023750000384199617, 0],
#  ['єлісєєв олександр', '35359137', 0.049999999999999996, 0],
#  ['зарх микита', '35359137', 0.018749998847401132, 0],
#  ['корчаченко алла олегівна', '35359137', 0.24999999999999997, 0],
#  ['білоус віталій григорійович', '35359137', 0.057500000768399236, 0],
#  ['хаіт олександр леонідович', '35359137', 0.049999999999999996, 0],
#  ['бадюл ігор анатолійович', '35359137', 0.049999999999999996, 0],
#  ['сапожніченко андрій павлович', '35359137', 0.24999999999999997, 0],
#  ['будницька катерина сергіївна', '35359137', 0, 1],
#  ['зарх владислав', '43012721', 0.0929, 0],
#  ['зарх микита', '43012721', 0.05, 0],
#  ['лаврентьєв олександр васильович', '43012721', 0.1428, 0],
#  ['білоус віталій григорійович', '43012721', 0.1429, 0],
#  ['бадюл ігор анатолійович', '43012721', 0.1429, 0],
#  ['наумов олег євгенович', '43012721', 0.1428, 0],
#  ['хаіт олександр леонідович', '43012721', 0.1428, 0],
#  ['єлісєєв олександр', '43012721', 0.1429, 0],
#  ['єлісєєв олександр', '43028946', 0.06666666666666667, 0],
#  ['хаіт олександр леонідович', '43028946', 0.06666666666666667, 0],
#  ['зарх владислав', '43028946', 0.03, 0],
#  ['зарх микита', '43028946', 0.02666666666666667, 0],
#  ['бадюл ігор анатолійович', '43028946', 0.06666666666666667, 0],
#  ['білоус віталій григорійович', '43028946', 0.07666666666666666, 0],
#  ['мялковська-рокотова вікторія олександрівна',
#   '43028946',
#   0.3333333333333333,
#   0],
#  ['кузьменко андрій васильович', '43028946', 0.3333333333333333, 0],
#  ['рокотова вікторія олександрівна', '43028946', 0, 0],
#  ['білоус віталій григорійович', '40748323', 0.1, 0],
#  ['хаіт олександр леонідович', '40748323', 0.1, 0],
#  ['зарх владислав', '40748323', 0.0475, 0],
#  ['зарх данііл', '40748323', 0.005, 0],
#  ['бадюл ігор анатолійович', '40748323', 0.1, 0],
#  ['єлісєєв олександр', '40748323', 0.1, 0],
#  ['зарх микита', '40748323', 0.0475, 0],
#  ['24526422', '40748323', 0.5, 0],
#  ['приватна компанія з обмеженою відповідальністю "белвіт інвест лімітед"',
#   '34253609',
#   0.24084014525270095,
#   0],
#  ['зарх микита', '34253609', 0.0202442627968022, 0],
#  ['беллкор інвестмент лімітед (bellkor investment limiter)',
#   '34253609',
#   0.00628214644026389,
#   0],
#  ['бадюл ігор анатолійович', '34253609', 0.05061065694774435, 1],
#  ['ардашев андрій олександрович', '34253609', 0.24084014525270095, 1],
#  ['білоус віталій григорійович', '34253609', 0.05820225559613275, 0],
#  ['32430850', '34253609', 0.005930993222801523, 0],
#  ['хаіт олександр леонідович', '34253609', 0.05061065694774435, 0],
#  ['єлісєєв олександр', '34253609', 0.05061065694774435, 0],
#  ['зарх владислав', '34253609', 0.02277479567959833, 0],
#  ['хотякова неллі євгеніївна', '34253609', 0.25305328491576634, 0],
#  ['будницька катерина сергіївна', '34253609', 0, 1],
#  ['сабідо оскар алонцо', '34253609', 0, 1],
#  ['єлісєєв олександр', '42550215', 1.0, 0],
#  ['хотякова олена', '35565102', 0.5, 0],
#  ['хотякова неллі євгеніївна', '35565102', 0.5, 1],
#  ['зарх владислав', '40551992', 0.5, 0],
#  ['бадюл ігор анатолійович', '40551992', 0.5, 0],
#  ['наливайко валерій валентинович', '43690342', 0, 0],
#  ['оробей сергій ігорович', '43690342', 0, 0],
#  ['більтяєв олексій юрійович', '43690342', 0, 0],
#  ['бадюл ігор анатолійович', '43690342', 0, 0],
#  ['дівєєв олександр володимирович', '43690342', 0, 0],
#  ['хвостова тетяна михайлівна', '37758991', 0.5, 0],
#  ['чайковський сергій олександрович', '37758991', 0.5, 0],
#  ['хотякова неллі євгеніївна', '33137610', 1.0, 0],
#  ['хаіт олександр леонідович', '40961400', 0.5, 0],
#  ['будяну оксана валеріївна', '40961400', 0.5, 0],
#  ['міжнародна комерційна компанія bon enterprises ltd.', '34055644', 1.0, 0],
#  ['зарх владислав', '43269310', 0, 0],
#  ['карпенко ірина віталіївна', '43691977', 0.5, 1],
#  ['43012721', '43691977', 0.5, 0],
#  ['будяну олександр георгійович', '25964747', 0, 1]]

# %%
list_head # (голова, ЄДРПОУ фірми)
# Out:
# [['білоус віталій григорійович', '31382665'],
#  ['погорєлов вячеслав іванович', '42275040'],
#  ['погорелов вячеслав іванович', '42275040'],
#  ['чайковський сергій олександрович', '35050706'],
#  ['звєрєв сергій валерійович', '24526422'],
#  ['будницький максим валерійович', '42557980'],
#  ['кручко галина володимирівна', '42557980'],
#  ['мартиненко михайло сергійович', '41424397'],
#  ['будницька катерина сергіївна', '34873867'],
#  ['пасечник ганна олексіївна', '34873867'],
#  ['затона максим миколайович', '41680460'],
#  ['будницька катерина сергіївна', '43376508'],
#  ['сокол алла олександрівна', '41365887'],
#  ['затона максим миколайович', '42771752'],
#  ['будяну олександр георгійович', '41196618'],
#  ['затона максим миколайович', '41196618'],
#  ['сокол алла олександрівна', '36503216'],
#  ['ніколаєв роман вячеславович', '42084769'],
#  ['волянська наталія борисівна', '42084769'],
#  ['волянська євгенія олександрівна', '42084769'],
#  ['волкова надія анатоліївна', '42084769'],
#  ['циганова олена василівна', '41133715'],
#  ['василі олена володимирівна', '41133715'],
#  ['сокол валерій анатолійович', '35359137'],
#  ['сокол алла олександрівна', '43012721'],
#  ['сокол валерій анатолійович', '43028946'],
#  ['сокол валерій анатолійович', '40748323'],
#  ['будяну оксана валеріївна', '40748323'],
#  ['кочергіна світлана олександрівна', '34253609'],
#  ['будяну оксана валеріївна', '34253609'],
#  ['білоконь ігор іванович', '34253609'],
#  ['боярчук ірина володимирівна', '34253609'],
#  ['зайков володимир іванович', '42550215'],
#  ['білоконь ігор іванович', '42550215'],
#  ['сироткіна ірина георгіївна', '35565102'],
#  ['крамаренко вікторія георгіївна', '40551992'],
#  ['будяну олександр георгійович', '40551992'],
#  ['наливайко валерій валентинович', '43690342'],
#  ['хвостова тетяна михайлівна', '37758991'],
#  ['василі олена володимирівна', '33137610'],
#  ['заволокіна олена григорівна', '33137610'],
#  ['стаматова неля іванівна', '40961400'],
#  ['будяну оксана валеріївна', '40961400'],
#  ['заїчко інна олександрівна', '40961400'],
#  ['сапожніченко андрій павлович', '40961400'],
#  ['сарабєєв юрій миколайович', '34055644'],
#  ['звєрєв сергій валерійович', '34055644'],
#  ['ардашева олександра іларіонівна', '43269310'],
#  ['карпенко ірина віталіївна', '43691977'],
#  ['кручко галина володимирівна', '43691977'],
#  ['будяну олександр георгійович', '25964747']]

# %%
list_temp # список контрагентів, за якими здійснювався пошук на останньому рівні
# Out:
# [('товариство з обмеженою відповідальністю "хіт-трейд"', -1),
#  ('погорєлов вячеслав іванович', 5),
#  ('погорелов вячеслав іванович', 5),
#  ('товариство з обмеженою відповідальністю "фортуна інвест"', -1),
#  ('хотякова олена', 5),
#  ('бадюл ігор анатолійович', 5, []),
#  ('чайковський сергій олександрович', 5),
#  ('хотякова неллі євгеніївна', 5),
#  ('хаіт олександр леонідович', 5),
#  ('товариство з обмеженою відповідальністю "аріадна."', -1),
#  ('зарх микита', 5, ['одеськаобласть,м.одеса,приморськийбульвар.буд.10,кв.5']),
#  ('зарх данііл', 5),
#  ('звєрєв сергій валерійович', 5),
#  ('зарх владислав', 5),
#  ('товариство з обмеженою відповідальністю "рент-ол"', -1),
#  ('будницький максим валерійович', 5),
#  ('кручко галина володимирівна', 5),
#  ('товариство з обмеженою відповідальністю "актив естейт"', -1),
#  ('мартиненко михайло сергійович', 5),
#  ('зарх даніїл', 5),
#  ('кочергіна світлана олександрівна',
#   5,
#   ['житомирськаобл.,м.бердичів,вул.житомирськабуд.51,кв.47',
#    'вн,житомирськаобл.,м.бердичів,вул.житомирськабуд.51,кв.47']),
#  ('товариство з обмеженою відповідальністю "елітстройпроект"', -1),
#  ('будницька катерина сергіївна', 5),
#  ('пасечник ганна олексіївна', 5),
#  ('сабідо оскар алонцо',
#   5,
#   ['ро;м.belizecity,newroad5', 'м.belizecity,newroad5']),
#  ('товариство з обмеженою відповідальністю "рент-естейт"', -1),
#  ('затона максим миколайович', 5),
#  ('товариство з обмеженою відповідальністю "проект-ф"', -1),
#  ('товариство з обмеженою відповідальністю "спот юг"', -1),
#  ('лаврентьєв олександр васильович', 5),
#  ('наумов олег євгенович', 5),
#  ('сокол алла олександрівна', 5),
#  ('товариство з обмеженою відповідальністю "ленд юг"', -1),
#  ('товариство з обмеженою відповідальністю "руд рент"', -1),
#  ('будяну олександр георгійович', 5),
#  ('коляда оксана олександрівна', 5),
#  ('товариство з обмеженою відповідальністю "вимпел-сіті"', -1),
#  ('гудима наталя володимирівна', 5),
#  ('нащубська алла борисівна', 5),
#  ('товариство з обмеженою відповідальністю "лакрос юг"', -1),
#  ('волянська наталія борисівна', 5),
#  ('волкова надія анатоліївна', 5),
#  ('ніколаєв роман вячеславович', 5),
#  ('волянська євгенія олександрівна', 5),
#  ('товариство з обмеженою відповідальністю "бон буассон естейт"', -1),
#  ('василі олена володимирівна', 5),
#  ('циганова олена василівна', 5),
#  ('будяну оксана валеріївна',
#   5,
#   ['одеськаобл.,м.одеса,суворовськийрайон,вулицякримська,буд.69,вк.61',
#    'км,україна,одеськаобл.,м.одеса,суворовськийрайон,вулицякримська,буд.69,вк.61']),
#  ('приватне підприємство "джерело - 1"', -1),
#  ('сапожніченко андрій павлович', 5),
#  ('сокол валерій анатолійович', 5),
#  ('корчаченко алла олегівна', 5),
#  ('товариство з обмеженою відповідальністю "еос естейт"', -1),
#  ('товариство з обмеженою відповідальністю "троя юг"', -1),
#  ('кузьменко андрій васильович', 5),
#  ('рокотова вікторія олександрівна', 5),
#  ('товариство з обмеженою відповідальністю "буклет-юг"', -1),
#  ('товариство з обмеженою відповідальністю "карнавал-юг"', -1),
#  ('білоконь ігор іванович', 5),
#  ('боярчук ірина володимирівна', 5),
#  ('ардашев андрій олександрович',
#   5,
#   ['67821,одеськаобл.,овідіопольськийрайон,селосухийлиман,вулицянадії,будинок76']),
#  ('товариство з обмеженою відповідальністю "данера"', -1),
#  ('зайков володимир іванович', 5)]

# %%
list_next # список контрагентів для пошуку на наступному рівні (непорожній, якщо було задано максимальний рівень)
# Out:
# [('товариство з обмеженою відповідальністю "укрбізнесавто"', -1),
#  ('сироткіна ірина георгіївна', 5),
#  ('приватне підприємство "управитель"', -1),
#  ('крамаренко вікторія георгіївна', 5),
#  ('громадська організація "одеський музей авіаційної техніки"', -1),
#  ('оробей сергій ігорович', 5),
#  ('дівєєв олександр володимирович', 5),
#  ('наливайко валерій валентинович', 5),
#  ('більтяєв олексій юрійович', 5),
#  ('товариство з обмеженою відповідальністю "бєнєфіт ав"', -1),
#  ('хвостова тетяна михайлівна', 5),
#  ('приватне підприємство "маранта плюс"', -1),
#  ('заволокіна олена григорівна', 5),
#  ('товариство з обмеженою відповідальністю "ленд естейт"', -1),
#  ('заїчко інна олександрівна', 5),
#  ('стаматова неля іванівна', 5),
#  ('товариство з обмеженою відповідальністю "льодова зірка"', -1),
#  ('сарабєєв юрій миколайович', 5),
#  ('благодійна організація "дитячий благодійний фонд "сприяння"', -1),
#  ('ардашева олександра іларіонівна', 5),
#  ('приватне підприємство "нікатед"', -1),
#  ('карпенко ірина віталіївна', 5, []),
#  ('одеська обласна організація всеукраїнської федерації гольфу', -1)]

# %%
firms = [x for (x, y) in dict_find.items() if len(y) > 0] # список усіх знайдених контрагентів-юросіб
set([y[2] for (x, y) in dict_find.items() if x in firms]) # можливі стани юросіб
# Out:
# {'в стані припинення',
#  'зареєстровано',
#  'зареєстровано, свідоцтво про державну реєстрацію недійсне',
#  'припинено',
#  'скасовано'}

# %%
df_types = pd.DataFrame(list_type, columns=['Founder', 'EDRPOU', 'Founder_part', 'Is_benef'])
#df_types.to_excel('Founded_types.xlsx', index=False)
df_types.tail()
# Out:
#                                                Founder    EDRPOU  \
# 170  міжнародна комерційна компанія bon enterprises...  34055644
# 171                                     зарх владислав  43269310
# 172                          карпенко ірина віталіївна  43691977
# 173                                           43012721  43691977
# 174                       будяну олександр георгійович  25964747
#
#      Founder_part  Is_benef
# 170           1.0         0
# 171           0.0         0
# 172           0.5         1
# 173           0.5         0
# 174           0.0         1

# %%
df_heads = pd.DataFrame(list_head, columns=['Head', 'EDRPOU'])
#df_heads.to_excel('Founded_heads.xlsx', index=False)
df_heads.tail()
# Out:
#                                Head    EDRPOU
# 46        звєрєв сергій валерійович  34055644
# 47  ардашева олександра іларіонівна  43269310
# 48        карпенко ірина віталіївна  43691977
# 49      кручко галина володимирівна  43691977
# 50     будяну олександр георгійович  25964747

# %% [markdown]
# Сформуємо список усіх знайдених контрагентів (вершин графа).

# %%
dict_colours = {'припинено': 'red', 'в стані припинення': 'orange', 
                'зареєстровано, свідоцтво про державну реєстрацію недійсне': 'yellow', 
                'зареєстровано': 'green', 'скасовано': 'blue'}

# %%
nodes = []
ident = 0
for key, value in dict_find.items():
    ident += 1
    if len(value) > 0: # знайдений контрагент -- юрособа
        edrpou = key
        name = value[1]
        colour = dict_colours[value[2]]
    else: # знайдений контрагент -- фізособа
        edrpou = ''
        name = key
        colour = 'white'
    nodes.append({'id': ident, 'colour': colour, 'name': name, 'edrpou': edrpou})

# %%
other = set(df_types['Founder']) - (set([x['name'] for x in nodes]) | set([x['edrpou'] for x in nodes]))
ident = len(nodes)
for item in other:
    ident += 1
    nodes.append({'id': ident, 'colour': 'black', 'name': item, 'edrpou': ''})

# %% [markdown]
# Формуємо граф, поки що без зв'язків, тільки з вершинами.

# %%
G = {"directed": True, "multigraph": True, "graph": {}, "nodes": nodes, "links": []}

# %%
with open('../json/graph.json', 'w', encoding='utf-8') as file:
    json.dump(G, file)

# %% [markdown]
# Тепер додаємо до вершин ідентифікатори і формуємо зв'язки між вершинами.

# %%
df_nodes = pd.DataFrame(nodes)
df_nodes['value'] = df_nodes[['name', 'edrpou']].apply(
    lambda x: x['edrpou'] if x['edrpou'] != '' else x['name'], axis=1)
df_nodes
# Out:
#       id colour                                               name    edrpou  \
# 0      1  green                         тов "сигарний дім фортуна"  31382665
# 1      2  white                         білоус вікторія віталіївна
# 2      3  white                        білоус віталій григорійович
# 3      4  white                                  єлісєєв олександр
# 4      5  green                                    тов "хіт-трейд"  42275040
# ..   ...    ...                                                ...       ...
# 279  280  black  беллкор інвестмен лімітед (bellkor investment ...
# 280  281  black  товариство з обмеженою відповідальністю "рінсв...
# 281  282  black         мялковська-рокотова вікторія олександрівна
# 282  283  black  беллкор інвестмент лімітед (bellkor investment...
# 283  284  black               компанія "беллкор інвестмен лімітед"
#
#                                                  value
# 0                                             31382665
# 1                           білоус вікторія віталіївна
# 2                          білоус віталій григорійович
# 3                                    єлісєєв олександр
# 4                                             42275040
# ..                                                 ...
# 279  беллкор інвестмен лімітед (bellkor investment ...
# 280  товариство з обмеженою відповідальністю "рінсв...
# 281         мялковська-рокотова вікторія олександрівна
# 282  беллкор інвестмент лімітед (bellkor investment...
# 283               компанія "беллкор інвестмен лімітед"
#
# [284 rows x 5 columns]

# %%
def relation_type(part):
    if part >= 0.5:
        return 'high'
    elif part >= 10:
        return 'medium'
    elif part > 0:
        return 'small'
    else:
        return 'undefined'

# %%
dict_colors = {'benef': 'magenta', 'high': 'red', 'medium': 'yellow', 'small': 'green', 'undefined': 'black', 
               'head': 'blue'}

# %%
df_types = df_types.merge(df_nodes[['id', 'value']].rename(columns={'value': 'Founder'}), how='left', 
                          on='Founder').rename(columns={'id': 'source'})
df_types = df_types.merge(df_nodes[['id', 'value']].rename(columns={'value': 'EDRPOU'}), how='left', 
                          on='EDRPOU').rename(columns={'id': 'target'})
df_types['type'] = df_types['Founder_part'].apply(lambda x: relation_type(x))
df_types.tail()
# Out:
#                                                Founder    EDRPOU  \
# 170  міжнародна комерційна компанія bon enterprises...  34055644
# 171                                     зарх владислав  43269310
# 172                          карпенко ірина віталіївна  43691977
# 173                                           43012721  43691977
# 174                       будяну олександр георгійович  25964747
#
#      Founder_part  Is_benef  source  target       type
# 170           1.0         0     277     226       high
# 171           0.0         0      22     232  undefined
# 172           0.5         1     236     235       high
# 173           0.5         0      63     235       high
# 174           0.0         1      45     259  undefined

# %%
df_heads = df_heads.merge(df_nodes[['id', 'value']].rename(columns={'value': 'Head'}), how='left', 
                          on='Head').rename(columns={'id': 'source'})
df_heads = df_heads.merge(df_nodes[['id', 'value']].rename(columns={'value': 'EDRPOU'}), how='left', 
                          on='EDRPOU').rename(columns={'id': 'target'})
df_heads.tail()
# Out:
#                                Head    EDRPOU  source  target
# 46        звєрєв сергій валерійович  34055644      21     226
# 47  ардашева олександра іларіонівна  43269310     233     232
# 48        карпенко ірина віталіївна  43691977     236     235
# 49      кручко галина володимирівна  43691977      25     235
# 50     будяну олександр георгійович  25964747      45     259

# %%
df_rel = df_types[['source', 'target', 'type']]
df_ben = df_types[df_types['Is_benef'] == 1][['source', 'target']].reset_index(drop=True)
df_ben['type'] = 'benef'
df_head = df_heads[['source', 'target']]
df_head['type'] = 'head'
df_type = pd.concat([df_rel, df_ben, df_head], ignore_index=True)
df_type = df_type.sort_values(by=['source', 'target']).reset_index(drop=True)
# Out:
# <ipython-input-59-df857b58dcb3>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_head['type'] = 'head'

# %%
df_type['type'].value_counts()
# Out:
# small        137
# head          51
# benef         23
# high          21
# undefined     17
# Name: type, dtype: int64

# %%
keys = [0]
key = 0
source = df_type['source'][0]
target = df_type['target'][0]
for i in range(1, len(df_type)):
    source_new = df_type['source'][i]
    target_new = df_type['target'][i]
    if (target_new == target) and (source_new == source):
        key += 1
    else:
        key = 0
    keys.append(key)
    source = source_new
    target = target_new

# %%
df_type['color'] = df_type['type'].map(dict_colors)
df_type['key'] = keys
df_type.tail()
# Out:
#      source  target   type  color  key
# 244     283      18  small  green    0
# 245     283      47  small  green    0
# 246     283      50  small  green    0
# 247     283      59  small  green    0
# 248     284      30   high    red    0

# %%
df_type['key'].value_counts()
# Out:
# 0    220
# 1     27
# 2      2
# Name: key, dtype: int64

# %%
links = []
for i in range(len(df_type)): # for JSON, type of integers must be int, not int64!!!
    links.append({'source': int(df_type['source'][i]), 'target': int(df_type['target'][i]), 
                  'color': df_type['color'][i], 'key': int(df_type['key'][i])})

# %%
G["links"] = links

# %%
with open('../json/graph.json', 'w', encoding='utf-8') as file:
    json.dump(G, file)

# %% [markdown]
# That's all!!! We have nodes and endes of our graph in JSON. Лишилося тільки додати степені вершин.

# %%
G = read_json('../json/graph.json')

# %%
G = nodes_degree(G)

# %%
write_json(G, '../json/graph.json')

# %%
#dict_nodes_jur = dict()
#for i in list(dict_find.keys()):
#    if i.isnumeric():
#        dict_nodes_jur[i] = dict_find[i]

# %%
df_nodes = pd.DataFrame(dict_find_new)#, columns=['Head', 'EDRPOU'])
df_nodes#.to_excel('Fortuna_nodes.xlsx', index=False)
